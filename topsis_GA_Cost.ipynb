# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',  # Keeping as requested
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups

    def calculate_required_vehicles(self, vehicle: Dict) -> int:
        """Calculate required number of vehicles based on demand and yearly range"""
        return int(np.ceil(vehicle['demand'] / vehicle['yearly_range']))

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        
        for _ in range(population_size):
            solution = {
                v['vehicle_type']: random.randint(0, self.calculate_required_vehicles(v))
                for v in vehicles
            }
            population.append(solution)
        
        return population

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost (insurance + maintenance + fuel)
        """
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        # Fitness score combining TOPSIS, cost, and demand penalty
        return weighted_topsis + cost_score - demand_penalty

    def crossover(self, parent1: Dict, parent2: Dict) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions"""
        crossover_point = random.randint(1, len(parent1) - 1)
        child1 = {}
        child2 = {}

        for i, vehicle_type in enumerate(parent1.keys()):
            if i < crossover_point:
                child1[vehicle_type] = parent1[vehicle_type]
                child2[vehicle_type] = parent2[vehicle_type]
            else:
                child1[vehicle_type] = parent2[vehicle_type]
                child2[vehicle_type] = parent1[vehicle_type]

        return child1, child2

    def mutate(self, solution: Dict, mutation_rate: float = 0.1, size_distance: Tuple = None) -> Dict:
        """Mutate a solution by randomly adjusting the number of vehicles"""
        mutated_solution = solution.copy()

        # Ensure size_distance is passed, as it is needed for vehicle grouping
        if size_distance is None:
            raise ValueError("size_distance must be provided for mutation")

        vehicles = self.vehicles_by_size_distance[size_distance]
        
        for vehicle_type in mutated_solution.keys():
            if random.random() < mutation_rate:
                # Get the maximum allowed number of vehicles for this vehicle
                max_vehicles = self.calculate_required_vehicles(next(v for v in vehicles if v['vehicle_type'] == vehicle_type))
                mutated_solution[vehicle_type] = max(0, min(max_vehicles, mutated_solution[vehicle_type] + random.choice([-1, 1])))

        return mutated_solution

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for generation in range(generations):
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                              for solution in population]
            
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Track best fitness score
            print(f"Generation {generation + 1}: Best Fitness Score = {fitness_scores[0][1]}")

            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                
                # Pass size_distance during mutation
                child1 = self.mutate(child1, size_distance=size_distance)
                child2 = self.mutate(child2, size_distance=size_distance)
                
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    print(results_df)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Generation 1: Best Fitness Score = 27.484541431041233
# Generation 2: Best Fitness Score = 27.484541431041233
# Generation 3: Best Fitness Score = 28.40313207481445
# Generation 4: Best Fitness Score = 28.40313207481445
# Generation 5: Best Fitness Score = 28.40313207481445
# Generation 6: Best Fitness Score = 28.40313207481445
# Generation 7: Best Fitness Score = 28.40313207481445
# Generation 8: Best Fitness Score = 28.40313207481445
# Generation 9: Best Fitness Score = 28.40313207481445
# Generation 10: Best Fitness Score = 28.40313207481445
# Generation 11: Best Fitness Score = 28.40313207481445
# Generation 12: Best Fitness Score = 28.40313207481445
# Generation 13: Best Fitness Score = 28.40313207481445
# Generation 14: Best Fitness Score = 28.40313207481445
# Generation 15: Best Fitness Score = 28.40313207481445
# Generation 16: Best Fitness Score = 28.40313207481445
# Generation 17: Best Fitness Score = 28.40313207481445
# Generation 18: Best Fitness Score = 28.40313207481445
# Generation 19: Best Fitness Score = 28.40313207481445
# Generation 20: Best Fitness Score = 28.40313207481445
# Generation 21: Best Fitness Score = 28.40313207481445
# Generation 22: Best Fitness Score = 28.40313207481445
# Generation 23: Best Fitness Score = 28.40313207481445
# Generation 24: Best Fitness Score = 28.40313207481445
# Generation 25: Best Fitness Score = 28.40313207481445
# Generation 26: Best Fitness Score = 28.40313207481445
# Generation 27: Best Fitness Score = 28.40313207481445
# Generation 28: Best Fitness Score = 28.40313207481445
# Generation 29: Best Fitness Score = 28.40313207481445
# Generation 30: Best Fitness Score = 28.40313207481445
# Generation 31: Best Fitness Score = 28.40313207481445
# Generation 32: Best Fitness Score = 28.40313207481445
# Generation 33: Best Fitness Score = 28.40313207481445
# Generation 34: Best Fitness Score = 28.40313207481445
# Generation 35: Best Fitness Score = 28.40313207481445
# Generation 36: Best Fitness Score = 28.40313207481445
# Generation 37: Best Fitness Score = 28.40313207481445
# Generation 38: Best Fitness Score = 28.40313207481445
# Generation 39: Best Fitness Score = 28.40313207481445
# Generation 40: Best Fitness Score = 28.40313207481445
# Generation 41: Best Fitness Score = 28.40313207481445
# Generation 42: Best Fitness Score = 28.40313207481445
# Generation 43: Best Fitness Score = 28.40313207481445
# Generation 44: Best Fitness Score = 28.40313207481445
# Generation 45: Best Fitness Score = 28.40313207481445
# Generation 46: Best Fitness Score = 28.40313207481445
# Generation 47: Best Fitness Score = 28.40313207481445
# Generation 48: Best Fitness Score = 28.40313207481445
# Generation 49: Best Fitness Score = 28.40313207481445
# Generation 50: Best Fitness Score = 28.40313207481445
# Generation 51: Best Fitness Score = 28.40313207481445
# Generation 52: Best Fitness Score = 28.40313207481445
# Generation 53: Best Fitness Score = 28.40313207481445
# Generation 54: Best Fitness Score = 28.40313207481445
# Generation 55: Best Fitness Score = 28.40313207481445
# Generation 56: Best Fitness Score = 28.40313207481445
# Generation 57: Best Fitness Score = 28.40313207481445
# Generation 58: Best Fitness Score = 28.40313207481445
# Generation 59: Best Fitness Score = 28.40313207481445
# Generation 60: Best Fitness Score = 28.40313207481445
# Generation 61: Best Fitness Score = 28.40313207481445
# Generation 62: Best Fitness Score = 28.40313207481445
# Generation 63: Best Fitness Score = 28.40313207481445
# Generation 64: Best Fitness Score = 28.40313207481445
# Generation 65: Best Fitness Score = 28.40313207481445
# Generation 66: Best Fitness Score = 28.40313207481445
# Generation 67: Best Fitness Score = 28.40313207481445
# Generation 68: Best Fitness Score = 28.40313207481445
# Generation 69: Best Fitness Score = 28.40313207481445
# Generation 70: Best Fitness Score = 28.40313207481445
# Generation 71: Best Fitness Score = 28.40313207481445
# Generation 72: Best Fitness Score = 28.40313207481445
# Generation 73: Best Fitness Score = 28.40313207481445
# Generation 74: Best Fitness Score = 28.40313207481445
# Generation 75: Best Fitness Score = 28.40313207481445
# Generation 76: Best Fitness Score = 28.40313207481445
# Generation 77: Best Fitness Score = 28.40313207481445
# Generation 78: Best Fitness Score = 28.40313207481445
# Generation 79: Best Fitness Score = 28.40313207481445
# Generation 80: Best Fitness Score = 28.40313207481445
# Generation 81: Best Fitness Score = 28.40313207481445
# Generation 82: Best Fitness Score = 28.40313207481445
# Generation 83: Best Fitness Score = 28.40313207481445
# Generation 84: Best Fitness Score = 28.40313207481445
# Generation 85: Best Fitness Score = 28.40313207481445
# Generation 86: Best Fitness Score = 28.40313207481445
# Generation 87: Best Fitness Score = 28.40313207481445
# Generation 88: Best Fitness Score = 28.40313207481445
# Generation 89: Best Fitness Score = 28.40313207481445
# Generation 90: Best Fitness Score = 28.40313207481445
# Generation 91: Best Fitness Score = 28.40313207481445
# Generation 92: Best Fitness Score = 28.40313207481445
# Generation 93: Best Fitness Score = 28.40313207481445
# Generation 94: Best Fitness Score = 28.40313207481445
# Generation 95: Best Fitness Score = 28.40313207481445
# Generation 96: Best Fitness Score = 28.40313207481445
# Generation 97: Best Fitness Score = 28.40313207481445
# Generation 98: Best Fitness Score = 28.40313207481445
# Generation 99: Best Fitness Score = 28.40313207481445
# Generation 100: Best Fitness Score = 28.40313207481445
# Generation 1: Best Fitness Score = 59.46437444621263
# Generation 2: Best Fitness Score = 59.46437444621263
# Generation 3: Best Fitness Score = 59.46437444621263
# Generation 4: Best Fitness Score = 59.46437444621263
# Generation 5: Best Fitness Score = 59.46437444621263
# Generation 6: Best Fitness Score = 60.970511852105744
# Generation 7: Best Fitness Score = 60.970511852105744
# Generation 8: Best Fitness Score = 61.84294939927978
# Generation 9: Best Fitness Score = 61.84294939927978
# Generation 10: Best Fitness Score = 61.84294939927978
# Generation 11: Best Fitness Score = 61.84294939927978
# Generation 12: Best Fitness Score = 61.84294939927978
# Generation 13: Best Fitness Score = 61.84294939927978
# Generation 14: Best Fitness Score = 61.84294939927978
# Generation 15: Best Fitness Score = 61.84294939927978
# Generation 16: Best Fitness Score = 61.84294939927978
# Generation 17: Best Fitness Score = 61.84294939927978
# Generation 18: Best Fitness Score = 61.84294939927978
# Generation 19: Best Fitness Score = 61.84294939927978
# Generation 20: Best Fitness Score = 61.84294939927978
# Generation 21: Best Fitness Score = 61.84294939927978
# Generation 22: Best Fitness Score = 61.84294939927978
# Generation 23: Best Fitness Score = 61.84294939927978
# Generation 24: Best Fitness Score = 61.84294939927978
# Generation 25: Best Fitness Score = 61.84294939927978
# Generation 26: Best Fitness Score = 61.84294939927978
# Generation 27: Best Fitness Score = 61.84294939927978
# Generation 28: Best Fitness Score = 61.84294939927978
# Generation 29: Best Fitness Score = 61.84294939927978
# Generation 30: Best Fitness Score = 61.84294939927978
# Generation 31: Best Fitness Score = 61.84294939927978
# Generation 32: Best Fitness Score = 61.84294939927978
# Generation 33: Best Fitness Score = 61.84294939927978
# Generation 34: Best Fitness Score = 61.84294939927978
# Generation 35: Best Fitness Score = 61.84294939927978
# Generation 36: Best Fitness Score = 61.84294939927978
# Generation 37: Best Fitness Score = 61.84294939927978
# Generation 38: Best Fitness Score = 61.84294939927978
# Generation 39: Best Fitness Score = 61.84294939927978
# Generation 40: Best Fitness Score = 61.84294939927978
# Generation 41: Best Fitness Score = 61.84294939927978
# Generation 42: Best Fitness Score = 61.84294939927978
# Generation 43: Best Fitness Score = 61.84294939927978
# Generation 44: Best Fitness Score = 61.84294939927978
# Generation 45: Best Fitness Score = 61.84294939927978
# Generation 46: Best Fitness Score = 61.84294939927978
# Generation 47: Best Fitness Score = 61.84294939927978
# Generation 48: Best Fitness Score = 61.84294939927978
# Generation 49: Best Fitness Score = 61.84294939927978
# Generation 50: Best Fitness Score = 61.84294939927978
# Generation 51: Best Fitness Score = 61.84294939927978
# Generation 52: Best Fitness Score = 61.84294939927978
# Generation 53: Best Fitness Score = 61.84294939927978
# Generation 54: Best Fitness Score = 61.84294939927978
# Generation 55: Best Fitness Score = 61.84294939927978
# Generation 56: Best Fitness Score = 61.84294939927978
# Generation 57: Best Fitness Score = 61.84294939927978
# Generation 58: Best Fitness Score = 61.84294939927978
# Generation 59: Best Fitness Score = 61.84294939927978
# Generation 60: Best Fitness Score = 61.84294939927978
# Generation 61: Best Fitness Score = 61.84294939927978
# Generation 62: Best Fitness Score = 61.84294939927978
# Generation 63: Best Fitness Score = 61.84294939927978
# Generation 64: Best Fitness Score = 61.84294939927978
# Generation 65: Best Fitness Score = 61.84294939927978
# Generation 66: Best Fitness Score = 61.84294939927978
# Generation 67: Best Fitness Score = 61.84294939927978
# Generation 68: Best Fitness Score = 61.84294939927978
# Generation 69: Best Fitness Score = 61.84294939927978
# Generation 70: Best Fitness Score = 61.84294939927978
# Generation 71: Best Fitness Score = 61.84294939927978
# Generation 72: Best Fitness Score = 61.84294939927978
# Generation 73: Best Fitness Score = 61.84294939927978
# Generation 74: Best Fitness Score = 61.84294939927978
# Generation 75: Best Fitness Score = 61.84294939927978
# Generation 76: Best Fitness Score = 61.84294939927978
# Generation 77: Best Fitness Score = 61.84294939927978
# Generation 78: Best Fitness Score = 61.84294939927978
# Generation 79: Best Fitness Score = 61.84294939927978
# Generation 80: Best Fitness Score = 61.84294939927978
# Generation 81: Best Fitness Score = 61.84294939927978
# Generation 82: Best Fitness Score = 61.84294939927978
# Generation 83: Best Fitness Score = 61.84294939927978
# Generation 84: Best Fitness Score = 61.84294939927978
# Generation 85: Best Fitness Score = 61.84294939927978
# Generation 86: Best Fitness Score = 61.84294939927978
# Generation 87: Best Fitness Score = 61.84294939927978
# Generation 88: Best Fitness Score = 61.84294939927978
# Generation 89: Best Fitness Score = 61.84294939927978
# Generation 90: Best Fitness Score = 61.84294939927978
# Generation 91: Best Fitness Score = 61.84294939927978
# Generation 92: Best Fitness Score = 61.84294939927978
# Generation 93: Best Fitness Score = 61.84294939927978
# Generation 94: Best Fitness Score = 61.84294939927978
# Generation 95: Best Fitness Score = 61.84294939927978
# Generation 96: Best Fitness Score = 61.84294939927978
# Generation 97: Best Fitness Score = 61.84294939927978
# Generation 98: Best Fitness Score = 61.84294939927978
# Generation 99: Best Fitness Score = 61.84294939927978
# Generation 100: Best Fitness Score = 61.84294939927978
# Generation 1: Best Fitness Score = 78.49297409136412
# Generation 2: Best Fitness Score = 78.49297409136412
# Generation 3: Best Fitness Score = 78.49297409136412
# Generation 4: Best Fitness Score = 78.49297409136412
# Generation 5: Best Fitness Score = 78.49297409136412
# Generation 6: Best Fitness Score = 78.49297409136412
# Generation 7: Best Fitness Score = 78.49297409136412
# Generation 8: Best Fitness Score = 78.49297409136412
# Generation 9: Best Fitness Score = 78.49297409136412
# Generation 10: Best Fitness Score = 78.49297409136412
# Generation 11: Best Fitness Score = 78.49297409136412
# Generation 12: Best Fitness Score = 78.49297409136412
# Generation 13: Best Fitness Score = 78.49297409136412
# Generation 14: Best Fitness Score = 78.49297409136412
# Generation 15: Best Fitness Score = 78.49297409136412
# Generation 16: Best Fitness Score = 78.49297409136412
# Generation 17: Best Fitness Score = 78.49297409136412
# Generation 18: Best Fitness Score = 78.49297409136412
# Generation 19: Best Fitness Score = 78.49297409136412
# Generation 20: Best Fitness Score = 78.49297409136412
# Generation 21: Best Fitness Score = 78.49297409136412
# Generation 22: Best Fitness Score = 78.49297409136412
# Generation 23: Best Fitness Score = 78.49297409136412
# Generation 24: Best Fitness Score = 78.49297409136412
# Generation 25: Best Fitness Score = 78.49297409136412
# Generation 26: Best Fitness Score = 78.49297409136412
# Generation 27: Best Fitness Score = 78.49297409136412
# Generation 28: Best Fitness Score = 78.49297409136412
# Generation 29: Best Fitness Score = 78.49297409136412
# Generation 30: Best Fitness Score = 78.49297409136412
# Generation 31: Best Fitness Score = 78.49297409136412
# Generation 32: Best Fitness Score = 78.49297409136412
# Generation 33: Best Fitness Score = 78.49297409136412
# Generation 34: Best Fitness Score = 78.49297409136412
# Generation 35: Best Fitness Score = 78.49297409136412
# Generation 36: Best Fitness Score = 78.49297409136412
# Generation 37: Best Fitness Score = 78.49297409136412
# Generation 38: Best Fitness Score = 78.49297409136412
# Generation 39: Best Fitness Score = 78.49297409136412
# Generation 40: Best Fitness Score = 78.49297409136412
# Generation 41: Best Fitness Score = 78.49297409136412
# Generation 42: Best Fitness Score = 78.49297409136412
# Generation 43: Best Fitness Score = 78.49297409136412
# Generation 44: Best Fitness Score = 78.49297409136412
# Generation 45: Best Fitness Score = 78.49297409136412
# Generation 46: Best Fitness Score = 78.49297409136412
# Generation 47: Best Fitness Score = 78.49297409136412
# Generation 48: Best Fitness Score = 78.49297409136412
# Generation 49: Best Fitness Score = 78.49297409136412
# Generation 50: Best Fitness Score = 78.49297409136412
# Generation 51: Best Fitness Score = 78.49297409136412
# Generation 52: Best Fitness Score = 78.49297409136412
# Generation 53: Best Fitness Score = 78.49297409136412
# Generation 54: Best Fitness Score = 78.49297409136412
# Generation 55: Best Fitness Score = 78.49297409136412
# Generation 56: Best Fitness Score = 78.49297409136412
# Generation 57: Best Fitness Score = 78.49297409136412
# Generation 58: Best Fitness Score = 78.49297409136412
# Generation 59: Best Fitness Score = 78.49297409136412
# Generation 60: Best Fitness Score = 78.49297409136412
# Generation 61: Best Fitness Score = 78.49297409136412
# Generation 62: Best Fitness Score = 78.49297409136412
# Generation 63: Best Fitness Score = 78.49297409136412
# Generation 64: Best Fitness Score = 78.49297409136412
# Generation 65: Best Fitness Score = 78.49297409136412
# Generation 66: Best Fitness Score = 78.49297409136412
# Generation 67: Best Fitness Score = 78.49297409136412
# Generation 68: Best Fitness Score = 78.49297409136412
# Generation 69: Best Fitness Score = 78.49297409136412
# Generation 70: Best Fitness Score = 78.49297409136412
# Generation 71: Best Fitness Score = 78.49297409136412
# Generation 72: Best Fitness Score = 78.49297409136412
# Generation 73: Best Fitness Score = 78.49297409136412
# Generation 74: Best Fitness Score = 78.49297409136412
# Generation 75: Best Fitness Score = 78.49297409136412
# Generation 76: Best Fitness Score = 78.49297409136412
# Generation 77: Best Fitness Score = 78.49297409136412
# Generation 78: Best Fitness Score = 78.49297409136412
# Generation 79: Best Fitness Score = 78.49297409136412
# Generation 80: Best Fitness Score = 78.49297409136412
# Generation 81: Best Fitness Score = 78.49297409136412
# Generation 82: Best Fitness Score = 78.49297409136412
# Generation 83: Best Fitness Score = 78.49297409136412
# Generation 84: Best Fitness Score = 78.49297409136412
# Generation 85: Best Fitness Score = 78.49297409136412
# Generation 86: Best Fitness Score = 78.49297409136412
# Generation 87: Best Fitness Score = 78.49297409136412
# Generation 88: Best Fitness Score = 78.49297409136412
# Generation 89: Best Fitness Score = 78.49297409136412
# Generation 90: Best Fitness Score = 78.49297409136412
# Generation 91: Best Fitness Score = 78.49297409136412
# Generation 92: Best Fitness Score = 78.49297409136412
# Generation 93: Best Fitness Score = 78.49297409136412
# Generation 94: Best Fitness Score = 78.49297409136412
# Generation 95: Best Fitness Score = 78.49297409136412
# Generation 96: Best Fitness Score = 78.49297409136412
# Generation 97: Best Fitness Score = 78.49297409136412
# Generation 98: Best Fitness Score = 78.49297409136412
# Generation 99: Best Fitness Score = 78.49297409136412
# Generation 100: Best Fitness Score = 78.49297409136412
# Generation 1: Best Fitness Score = 11.020439076503015
# Generation 2: Best Fitness Score = 11.892876405276787
# Generation 3: Best Fitness Score = 11.892876405276787
# Generation 4: Best Fitness Score = 11.892876405276787
# Generation 5: Best Fitness Score = 11.892876405276787
# Generation 6: Best Fitness Score = 11.892876405276787
# Generation 7: Best Fitness Score = 11.892876405276787
# Generation 8: Best Fitness Score = 11.892876405276787
# Generation 9: Best Fitness Score = 11.892876405276787
# Generation 10: Best Fitness Score = 11.892876405276787
# Generation 11: Best Fitness Score = 11.892876405276787
# Generation 12: Best Fitness Score = 11.892876405276787
# Generation 13: Best Fitness Score = 11.892876405276787
# Generation 14: Best Fitness Score = 11.892876405276787
# Generation 15: Best Fitness Score = 11.892876405276787
# Generation 16: Best Fitness Score = 11.892876405276787
# Generation 17: Best Fitness Score = 11.892876405276787
# Generation 18: Best Fitness Score = 11.892876405276787
# Generation 19: Best Fitness Score = 11.892876405276787
# Generation 20: Best Fitness Score = 11.892876405276787
# Generation 21: Best Fitness Score = 11.892876405276787
# Generation 22: Best Fitness Score = 11.892876405276787
# Generation 23: Best Fitness Score = 11.892876405276787
# Generation 24: Best Fitness Score = 11.892876405276787
# Generation 25: Best Fitness Score = 11.892876405276787
# Generation 26: Best Fitness Score = 11.892876405276787
# Generation 27: Best Fitness Score = 11.892876405276787
# Generation 28: Best Fitness Score = 11.892876405276787
# Generation 29: Best Fitness Score = 11.892876405276787
# Generation 30: Best Fitness Score = 11.892876405276787
# Generation 31: Best Fitness Score = 11.892876405276787
# Generation 32: Best Fitness Score = 11.892876405276787
# Generation 33: Best Fitness Score = 11.892876405276787
# Generation 34: Best Fitness Score = 11.892876405276787
# Generation 35: Best Fitness Score = 11.892876405276787
# Generation 36: Best Fitness Score = 11.892876405276787
# Generation 37: Best Fitness Score = 11.892876405276787
# Generation 38: Best Fitness Score = 11.892876405276787
# Generation 39: Best Fitness Score = 11.892876405276787
# Generation 40: Best Fitness Score = 11.892876405276787
# Generation 41: Best Fitness Score = 11.892876405276787
# Generation 42: Best Fitness Score = 11.892876405276787
# Generation 43: Best Fitness Score = 11.892876405276787
# Generation 44: Best Fitness Score = 11.892876405276787
# Generation 45: Best Fitness Score = 11.892876405276787
# Generation 46: Best Fitness Score = 11.892876405276787
# Generation 47: Best Fitness Score = 11.892876405276787
# Generation 48: Best Fitness Score = 11.892876405276787
# Generation 49: Best Fitness Score = 11.892876405276787
# Generation 50: Best Fitness Score = 11.892876405276787
# Generation 51: Best Fitness Score = 11.892876405276787
# Generation 52: Best Fitness Score = 11.892876405276787
# Generation 53: Best Fitness Score = 11.892876405276787
# Generation 54: Best Fitness Score = 11.892876405276787
# Generation 55: Best Fitness Score = 11.892876405276787
# Generation 56: Best Fitness Score = 11.892876405276787
# Generation 57: Best Fitness Score = 11.892876405276787
# Generation 58: Best Fitness Score = 11.892876405276787
# Generation 59: Best Fitness Score = 11.892876405276787
# Generation 60: Best Fitness Score = 11.892876405276787
# Generation 61: Best Fitness Score = 11.892876405276787
# Generation 62: Best Fitness Score = 11.892876405276787
# Generation 63: Best Fitness Score = 11.892876405276787
# Generation 64: Best Fitness Score = 11.892876405276787
# Generation 65: Best Fitness Score = 11.892876405276787
# Generation 66: Best Fitness Score = 11.892876405276787
# Generation 67: Best Fitness Score = 11.892876405276787
# Generation 68: Best Fitness Score = 11.892876405276787
# Generation 69: Best Fitness Score = 11.892876405276787
# Generation 70: Best Fitness Score = 11.892876405276787
# Generation 71: Best Fitness Score = 11.892876405276787
# Generation 72: Best Fitness Score = 11.892876405276787
# Generation 73: Best Fitness Score = 11.892876405276787
# Generation 74: Best Fitness Score = 11.892876405276787
# Generation 75: Best Fitness Score = 11.892876405276787
# Generation 76: Best Fitness Score = 11.892876405276787
# Generation 77: Best Fitness Score = 11.892876405276787
# Generation 78: Best Fitness Score = 11.892876405276787
# Generation 79: Best Fitness Score = 11.892876405276787
# Generation 80: Best Fitness Score = 11.892876405276787
# Generation 81: Best Fitness Score = 11.892876405276787
# Generation 82: Best Fitness Score = 11.892876405276787
# Generation 83: Best Fitness Score = 11.892876405276787
# Generation 84: Best Fitness Score = 11.892876405276787
# Generation 85: Best Fitness Score = 11.892876405276787
# Generation 86: Best Fitness Score = 11.892876405276787
# Generation 87: Best Fitness Score = 11.892876405276787
# Generation 88: Best Fitness Score = 11.892876405276787
# Generation 89: Best Fitness Score = 11.892876405276787
# Generation 90: Best Fitness Score = 11.892876405276787
# Generation 91: Best Fitness Score = 11.892876405276787
# Generation 92: Best Fitness Score = 11.892876405276787
# Generation 93: Best Fitness Score = 11.892876405276787
# Generation 94: Best Fitness Score = 11.892876405276787
# Generation 95: Best Fitness Score = 11.892876405276787
# Generation 96: Best Fitness Score = 11.892876405276787
# Generation 97: Best Fitness Score = 11.892876405276787
# Generation 98: Best Fitness Score = 11.892876405276787
# Generation 99: Best Fitness Score = 11.892876405276787
# Generation 100: Best Fitness Score = 11.892876405276787
# Generation 1: Best Fitness Score = 29.5004326005135
# Generation 2: Best Fitness Score = 29.5004326005135
# Generation 3: Best Fitness Score = 30.328741451540434
# Generation 4: Best Fitness Score = 30.357427374025107
# Generation 5: Best Fitness Score = 30.357427374025107
# Generation 6: Best Fitness Score = 30.357427374025107
# Generation 7: Best Fitness Score = 31.21442215080922
# Generation 8: Best Fitness Score = 31.21442215080922
# Generation 9: Best Fitness Score = 31.21442215080922
# Generation 10: Best Fitness Score = 31.21442215080922
# Generation 11: Best Fitness Score = 31.21442215080922
# Generation 12: Best Fitness Score = 31.21442215080922
# Generation 13: Best Fitness Score = 31.21442215080922
# Generation 14: Best Fitness Score = 31.21442215080922
# Generation 15: Best Fitness Score = 31.21442215080922
# Generation 16: Best Fitness Score = 31.21442215080922
# Generation 17: Best Fitness Score = 31.21442215080922
# Generation 18: Best Fitness Score = 31.21442215080922
# Generation 19: Best Fitness Score = 31.21442215080922
# Generation 20: Best Fitness Score = 31.21442215080922
# Generation 21: Best Fitness Score = 31.21442215080922
# Generation 22: Best Fitness Score = 31.21442215080922
# Generation 23: Best Fitness Score = 31.21442215080922
# Generation 24: Best Fitness Score = 31.21442215080922
# Generation 25: Best Fitness Score = 31.21442215080922
# Generation 26: Best Fitness Score = 31.21442215080922
# Generation 27: Best Fitness Score = 31.21442215080922
# Generation 28: Best Fitness Score = 31.21442215080922
# Generation 29: Best Fitness Score = 31.21442215080922
# Generation 30: Best Fitness Score = 31.21442215080922
# Generation 31: Best Fitness Score = 31.21442215080922
# Generation 32: Best Fitness Score = 31.21442215080922
# Generation 33: Best Fitness Score = 31.21442215080922
# Generation 34: Best Fitness Score = 31.21442215080922
# Generation 35: Best Fitness Score = 31.21442215080922
# Generation 36: Best Fitness Score = 31.21442215080922
# Generation 37: Best Fitness Score = 31.21442215080922
# Generation 38: Best Fitness Score = 31.21442215080922
# Generation 39: Best Fitness Score = 31.21442215080922
# Generation 40: Best Fitness Score = 31.21442215080922
# Generation 41: Best Fitness Score = 31.21442215080922
# Generation 42: Best Fitness Score = 31.21442215080922
# Generation 43: Best Fitness Score = 31.21442215080922
# Generation 44: Best Fitness Score = 31.21442215080922
# Generation 45: Best Fitness Score = 31.21442215080922
# Generation 46: Best Fitness Score = 31.21442215080922
# Generation 47: Best Fitness Score = 31.21442215080922
# Generation 48: Best Fitness Score = 31.21442215080922
# Generation 49: Best Fitness Score = 31.21442215080922
# Generation 50: Best Fitness Score = 31.21442215080922
# Generation 51: Best Fitness Score = 31.21442215080922
# Generation 52: Best Fitness Score = 31.21442215080922
# Generation 53: Best Fitness Score = 31.21442215080922
# Generation 54: Best Fitness Score = 31.21442215080922
# Generation 55: Best Fitness Score = 31.21442215080922
# Generation 56: Best Fitness Score = 31.21442215080922
# Generation 57: Best Fitness Score = 31.21442215080922
# Generation 58: Best Fitness Score = 31.21442215080922
# Generation 59: Best Fitness Score = 31.21442215080922
# Generation 60: Best Fitness Score = 31.21442215080922
# Generation 61: Best Fitness Score = 31.21442215080922
# Generation 62: Best Fitness Score = 31.21442215080922
# Generation 63: Best Fitness Score = 31.21442215080922
# Generation 64: Best Fitness Score = 31.21442215080922
# Generation 65: Best Fitness Score = 31.21442215080922
# Generation 66: Best Fitness Score = 31.21442215080922
# Generation 67: Best Fitness Score = 31.21442215080922
# Generation 68: Best Fitness Score = 31.21442215080922
# Generation 69: Best Fitness Score = 31.21442215080922
# Generation 70: Best Fitness Score = 31.21442215080922
# Generation 71: Best Fitness Score = 31.21442215080922
# Generation 72: Best Fitness Score = 31.21442215080922
# Generation 73: Best Fitness Score = 31.21442215080922
# Generation 74: Best Fitness Score = 31.21442215080922
# Generation 75: Best Fitness Score = 31.21442215080922
# Generation 76: Best Fitness Score = 31.21442215080922
# Generation 77: Best Fitness Score = 31.21442215080922
# Generation 78: Best Fitness Score = 31.21442215080922
# Generation 79: Best Fitness Score = 31.21442215080922
# Generation 80: Best Fitness Score = 31.21442215080922
# Generation 81: Best Fitness Score = 31.21442215080922
# Generation 82: Best Fitness Score = 31.21442215080922
# Generation 83: Best Fitness Score = 31.21442215080922
# Generation 84: Best Fitness Score = 31.21442215080922
# Generation 85: Best Fitness Score = 31.21442215080922
# Generation 86: Best Fitness Score = 31.21442215080922
# Generation 87: Best Fitness Score = 31.21442215080922
# Generation 88: Best Fitness Score = 31.21442215080922
# Generation 89: Best Fitness Score = 31.21442215080922
# Generation 90: Best Fitness Score = 31.21442215080922
# Generation 91: Best Fitness Score = 31.21442215080922
# Generation 92: Best Fitness Score = 31.21442215080922
# Generation 93: Best Fitness Score = 31.21442215080922
# Generation 94: Best Fitness Score = 31.21442215080922
# Generation 95: Best Fitness Score = 31.21442215080922
# Generation 96: Best Fitness Score = 31.21442215080922
# Generation 97: Best Fitness Score = 31.21442215080922
# Generation 98: Best Fitness Score = 31.21442215080922
# Generation 99: Best Fitness Score = 31.21442215080922
# Generation 100: Best Fitness Score = 31.21442215080922
# Generation 1: Best Fitness Score = 28.807855354730698
# Generation 2: Best Fitness Score = 32.41802185628219
# Generation 3: Best Fitness Score = 32.41802185628219
# Generation 4: Best Fitness Score = 32.41802185628219
# Generation 5: Best Fitness Score = 33.29937527762527
# Generation 6: Best Fitness Score = 33.29937527762527
# Generation 7: Best Fitness Score = 33.29937527762527
# Generation 8: Best Fitness Score = 33.29937527762527
# Generation 9: Best Fitness Score = 33.29937527762527
# Generation 10: Best Fitness Score = 33.29937527762527
# Generation 11: Best Fitness Score = 33.29937527762527
# Generation 12: Best Fitness Score = 33.29937527762527
# Generation 13: Best Fitness Score = 33.29937527762527
# Generation 14: Best Fitness Score = 33.29937527762527
# Generation 15: Best Fitness Score = 33.29937527762527
# Generation 16: Best Fitness Score = 33.29937527762527
# Generation 17: Best Fitness Score = 33.29937527762527
# Generation 18: Best Fitness Score = 33.29937527762527
# Generation 19: Best Fitness Score = 33.29937527762527
# Generation 20: Best Fitness Score = 33.29937527762527
# Generation 21: Best Fitness Score = 33.29937527762527
# Generation 22: Best Fitness Score = 33.29937527762527
# Generation 23: Best Fitness Score = 33.29937527762527
# Generation 24: Best Fitness Score = 33.29937527762527
# Generation 25: Best Fitness Score = 33.29937527762527
# Generation 26: Best Fitness Score = 33.29937527762527
# Generation 27: Best Fitness Score = 33.29937527762527
# Generation 28: Best Fitness Score = 33.29937527762527
# Generation 29: Best Fitness Score = 33.29937527762527
# Generation 30: Best Fitness Score = 33.29937527762527
# Generation 31: Best Fitness Score = 33.29937527762527
# Generation 32: Best Fitness Score = 33.29937527762527
# Generation 33: Best Fitness Score = 33.29937527762527
# Generation 34: Best Fitness Score = 33.29937527762527
# Generation 35: Best Fitness Score = 33.29937527762527
# Generation 36: Best Fitness Score = 33.29937527762527
# Generation 37: Best Fitness Score = 33.29937527762527
# Generation 38: Best Fitness Score = 33.29937527762527
# Generation 39: Best Fitness Score = 33.29937527762527
# Generation 40: Best Fitness Score = 33.29937527762527
# Generation 41: Best Fitness Score = 33.29937527762527
# Generation 42: Best Fitness Score = 33.29937527762527
# Generation 43: Best Fitness Score = 33.29937527762527
# Generation 44: Best Fitness Score = 33.29937527762527
# Generation 45: Best Fitness Score = 33.29937527762527
# Generation 46: Best Fitness Score = 33.29937527762527
# Generation 47: Best Fitness Score = 33.29937527762527
# Generation 48: Best Fitness Score = 33.29937527762527
# Generation 49: Best Fitness Score = 33.29937527762527
# Generation 50: Best Fitness Score = 33.29937527762527
# Generation 51: Best Fitness Score = 33.29937527762527
# Generation 52: Best Fitness Score = 33.29937527762527
# Generation 53: Best Fitness Score = 33.29937527762527
# Generation 54: Best Fitness Score = 33.29937527762527
# Generation 55: Best Fitness Score = 33.29937527762527
# Generation 56: Best Fitness Score = 33.29937527762527
# Generation 57: Best Fitness Score = 33.29937527762527
# Generation 58: Best Fitness Score = 33.29937527762527
# Generation 59: Best Fitness Score = 33.29937527762527
# Generation 60: Best Fitness Score = 33.29937527762527
# Generation 61: Best Fitness Score = 33.29937527762527
# Generation 62: Best Fitness Score = 33.29937527762527
# Generation 63: Best Fitness Score = 33.29937527762527
# Generation 64: Best Fitness Score = 33.29937527762527
# Generation 65: Best Fitness Score = 33.29937527762527
# Generation 66: Best Fitness Score = 33.29937527762527
# Generation 67: Best Fitness Score = 33.29937527762527
# Generation 68: Best Fitness Score = 33.29937527762527
# Generation 69: Best Fitness Score = 33.29937527762527
# Generation 70: Best Fitness Score = 33.29937527762527
# Generation 71: Best Fitness Score = 33.29937527762527
# Generation 72: Best Fitness Score = 33.29937527762527
# Generation 73: Best Fitness Score = 33.29937527762527
# Generation 74: Best Fitness Score = 33.29937527762527
# Generation 75: Best Fitness Score = 33.29937527762527
# Generation 76: Best Fitness Score = 33.29937527762527
# Generation 77: Best Fitness Score = 33.29937527762527
# Generation 78: Best Fitness Score = 33.29937527762527
# Generation 79: Best Fitness Score = 33.29937527762527
# Generation 80: Best Fitness Score = 33.29937527762527
# Generation 81: Best Fitness Score = 33.29937527762527
# Generation 82: Best Fitness Score = 33.29937527762527
# Generation 83: Best Fitness Score = 33.29937527762527
# Generation 84: Best Fitness Score = 33.29937527762527
# Generation 85: Best Fitness Score = 33.29937527762527
# Generation 86: Best Fitness Score = 33.29937527762527
# Generation 87: Best Fitness Score = 33.29937527762527
# Generation 88: Best Fitness Score = 33.29937527762527
# Generation 89: Best Fitness Score = 33.29937527762527
# Generation 90: Best Fitness Score = 33.29937527762527
# Generation 91: Best Fitness Score = 33.29937527762527
# Generation 92: Best Fitness Score = 33.29937527762527
# Generation 93: Best Fitness Score = 33.29937527762527
# Generation 94: Best Fitness Score = 33.29937527762527
# Generation 95: Best Fitness Score = 33.29937527762527
# Generation 96: Best Fitness Score = 33.29937527762527
# Generation 97: Best Fitness Score = 33.29937527762527
# Generation 98: Best Fitness Score = 33.29937527762527
# Generation 99: Best Fitness Score = 33.29937527762527
# Generation 100: Best Fitness Score = 33.29937527762527
# Generation 1: Best Fitness Score = 19.02821505679853
# Generation 2: Best Fitness Score = 19.02821505679853
# Generation 3: Best Fitness Score = 19.02821505679853
# Generation 4: Best Fitness Score = 19.02821505679853
# Generation 5: Best Fitness Score = 19.02821505679853
# Generation 6: Best Fitness Score = 19.02821505679853
# Generation 7: Best Fitness Score = 19.02821505679853
# Generation 8: Best Fitness Score = 19.02821505679853
# Generation 9: Best Fitness Score = 19.02821505679853
# Generation 10: Best Fitness Score = 19.02821505679853
# Generation 11: Best Fitness Score = 19.02821505679853
# Generation 12: Best Fitness Score = 19.02821505679853
# Generation 13: Best Fitness Score = 19.02821505679853
# Generation 14: Best Fitness Score = 19.02821505679853
# Generation 15: Best Fitness Score = 19.02821505679853
# Generation 16: Best Fitness Score = 19.02821505679853
# Generation 17: Best Fitness Score = 19.02821505679853
# Generation 18: Best Fitness Score = 19.02821505679853
# Generation 19: Best Fitness Score = 19.02821505679853
# Generation 20: Best Fitness Score = 19.02821505679853
# Generation 21: Best Fitness Score = 19.02821505679853
# Generation 22: Best Fitness Score = 19.02821505679853
# Generation 23: Best Fitness Score = 19.02821505679853
# Generation 24: Best Fitness Score = 19.02821505679853
# Generation 25: Best Fitness Score = 19.02821505679853
# Generation 26: Best Fitness Score = 19.02821505679853
# Generation 27: Best Fitness Score = 19.02821505679853
# Generation 28: Best Fitness Score = 19.02821505679853
# Generation 29: Best Fitness Score = 19.02821505679853
# Generation 30: Best Fitness Score = 19.02821505679853
# Generation 31: Best Fitness Score = 19.02821505679853
# Generation 32: Best Fitness Score = 19.02821505679853
# Generation 33: Best Fitness Score = 19.02821505679853
# Generation 34: Best Fitness Score = 19.02821505679853
# Generation 35: Best Fitness Score = 19.02821505679853
# Generation 36: Best Fitness Score = 19.02821505679853
# Generation 37: Best Fitness Score = 19.02821505679853
# Generation 38: Best Fitness Score = 19.02821505679853
# Generation 39: Best Fitness Score = 19.02821505679853
# Generation 40: Best Fitness Score = 19.02821505679853
# Generation 41: Best Fitness Score = 19.02821505679853
# Generation 42: Best Fitness Score = 19.02821505679853
# Generation 43: Best Fitness Score = 19.02821505679853
# Generation 44: Best Fitness Score = 19.02821505679853
# Generation 45: Best Fitness Score = 19.02821505679853
# Generation 46: Best Fitness Score = 19.02821505679853
# Generation 47: Best Fitness Score = 19.02821505679853
# Generation 48: Best Fitness Score = 19.02821505679853
# Generation 49: Best Fitness Score = 19.02821505679853
# Generation 50: Best Fitness Score = 19.02821505679853
# Generation 51: Best Fitness Score = 19.02821505679853
# Generation 52: Best Fitness Score = 19.02821505679853
# Generation 53: Best Fitness Score = 19.02821505679853
# Generation 54: Best Fitness Score = 19.02821505679853
# Generation 55: Best Fitness Score = 19.02821505679853
# Generation 56: Best Fitness Score = 19.02821505679853
# Generation 57: Best Fitness Score = 19.02821505679853
# Generation 58: Best Fitness Score = 19.02821505679853
# Generation 59: Best Fitness Score = 19.02821505679853
# Generation 60: Best Fitness Score = 19.02821505679853
# Generation 61: Best Fitness Score = 19.02821505679853
# Generation 62: Best Fitness Score = 19.02821505679853
# Generation 63: Best Fitness Score = 19.02821505679853
# Generation 64: Best Fitness Score = 19.02821505679853
# Generation 65: Best Fitness Score = 19.02821505679853
# Generation 66: Best Fitness Score = 19.02821505679853
# Generation 67: Best Fitness Score = 19.02821505679853
# Generation 68: Best Fitness Score = 19.02821505679853
# Generation 69: Best Fitness Score = 19.02821505679853
# Generation 70: Best Fitness Score = 19.02821505679853
# Generation 71: Best Fitness Score = 19.02821505679853
# Generation 72: Best Fitness Score = 19.02821505679853
# Generation 73: Best Fitness Score = 19.02821505679853
# Generation 74: Best Fitness Score = 19.02821505679853
# Generation 75: Best Fitness Score = 19.02821505679853
# Generation 76: Best Fitness Score = 19.02821505679853
# Generation 77: Best Fitness Score = 19.02821505679853
# Generation 78: Best Fitness Score = 19.02821505679853
# Generation 79: Best Fitness Score = 19.02821505679853
# Generation 80: Best Fitness Score = 19.02821505679853
# Generation 81: Best Fitness Score = 19.02821505679853
# Generation 82: Best Fitness Score = 19.02821505679853
# Generation 83: Best Fitness Score = 19.02821505679853
# Generation 84: Best Fitness Score = 19.02821505679853
# Generation 85: Best Fitness Score = 19.02821505679853
# Generation 86: Best Fitness Score = 19.02821505679853
# Generation 87: Best Fitness Score = 19.02821505679853
# Generation 88: Best Fitness Score = 19.02821505679853
# Generation 89: Best Fitness Score = 19.02821505679853
# Generation 90: Best Fitness Score = 19.02821505679853
# Generation 91: Best Fitness Score = 19.02821505679853
# Generation 92: Best Fitness Score = 19.02821505679853
# Generation 93: Best Fitness Score = 19.02821505679853
# Generation 94: Best Fitness Score = 19.02821505679853
# Generation 95: Best Fitness Score = 19.02821505679853
# Generation 96: Best Fitness Score = 19.02821505679853
# Generation 97: Best Fitness Score = 19.02821505679853
# Generation 98: Best Fitness Score = 19.02821505679853
# Generation 99: Best Fitness Score = 19.02821505679853
# Generation 100: Best Fitness Score = 19.02821505679853
# Generation 1: Best Fitness Score = 4.757057174374477
# Generation 2: Best Fitness Score = 4.757057174374477
# Generation 3: Best Fitness Score = 4.757057174374477
# Generation 4: Best Fitness Score = 4.757057174374477
# Generation 5: Best Fitness Score = 4.757057174374477
# Generation 6: Best Fitness Score = 4.757057174374477
# Generation 7: Best Fitness Score = 4.757057174374477
# Generation 8: Best Fitness Score = 4.757057174374477
# Generation 9: Best Fitness Score = 4.757057174374477
# Generation 10: Best Fitness Score = 4.757057174374477
# Generation 11: Best Fitness Score = 4.757057174374477
# Generation 12: Best Fitness Score = 4.757057174374477
# Generation 13: Best Fitness Score = 4.757057174374477
# Generation 14: Best Fitness Score = 4.757057174374477
# Generation 15: Best Fitness Score = 4.757057174374477
# Generation 16: Best Fitness Score = 4.757057174374477
# Generation 17: Best Fitness Score = 4.757057174374477
# Generation 18: Best Fitness Score = 4.757057174374477
# Generation 19: Best Fitness Score = 4.757057174374477
# Generation 20: Best Fitness Score = 4.757057174374477
# Generation 21: Best Fitness Score = 4.757057174374477
# Generation 22: Best Fitness Score = 4.757057174374477
# Generation 23: Best Fitness Score = 4.757057174374477
# Generation 24: Best Fitness Score = 4.757057174374477
# Generation 25: Best Fitness Score = 4.757057174374477
# Generation 26: Best Fitness Score = 4.757057174374477
# Generation 27: Best Fitness Score = 4.757057174374477
# Generation 28: Best Fitness Score = 4.757057174374477
# Generation 29: Best Fitness Score = 4.757057174374477
# Generation 30: Best Fitness Score = 4.757057174374477
# Generation 31: Best Fitness Score = 4.757057174374477
# Generation 32: Best Fitness Score = 4.757057174374477
# Generation 33: Best Fitness Score = 4.757057174374477
# Generation 34: Best Fitness Score = 4.757057174374477
# Generation 35: Best Fitness Score = 4.757057174374477
# Generation 36: Best Fitness Score = 4.757057174374477
# Generation 37: Best Fitness Score = 4.757057174374477
# Generation 38: Best Fitness Score = 4.757057174374477
# Generation 39: Best Fitness Score = 4.757057174374477
# Generation 40: Best Fitness Score = 4.757057174374477
# Generation 41: Best Fitness Score = 4.757057174374477
# Generation 42: Best Fitness Score = 4.757057174374477
# Generation 43: Best Fitness Score = 4.757057174374477
# Generation 44: Best Fitness Score = 4.757057174374477
# Generation 45: Best Fitness Score = 4.757057174374477
# Generation 46: Best Fitness Score = 4.757057174374477
# Generation 47: Best Fitness Score = 4.757057174374477
# Generation 48: Best Fitness Score = 4.757057174374477
# Generation 49: Best Fitness Score = 4.757057174374477
# Generation 50: Best Fitness Score = 4.757057174374477
# Generation 51: Best Fitness Score = 4.757057174374477
# Generation 52: Best Fitness Score = 4.757057174374477
# Generation 53: Best Fitness Score = 4.757057174374477
# Generation 54: Best Fitness Score = 4.757057174374477
# Generation 55: Best Fitness Score = 4.757057174374477
# Generation 56: Best Fitness Score = 4.757057174374477
# Generation 57: Best Fitness Score = 4.757057174374477
# Generation 58: Best Fitness Score = 4.757057174374477
# Generation 59: Best Fitness Score = 4.757057174374477
# Generation 60: Best Fitness Score = 4.757057174374477
# Generation 61: Best Fitness Score = 4.757057174374477
# Generation 62: Best Fitness Score = 4.757057174374477
# Generation 63: Best Fitness Score = 4.757057174374477
# Generation 64: Best Fitness Score = 4.757057174374477
# Generation 65: Best Fitness Score = 4.757057174374477
# Generation 66: Best Fitness Score = 4.757057174374477
# Generation 67: Best Fitness Score = 4.757057174374477
# Generation 68: Best Fitness Score = 4.757057174374477
# Generation 69: Best Fitness Score = 4.757057174374477
# Generation 70: Best Fitness Score = 4.757057174374477
# Generation 71: Best Fitness Score = 4.757057174374477
# Generation 72: Best Fitness Score = 4.757057174374477
# Generation 73: Best Fitness Score = 4.757057174374477
# Generation 74: Best Fitness Score = 4.757057174374477
# Generation 75: Best Fitness Score = 4.757057174374477
# Generation 76: Best Fitness Score = 4.757057174374477
# Generation 77: Best Fitness Score = 4.757057174374477
# Generation 78: Best Fitness Score = 4.757057174374477
# Generation 79: Best Fitness Score = 4.757057174374477
# Generation 80: Best Fitness Score = 4.757057174374477
# Generation 81: Best Fitness Score = 4.757057174374477
# Generation 82: Best Fitness Score = 4.757057174374477
# Generation 83: Best Fitness Score = 4.757057174374477
# Generation 84: Best Fitness Score = 4.757057174374477
# Generation 85: Best Fitness Score = 4.757057174374477
# Generation 86: Best Fitness Score = 4.757057174374477
# Generation 87: Best Fitness Score = 4.757057174374477
# Generation 88: Best Fitness Score = 4.757057174374477
# Generation 89: Best Fitness Score = 4.757057174374477
# Generation 90: Best Fitness Score = 4.757057174374477
# Generation 91: Best Fitness Score = 4.757057174374477
# Generation 92: Best Fitness Score = 4.757057174374477
# Generation 93: Best Fitness Score = 4.757057174374477
# Generation 94: Best Fitness Score = 4.757057174374477
# Generation 95: Best Fitness Score = 4.757057174374477
# Generation 96: Best Fitness Score = 4.757057174374477
# Generation 97: Best Fitness Score = 4.757057174374477
# Generation 98: Best Fitness Score = 4.757057174374477
# Generation 99: Best Fitness Score = 4.757057174374477
# Generation 100: Best Fitness Score = 4.757057174374477
# Generation 1: Best Fitness Score = 69.78983189506536
# Generation 2: Best Fitness Score = 85.84388849683019
# Generation 3: Best Fitness Score = 85.84388849683019
# Generation 4: Best Fitness Score = 87.58375234801557
# Generation 5: Best Fitness Score = 89.2236898884554
# Generation 6: Best Fitness Score = 90.58634799284964
# Generation 7: Best Fitness Score = 90.58634799284964
# Generation 8: Best Fitness Score = 91.45627991871731
# Generation 9: Best Fitness Score = 91.45627991871731
# Generation 10: Best Fitness Score = 92.32621184470445
# Generation 11: Best Fitness Score = 92.32621184470445
# Generation 12: Best Fitness Score = 92.32621184470445
# Generation 13: Best Fitness Score = 92.32621184470445
# Generation 14: Best Fitness Score = 92.32621184470445
# Generation 15: Best Fitness Score = 92.32621184470445
# Generation 16: Best Fitness Score = 92.32621184470445
# Generation 17: Best Fitness Score = 92.32621184470445
# Generation 18: Best Fitness Score = 92.32621184470445
# Generation 19: Best Fitness Score = 92.32621184470445
# Generation 20: Best Fitness Score = 92.32621184470445
# Generation 21: Best Fitness Score = 92.32621184470445
# Generation 22: Best Fitness Score = 92.32621184470445
# Generation 23: Best Fitness Score = 92.32621184470445
# Generation 24: Best Fitness Score = 92.32621184470445
# Generation 25: Best Fitness Score = 92.32621184470445
# Generation 26: Best Fitness Score = 92.32621184470445
# Generation 27: Best Fitness Score = 92.32621184470445
# Generation 28: Best Fitness Score = 92.32621184470445
# Generation 29: Best Fitness Score = 92.32621184470445
# Generation 30: Best Fitness Score = 92.32621184470445
# Generation 31: Best Fitness Score = 92.32621184470445
# Generation 32: Best Fitness Score = 92.32621184470445
# Generation 33: Best Fitness Score = 92.32621184470445
# Generation 34: Best Fitness Score = 92.32621184470445
# Generation 35: Best Fitness Score = 92.32621184470445
# Generation 36: Best Fitness Score = 92.32621184470445
# Generation 37: Best Fitness Score = 92.32621184470445
# Generation 38: Best Fitness Score = 92.32621184470445
# Generation 39: Best Fitness Score = 92.32621184470445
# Generation 40: Best Fitness Score = 92.32621184470445
# Generation 41: Best Fitness Score = 92.32621184470445
# Generation 42: Best Fitness Score = 92.32621184470445
# Generation 43: Best Fitness Score = 92.32621184470445
# Generation 44: Best Fitness Score = 92.32621184470445
# Generation 45: Best Fitness Score = 92.32621184470445
# Generation 46: Best Fitness Score = 92.32621184470445
# Generation 47: Best Fitness Score = 92.32621184470445
# Generation 48: Best Fitness Score = 92.32621184470445
# Generation 49: Best Fitness Score = 92.32621184470445
# Generation 50: Best Fitness Score = 92.32621184470445
# Generation 51: Best Fitness Score = 92.32621184470445
# Generation 52: Best Fitness Score = 92.32621184470445
# Generation 53: Best Fitness Score = 92.32621184470445
# Generation 54: Best Fitness Score = 92.32621184470445
# Generation 55: Best Fitness Score = 92.32621184470445
# Generation 56: Best Fitness Score = 92.32621184470445
# Generation 57: Best Fitness Score = 92.32621184470445
# Generation 58: Best Fitness Score = 92.32621184470445
# Generation 59: Best Fitness Score = 92.32621184470445
# Generation 60: Best Fitness Score = 92.32621184470445
# Generation 61: Best Fitness Score = 92.32621184470445
# Generation 62: Best Fitness Score = 92.32621184470445
# Generation 63: Best Fitness Score = 92.32621184470445
# Generation 64: Best Fitness Score = 92.32621184470445
# Generation 65: Best Fitness Score = 92.32621184470445
# Generation 66: Best Fitness Score = 92.32621184470445
# Generation 67: Best Fitness Score = 92.32621184470445
# Generation 68: Best Fitness Score = 92.32621184470445
# Generation 69: Best Fitness Score = 92.32621184470445
# Generation 70: Best Fitness Score = 92.32621184470445
# Generation 71: Best Fitness Score = 92.32621184470445
# Generation 72: Best Fitness Score = 92.32621184470445
# Generation 73: Best Fitness Score = 92.32621184470445
# Generation 74: Best Fitness Score = 92.32621184470445
# Generation 75: Best Fitness Score = 92.32621184470445
# Generation 76: Best Fitness Score = 92.32621184470445
# Generation 77: Best Fitness Score = 92.32621184470445
# Generation 78: Best Fitness Score = 92.32621184470445
# Generation 79: Best Fitness Score = 92.32621184470445
# Generation 80: Best Fitness Score = 92.32621184470445
# Generation 81: Best Fitness Score = 92.32621184470445
# Generation 82: Best Fitness Score = 92.32621184470445
# Generation 83: Best Fitness Score = 92.32621184470445
# Generation 84: Best Fitness Score = 92.32621184470445
# Generation 85: Best Fitness Score = 92.32621184470445
# Generation 86: Best Fitness Score = 92.32621184470445
# Generation 87: Best Fitness Score = 92.32621184470445
# Generation 88: Best Fitness Score = 92.32621184470445
# ...
# Generation 7: Best Fitness Score = 4.742442671833848
# Generation 8: Best Fitness Score = 4.742442671833848
# Generation 9: Best Fitness Score = 4.742442671833848
# Generation 10: Best Fitness Score = 4.742442671833848
# Generation 11: Best Fitness Score = 4.742442671833848
# Generation 12: Best Fitness Score = 4.742442671833848
# Generation 13: Best Fitness Score = 4.742442671833848
# Generation 14: Best Fitness Score = 4.742442671833848
# Generation 15: Best Fitness Score = 4.742442671833848
# Generation 16: Best Fitness Score = 4.742442671833848
# Generation 17: Best Fitness Score = 4.742442671833848
# Generation 18: Best Fitness Score = 4.742442671833848
# Generation 19: Best Fitness Score = 4.742442671833848
# Generation 20: Best Fitness Score = 4.742442671833848
# Generation 21: Best Fitness Score = 4.742442671833848
# Generation 22: Best Fitness Score = 4.742442671833848
# Generation 23: Best Fitness Score = 4.742442671833848
# Generation 24: Best Fitness Score = 4.742442671833848
# Generation 25: Best Fitness Score = 4.742442671833848
# Generation 26: Best Fitness Score = 4.742442671833848
# Generation 27: Best Fitness Score = 4.742442671833848
# Generation 28: Best Fitness Score = 4.742442671833848
# Generation 29: Best Fitness Score = 4.742442671833848
# Generation 30: Best Fitness Score = 4.742442671833848
# Generation 31: Best Fitness Score = 4.742442671833848
# Generation 32: Best Fitness Score = 4.742442671833848
# Generation 33: Best Fitness Score = 4.742442671833848
# Generation 34: Best Fitness Score = 4.742442671833848
# Generation 35: Best Fitness Score = 4.742442671833848
# Generation 36: Best Fitness Score = 4.742442671833848
# Generation 37: Best Fitness Score = 4.742442671833848
# Generation 38: Best Fitness Score = 4.742442671833848
# Generation 39: Best Fitness Score = 4.742442671833848
# Generation 40: Best Fitness Score = 4.742442671833848
# Generation 41: Best Fitness Score = 4.742442671833848
# Generation 42: Best Fitness Score = 4.742442671833848
# Generation 43: Best Fitness Score = 4.742442671833848
# Generation 44: Best Fitness Score = 4.742442671833848
# Generation 45: Best Fitness Score = 4.742442671833848
# Generation 46: Best Fitness Score = 4.742442671833848
# Generation 47: Best Fitness Score = 4.742442671833848
# Generation 48: Best Fitness Score = 4.742442671833848
# Generation 49: Best Fitness Score = 4.742442671833848
# Generation 50: Best Fitness Score = 4.742442671833848
# Generation 51: Best Fitness Score = 4.742442671833848
# Generation 52: Best Fitness Score = 4.742442671833848
# Generation 53: Best Fitness Score = 4.742442671833848
# Generation 54: Best Fitness Score = 4.742442671833848
# Generation 55: Best Fitness Score = 4.742442671833848
# Generation 56: Best Fitness Score = 4.742442671833848
# Generation 57: Best Fitness Score = 4.742442671833848
# Generation 58: Best Fitness Score = 4.742442671833848
# Generation 59: Best Fitness Score = 4.742442671833848
# Generation 60: Best Fitness Score = 4.742442671833848
# Generation 61: Best Fitness Score = 4.742442671833848
# Generation 62: Best Fitness Score = 4.742442671833848
# Generation 63: Best Fitness Score = 4.742442671833848
# Generation 64: Best Fitness Score = 4.742442671833848
# Generation 65: Best Fitness Score = 4.742442671833848
# Generation 66: Best Fitness Score = 4.742442671833848
# Generation 67: Best Fitness Score = 4.742442671833848
# Generation 68: Best Fitness Score = 4.742442671833848
# Generation 69: Best Fitness Score = 4.742442671833848
# Generation 70: Best Fitness Score = 4.742442671833848
# Generation 71: Best Fitness Score = 4.742442671833848
# Generation 72: Best Fitness Score = 4.742442671833848
# Generation 73: Best Fitness Score = 4.742442671833848
# Generation 74: Best Fitness Score = 4.742442671833848
# Generation 75: Best Fitness Score = 4.742442671833848
# Generation 76: Best Fitness Score = 4.742442671833848
# Generation 77: Best Fitness Score = 4.742442671833848
# Generation 78: Best Fitness Score = 4.742442671833848
# Generation 79: Best Fitness Score = 4.742442671833848
# Generation 80: Best Fitness Score = 4.742442671833848
# Generation 81: Best Fitness Score = 4.742442671833848
# Generation 82: Best Fitness Score = 4.742442671833848
# Generation 83: Best Fitness Score = 4.742442671833848
# Generation 84: Best Fitness Score = 4.742442671833848
# Generation 85: Best Fitness Score = 4.742442671833848
# Generation 86: Best Fitness Score = 4.742442671833848
# Generation 87: Best Fitness Score = 4.742442671833848
# Generation 88: Best Fitness Score = 4.742442671833848
# Generation 89: Best Fitness Score = 4.742442671833848
# Generation 90: Best Fitness Score = 4.742442671833848
# Generation 91: Best Fitness Score = 4.742442671833848
# Generation 92: Best Fitness Score = 4.742442671833848
# Generation 93: Best Fitness Score = 4.742442671833848
# Generation 94: Best Fitness Score = 4.742442671833848
# Generation 95: Best Fitness Score = 4.742442671833848
# Generation 96: Best Fitness Score = 4.742442671833848
# Generation 97: Best Fitness Score = 4.742442671833848
# Generation 98: Best Fitness Score = 4.742442671833848
# Generation 99: Best Fitness Score = 4.742442671833848
# Generation 100: Best Fitness Score = 4.742442671833848
# Generation 1: Best Fitness Score = 2.371225983159413
# Generation 2: Best Fitness Score = 2.371225983159413
# Generation 3: Best Fitness Score = 2.371225983159413
# Generation 4: Best Fitness Score = 2.371225983159413
# Generation 5: Best Fitness Score = 2.371225983159413
# Generation 6: Best Fitness Score = 2.371225983159413
# Generation 7: Best Fitness Score = 2.371225983159413
# Generation 8: Best Fitness Score = 2.371225983159413
# Generation 9: Best Fitness Score = 2.371225983159413
# Generation 10: Best Fitness Score = 2.371225983159413
# Generation 11: Best Fitness Score = 2.371225983159413
# Generation 12: Best Fitness Score = 2.371225983159413
# Generation 13: Best Fitness Score = 2.371225983159413
# Generation 14: Best Fitness Score = 2.371225983159413
# Generation 15: Best Fitness Score = 2.371225983159413
# Generation 16: Best Fitness Score = 2.371225983159413
# Generation 17: Best Fitness Score = 2.371225983159413
# Generation 18: Best Fitness Score = 2.371225983159413
# Generation 19: Best Fitness Score = 2.371225983159413
# Generation 20: Best Fitness Score = 2.371225983159413
# Generation 21: Best Fitness Score = 2.371225983159413
# Generation 22: Best Fitness Score = 2.371225983159413
# Generation 23: Best Fitness Score = 2.371225983159413
# Generation 24: Best Fitness Score = 2.371225983159413
# Generation 25: Best Fitness Score = 2.371225983159413
# Generation 26: Best Fitness Score = 2.371225983159413
# Generation 27: Best Fitness Score = 2.371225983159413
# Generation 28: Best Fitness Score = 2.371225983159413
# Generation 29: Best Fitness Score = 2.371225983159413
# Generation 30: Best Fitness Score = 2.371225983159413
# Generation 31: Best Fitness Score = 2.371225983159413
# Generation 32: Best Fitness Score = 2.371225983159413
# Generation 33: Best Fitness Score = 2.371225983159413
# Generation 34: Best Fitness Score = 2.371225983159413
# Generation 35: Best Fitness Score = 2.371225983159413
# Generation 36: Best Fitness Score = 2.371225983159413
# Generation 37: Best Fitness Score = 2.371225983159413
# Generation 38: Best Fitness Score = 2.371225983159413
# Generation 39: Best Fitness Score = 2.371225983159413
# Generation 40: Best Fitness Score = 2.371225983159413
# Generation 41: Best Fitness Score = 2.371225983159413
# Generation 42: Best Fitness Score = 2.371225983159413
# Generation 43: Best Fitness Score = 2.371225983159413
# Generation 44: Best Fitness Score = 2.371225983159413
# Generation 45: Best Fitness Score = 2.371225983159413
# Generation 46: Best Fitness Score = 2.371225983159413
# Generation 47: Best Fitness Score = 2.371225983159413
# Generation 48: Best Fitness Score = 2.371225983159413
# Generation 49: Best Fitness Score = 2.371225983159413
# Generation 50: Best Fitness Score = 2.371225983159413
# Generation 51: Best Fitness Score = 2.371225983159413
# Generation 52: Best Fitness Score = 2.371225983159413
# Generation 53: Best Fitness Score = 2.371225983159413
# Generation 54: Best Fitness Score = 2.371225983159413
# Generation 55: Best Fitness Score = 2.371225983159413
# Generation 56: Best Fitness Score = 2.371225983159413
# Generation 57: Best Fitness Score = 2.371225983159413
# Generation 58: Best Fitness Score = 2.371225983159413
# Generation 59: Best Fitness Score = 2.371225983159413
# Generation 60: Best Fitness Score = 2.371225983159413
# Generation 61: Best Fitness Score = 2.371225983159413
# Generation 62: Best Fitness Score = 2.371225983159413
# Generation 63: Best Fitness Score = 2.371225983159413
# Generation 64: Best Fitness Score = 2.371225983159413
# Generation 65: Best Fitness Score = 2.371225983159413
# Generation 66: Best Fitness Score = 2.371225983159413
# Generation 67: Best Fitness Score = 2.371225983159413
# Generation 68: Best Fitness Score = 2.371225983159413
# Generation 69: Best Fitness Score = 2.371225983159413
# Generation 70: Best Fitness Score = 2.371225983159413
# Generation 71: Best Fitness Score = 2.371225983159413
# Generation 72: Best Fitness Score = 2.371225983159413
# Generation 73: Best Fitness Score = 2.371225983159413
# Generation 74: Best Fitness Score = 2.371225983159413
# Generation 75: Best Fitness Score = 2.371225983159413
# Generation 76: Best Fitness Score = 2.371225983159413
# Generation 77: Best Fitness Score = 2.371225983159413
# Generation 78: Best Fitness Score = 2.371225983159413
# Generation 79: Best Fitness Score = 2.371225983159413
# Generation 80: Best Fitness Score = 2.371225983159413
# Generation 81: Best Fitness Score = 2.371225983159413
# Generation 82: Best Fitness Score = 2.371225983159413
# Generation 83: Best Fitness Score = 2.371225983159413
# Generation 84: Best Fitness Score = 2.371225983159413
# Generation 85: Best Fitness Score = 2.371225983159413
# Generation 86: Best Fitness Score = 2.371225983159413
# Generation 87: Best Fitness Score = 2.371225983159413
# Generation 88: Best Fitness Score = 2.371225983159413
# Generation 89: Best Fitness Score = 2.371225983159413
# Generation 90: Best Fitness Score = 2.371225983159413
# Generation 91: Best Fitness Score = 2.371225983159413
# Generation 92: Best Fitness Score = 2.371225983159413
# Generation 93: Best Fitness Score = 2.371225983159413
# Generation 94: Best Fitness Score = 2.371225983159413
# Generation 95: Best Fitness Score = 2.371225983159413
# Generation 96: Best Fitness Score = 2.371225983159413
# Generation 97: Best Fitness Score = 2.371225983159413
# Generation 98: Best Fitness Score = 2.371225983159413
# Generation 99: Best Fitness Score = 2.371225983159413
# Generation 100: Best Fitness Score = 2.371225983159413
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     BEV   258212.85  Electricity               9
# 1   Size S1, Distance D1  Diesel   295840.97          B20               9
# 2   Size S1, Distance D1     LNG   207700.92          LNG               9
# 3   Size S1, Distance D2  Diesel   854651.70          B20              26
# 4   Size S1, Distance D2     LNG   600024.87          LNG              26
# 5   Size S1, Distance D3  Diesel  1084750.23          B20              33
# 6   Size S1, Distance D3     LNG   761570.02          LNG              33
# 7   Size S1, Distance D4  Diesel   164356.10          B20               5
# 8   Size S1, Distance D4     LNG   115389.40          LNG               5
# 9   Size S2, Distance D1     BEV   345518.06  Electricity              10
# 10  Size S2, Distance D1  Diesel   352084.72          B20              10
# 11  Size S2, Distance D1     LNG   256988.62          LNG              10
# 12  Size S2, Distance D2  Diesel   492918.61          B20              14
# 13  Size S2, Distance D2     LNG   359784.07          LNG              14
# 14  Size S2, Distance D3  Diesel   281667.78          B20               8
# 15  Size S2, Distance D3     LNG   205590.90          LNG               8
# 16  Size S2, Distance D4  Diesel    70416.94          B20               2
# 17  Size S2, Distance D4     LNG    51397.72          LNG               2
# 18  Size S3, Distance D1     BEV   933543.28  Electricity              30
# 19  Size S3, Distance D1  Diesel   811840.31          B20              30
# 20  Size S3, Distance D1     LNG   637201.55          LNG              30
# 21  Size S3, Distance D2  Diesel   920085.68          B20              34
# 22  Size S3, Distance D2     LNG   722161.76          LNG              34
# 23  Size S3, Distance D3  Diesel   378858.81          B20              14
# 24  Size S3, Distance D3     LNG   297360.72          LNG              14
# 25  Size S3, Distance D4  Diesel    81184.03          B20               3
# 26  Size S3, Distance D4     LNG    63720.16          LNG               3
# 27  Size S4, Distance D1     BEV    44121.39  Electricity               1
# 28  Size S4, Distance D1  Diesel    40744.40          B20               1
# 29  Size S4, Distance D1     LNG    31574.93          LNG               1
# 30  Size S4, Distance D2  Diesel   285210.83          B20               7
# 31  Size S4, Distance D2     LNG   221024.52          LNG               7
# 32  Size S4, Distance D3  Diesel    81488.81          B20               2
# 33  Size S4, Distance D3     LNG    63149.86          LNG               2
# 34  Size S4, Distance D4  Diesel    40744.40          B20               1
# 35  Size S4, Distance D4     LNG    31574.93          LNG               1
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     BEV   258212.85  Electricity               9
# 1   Size S1, Distance D1  Diesel   295840.97          B20               9
# 2   Size S1, Distance D1     LNG   207700.92          LNG               9
# 3   Size S1, Distance D2  Diesel   854651.70          B20              26
# 4   Size S1, Distance D2     LNG   600024.87          LNG              26
# 5   Size S1, Distance D3  Diesel  1084750.23          B20              33
# 6   Size S1, Distance D3     LNG   761570.02          LNG              33
# 7   Size S1, Distance D4  Diesel   164356.10          B20               5
# 8   Size S1, Distance D4     LNG   115389.40          LNG               5
# 9   Size S2, Distance D1     BEV   345518.06  Electricity              10
# 10  Size S2, Distance D1  Diesel   352084.72          B20              10
# 11  Size S2, Distance D1     LNG   256988.62          LNG              10
# 12  Size S2, Distance D2  Diesel   492918.61          B20              14
# 13  Size S2, Distance D2     LNG   359784.07          LNG              14
# 14  Size S2, Distance D3  Diesel   281667.78          B20               8
# 15  Size S2, Distance D3     LNG   205590.90          LNG               8
# 16  Size S2, Distance D4  Diesel    70416.94          B20               2
# 17  Size S2, Distance D4     LNG    51397.72          LNG               2
# 18  Size S3, Distance D1     BEV   933543.28  Electricity              30
# 19  Size S3, Distance D1  Diesel   811840.31          B20              30
# 20  Size S3, Distance D1     LNG   637201.55          LNG              30
# 21  Size S3, Distance D2  Diesel   920085.68          B20              34
# 22  Size S3, Distance D2     LNG   722161.76          LNG              34
# 23  Size S3, Distance D3  Diesel   378858.81          B20              14
# 24  Size S3, Distance D3     LNG   297360.72          LNG              14
# 25  Size S3, Distance D4  Diesel    81184.03          B20               3
# 26  Size S3, Distance D4     LNG    63720.16          LNG               3
# 27  Size S4, Distance D1     BEV    44121.39  Electricity               1
# 28  Size S4, Distance D1  Diesel    40744.40          B20               1
# 29  Size S4, Distance D1     LNG    31574.93          LNG               1
# 30  Size S4, Distance D2  Diesel   285210.83          B20               7
# 31  Size S4, Distance D2     LNG   221024.52          LNG               7
# 32  Size S4, Distance D3  Diesel    81488.81          B20               2
# 33  Size S4, Distance D3     LNG    63149.86          LNG               2
# 34  Size S4, Distance D4  Diesel    40744.40          B20               1
# 35  Size S4, Distance D4     LNG    31574.93          LNG               1

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',  # Keeping as requested
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups

    def calculate_required_vehicles(self, vehicle: Dict) -> int:
        """Calculate required number of vehicles based on demand and yearly range"""
        return int(np.ceil(vehicle['demand'] / vehicle['yearly_range']))

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        
        for _ in range(population_size):
            solution = {
                v['vehicle_type']: random.randint(0, self.calculate_required_vehicles(v))
                for v in vehicles
            }
            population.append(solution)
        
        return population

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost (insurance + maintenance + fuel)
        """
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        # Fitness score combining TOPSIS, cost, and demand penalty
        return weighted_topsis + cost_score - demand_penalty

    def crossover(self, parent1: Dict, parent2: Dict) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions"""
        crossover_point = random.randint(1, len(parent1) - 1)
        child1 = {}
        child2 = {}

        for i, vehicle_type in enumerate(parent1.keys()):
            if i < crossover_point:
                child1[vehicle_type] = parent1[vehicle_type]
                child2[vehicle_type] = parent2[vehicle_type]
            else:
                child1[vehicle_type] = parent2[vehicle_type]
                child2[vehicle_type] = parent1[vehicle_type]

        return child1, child2

    def mutate(self, solution: Dict, mutation_rate: float = 0.1, size_distance: Tuple = None) -> Dict:
        """Mutate a solution by randomly adjusting the number of vehicles"""
        mutated_solution = solution.copy()

        # Ensure size_distance is passed, as it is needed for vehicle grouping
        if size_distance is None:
            raise ValueError("size_distance must be provided for mutation")

        vehicles = self.vehicles_by_size_distance[size_distance]
        
        for vehicle_type in mutated_solution.keys():
            if random.random() < mutation_rate:
                # Get the maximum allowed number of vehicles for this vehicle
                max_vehicles = self.calculate_required_vehicles(next(v for v in vehicles if v['vehicle_type'] == vehicle_type))
                new_vehicle_count = mutated_solution[vehicle_type] + random.randint(-1, 1)
                # Ensure vehicle count is within the feasible range
                mutated_solution[vehicle_type] = max(0, min(max_vehicles, new_vehicle_count))

        return mutated_solution

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for generation in range(generations):
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                              for solution in population]
            
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Track best fitness score
            print(f"Generation {generation + 1}: Best Fitness Score = {fitness_scores[0][1]}")

            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                
                # Pass size_distance during mutation
                child1 = self.mutate(child1, size_distance=size_distance)
                child2 = self.mutate(child2, size_distance=size_distance)
                
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Generation 1: Best Fitness Score = 22.56099210915077
# Generation 2: Best Fitness Score = 24.72876950374236
# Generation 3: Best Fitness Score = 28.40313207481445
# Generation 4: Best Fitness Score = 28.40313207481445
# Generation 5: Best Fitness Score = 28.40313207481445
# Generation 6: Best Fitness Score = 28.40313207481445
# Generation 7: Best Fitness Score = 28.40313207481445
# Generation 8: Best Fitness Score = 28.40313207481445
# Generation 9: Best Fitness Score = 28.40313207481445
# Generation 10: Best Fitness Score = 28.40313207481445
# Generation 11: Best Fitness Score = 28.40313207481445
# Generation 12: Best Fitness Score = 28.40313207481445
# Generation 13: Best Fitness Score = 28.40313207481445
# Generation 14: Best Fitness Score = 28.40313207481445
# Generation 15: Best Fitness Score = 28.40313207481445
# Generation 16: Best Fitness Score = 28.40313207481445
# Generation 17: Best Fitness Score = 28.40313207481445
# Generation 18: Best Fitness Score = 28.40313207481445
# Generation 19: Best Fitness Score = 28.40313207481445
# Generation 20: Best Fitness Score = 28.40313207481445
# Generation 21: Best Fitness Score = 28.40313207481445
# Generation 22: Best Fitness Score = 28.40313207481445
# Generation 23: Best Fitness Score = 28.40313207481445
# Generation 24: Best Fitness Score = 28.40313207481445
# Generation 25: Best Fitness Score = 28.40313207481445
# Generation 26: Best Fitness Score = 28.40313207481445
# Generation 27: Best Fitness Score = 28.40313207481445
# Generation 28: Best Fitness Score = 28.40313207481445
# Generation 29: Best Fitness Score = 28.40313207481445
# Generation 30: Best Fitness Score = 28.40313207481445
# Generation 31: Best Fitness Score = 28.40313207481445
# Generation 32: Best Fitness Score = 28.40313207481445
# Generation 33: Best Fitness Score = 28.40313207481445
# Generation 34: Best Fitness Score = 28.40313207481445
# Generation 35: Best Fitness Score = 28.40313207481445
# Generation 36: Best Fitness Score = 28.40313207481445
# Generation 37: Best Fitness Score = 28.40313207481445
# Generation 38: Best Fitness Score = 28.40313207481445
# Generation 39: Best Fitness Score = 28.40313207481445
# Generation 40: Best Fitness Score = 28.40313207481445
# Generation 41: Best Fitness Score = 28.40313207481445
# Generation 42: Best Fitness Score = 28.40313207481445
# Generation 43: Best Fitness Score = 28.40313207481445
# Generation 44: Best Fitness Score = 28.40313207481445
# Generation 45: Best Fitness Score = 28.40313207481445
# Generation 46: Best Fitness Score = 28.40313207481445
# Generation 47: Best Fitness Score = 28.40313207481445
# Generation 48: Best Fitness Score = 28.40313207481445
# Generation 49: Best Fitness Score = 28.40313207481445
# Generation 50: Best Fitness Score = 28.40313207481445
# Generation 51: Best Fitness Score = 28.40313207481445
# Generation 52: Best Fitness Score = 28.40313207481445
# Generation 53: Best Fitness Score = 28.40313207481445
# Generation 54: Best Fitness Score = 28.40313207481445
# Generation 55: Best Fitness Score = 28.40313207481445
# Generation 56: Best Fitness Score = 28.40313207481445
# Generation 57: Best Fitness Score = 28.40313207481445
# Generation 58: Best Fitness Score = 28.40313207481445
# Generation 59: Best Fitness Score = 28.40313207481445
# Generation 60: Best Fitness Score = 28.40313207481445
# Generation 61: Best Fitness Score = 28.40313207481445
# Generation 62: Best Fitness Score = 28.40313207481445
# Generation 63: Best Fitness Score = 28.40313207481445
# Generation 64: Best Fitness Score = 28.40313207481445
# Generation 65: Best Fitness Score = 28.40313207481445
# Generation 66: Best Fitness Score = 28.40313207481445
# Generation 67: Best Fitness Score = 28.40313207481445
# Generation 68: Best Fitness Score = 28.40313207481445
# Generation 69: Best Fitness Score = 28.40313207481445
# Generation 70: Best Fitness Score = 28.40313207481445
# Generation 71: Best Fitness Score = 28.40313207481445
# Generation 72: Best Fitness Score = 28.40313207481445
# Generation 73: Best Fitness Score = 28.40313207481445
# Generation 74: Best Fitness Score = 28.40313207481445
# Generation 75: Best Fitness Score = 28.40313207481445
# Generation 76: Best Fitness Score = 28.40313207481445
# Generation 77: Best Fitness Score = 28.40313207481445
# Generation 78: Best Fitness Score = 28.40313207481445
# Generation 79: Best Fitness Score = 28.40313207481445
# Generation 80: Best Fitness Score = 28.40313207481445
# Generation 81: Best Fitness Score = 28.40313207481445
# Generation 82: Best Fitness Score = 28.40313207481445
# Generation 83: Best Fitness Score = 28.40313207481445
# Generation 84: Best Fitness Score = 28.40313207481445
# Generation 85: Best Fitness Score = 28.40313207481445
# Generation 86: Best Fitness Score = 28.40313207481445
# Generation 87: Best Fitness Score = 28.40313207481445
# Generation 88: Best Fitness Score = 28.40313207481445
# Generation 89: Best Fitness Score = 28.40313207481445
# Generation 90: Best Fitness Score = 28.40313207481445
# Generation 91: Best Fitness Score = 28.40313207481445
# Generation 92: Best Fitness Score = 28.40313207481445
# Generation 93: Best Fitness Score = 28.40313207481445
# Generation 94: Best Fitness Score = 28.40313207481445
# Generation 95: Best Fitness Score = 28.40313207481445
# Generation 96: Best Fitness Score = 28.40313207481445
# Generation 97: Best Fitness Score = 28.40313207481445
# Generation 98: Best Fitness Score = 28.40313207481445
# Generation 99: Best Fitness Score = 28.40313207481445
# Generation 100: Best Fitness Score = 28.40313207481445
# Generation 1: Best Fitness Score = 56.45209963485786
# Generation 2: Best Fitness Score = 57.32453718133147
# Generation 3: Best Fitness Score = 61.84294939927978
# Generation 4: Best Fitness Score = 61.84294939927978
# Generation 5: Best Fitness Score = 61.84294939927978
# Generation 6: Best Fitness Score = 61.84294939927978
# Generation 7: Best Fitness Score = 61.84294939927978
# Generation 8: Best Fitness Score = 61.84294939927978
# Generation 9: Best Fitness Score = 61.84294939927978
# Generation 10: Best Fitness Score = 61.84294939927978
# Generation 11: Best Fitness Score = 61.84294939927978
# Generation 12: Best Fitness Score = 61.84294939927978
# Generation 13: Best Fitness Score = 61.84294939927978
# Generation 14: Best Fitness Score = 61.84294939927978
# Generation 15: Best Fitness Score = 61.84294939927978
# Generation 16: Best Fitness Score = 61.84294939927978
# Generation 17: Best Fitness Score = 61.84294939927978
# Generation 18: Best Fitness Score = 61.84294939927978
# Generation 19: Best Fitness Score = 61.84294939927978
# Generation 20: Best Fitness Score = 61.84294939927978
# Generation 21: Best Fitness Score = 61.84294939927978
# Generation 22: Best Fitness Score = 61.84294939927978
# Generation 23: Best Fitness Score = 61.84294939927978
# Generation 24: Best Fitness Score = 61.84294939927978
# Generation 25: Best Fitness Score = 61.84294939927978
# Generation 26: Best Fitness Score = 61.84294939927978
# Generation 27: Best Fitness Score = 61.84294939927978
# Generation 28: Best Fitness Score = 61.84294939927978
# Generation 29: Best Fitness Score = 61.84294939927978
# Generation 30: Best Fitness Score = 61.84294939927978
# Generation 31: Best Fitness Score = 61.84294939927978
# Generation 32: Best Fitness Score = 61.84294939927978
# Generation 33: Best Fitness Score = 61.84294939927978
# Generation 34: Best Fitness Score = 61.84294939927978
# Generation 35: Best Fitness Score = 61.84294939927978
# Generation 36: Best Fitness Score = 61.84294939927978
# Generation 37: Best Fitness Score = 61.84294939927978
# Generation 38: Best Fitness Score = 61.84294939927978
# Generation 39: Best Fitness Score = 61.84294939927978
# Generation 40: Best Fitness Score = 61.84294939927978
# Generation 41: Best Fitness Score = 61.84294939927978
# Generation 42: Best Fitness Score = 61.84294939927978
# Generation 43: Best Fitness Score = 61.84294939927978
# Generation 44: Best Fitness Score = 61.84294939927978
# Generation 45: Best Fitness Score = 61.84294939927978
# Generation 46: Best Fitness Score = 61.84294939927978
# Generation 47: Best Fitness Score = 61.84294939927978
# Generation 48: Best Fitness Score = 61.84294939927978
# Generation 49: Best Fitness Score = 61.84294939927978
# Generation 50: Best Fitness Score = 61.84294939927978
# Generation 51: Best Fitness Score = 61.84294939927978
# Generation 52: Best Fitness Score = 61.84294939927978
# Generation 53: Best Fitness Score = 61.84294939927978
# Generation 54: Best Fitness Score = 61.84294939927978
# Generation 55: Best Fitness Score = 61.84294939927978
# Generation 56: Best Fitness Score = 61.84294939927978
# Generation 57: Best Fitness Score = 61.84294939927978
# Generation 58: Best Fitness Score = 61.84294939927978
# Generation 59: Best Fitness Score = 61.84294939927978
# Generation 60: Best Fitness Score = 61.84294939927978
# Generation 61: Best Fitness Score = 61.84294939927978
# Generation 62: Best Fitness Score = 61.84294939927978
# Generation 63: Best Fitness Score = 61.84294939927978
# Generation 64: Best Fitness Score = 61.84294939927978
# Generation 65: Best Fitness Score = 61.84294939927978
# Generation 66: Best Fitness Score = 61.84294939927978
# Generation 67: Best Fitness Score = 61.84294939927978
# Generation 68: Best Fitness Score = 61.84294939927978
# Generation 69: Best Fitness Score = 61.84294939927978
# Generation 70: Best Fitness Score = 61.84294939927978
# Generation 71: Best Fitness Score = 61.84294939927978
# Generation 72: Best Fitness Score = 61.84294939927978
# Generation 73: Best Fitness Score = 61.84294939927978
# Generation 74: Best Fitness Score = 61.84294939927978
# Generation 75: Best Fitness Score = 61.84294939927978
# Generation 76: Best Fitness Score = 61.84294939927978
# Generation 77: Best Fitness Score = 61.84294939927978
# Generation 78: Best Fitness Score = 61.84294939927978
# Generation 79: Best Fitness Score = 61.84294939927978
# Generation 80: Best Fitness Score = 61.84294939927978
# Generation 81: Best Fitness Score = 61.84294939927978
# Generation 82: Best Fitness Score = 61.84294939927978
# Generation 83: Best Fitness Score = 61.84294939927978
# Generation 84: Best Fitness Score = 61.84294939927978
# Generation 85: Best Fitness Score = 61.84294939927978
# Generation 86: Best Fitness Score = 61.84294939927978
# Generation 87: Best Fitness Score = 61.84294939927978
# Generation 88: Best Fitness Score = 61.84294939927978
# Generation 89: Best Fitness Score = 61.84294939927978
# Generation 90: Best Fitness Score = 61.84294939927978
# Generation 91: Best Fitness Score = 61.84294939927978
# Generation 92: Best Fitness Score = 61.84294939927978
# Generation 93: Best Fitness Score = 61.84294939927978
# Generation 94: Best Fitness Score = 61.84294939927978
# Generation 95: Best Fitness Score = 61.84294939927978
# Generation 96: Best Fitness Score = 61.84294939927978
# Generation 97: Best Fitness Score = 61.84294939927978
# Generation 98: Best Fitness Score = 61.84294939927978
# Generation 99: Best Fitness Score = 61.84294939927978
# Generation 100: Best Fitness Score = 61.84294939927978
# Generation 1: Best Fitness Score = 75.00322389234947
# Generation 2: Best Fitness Score = 75.00322389234947
# Generation 3: Best Fitness Score = 75.87566144180704
# Generation 4: Best Fitness Score = 76.7480989914698
# Generation 5: Best Fitness Score = 76.7480989914698
# Generation 6: Best Fitness Score = 76.7480989914698
# Generation 7: Best Fitness Score = 76.7480989914698
# Generation 8: Best Fitness Score = 76.7480989914698
# Generation 9: Best Fitness Score = 77.62053654132582
# Generation 10: Best Fitness Score = 77.62053654132582
# Generation 11: Best Fitness Score = 77.62053654132582
# Generation 12: Best Fitness Score = 77.62053654132582
# Generation 13: Best Fitness Score = 77.62053654132582
# Generation 14: Best Fitness Score = 78.49297409136412
# Generation 15: Best Fitness Score = 78.49297409136412
# Generation 16: Best Fitness Score = 78.49297409136412
# Generation 17: Best Fitness Score = 78.49297409136412
# Generation 18: Best Fitness Score = 78.49297409136412
# Generation 19: Best Fitness Score = 78.49297409136412
# Generation 20: Best Fitness Score = 78.49297409136412
# Generation 21: Best Fitness Score = 78.49297409136412
# Generation 22: Best Fitness Score = 78.49297409136412
# Generation 23: Best Fitness Score = 78.49297409136412
# Generation 24: Best Fitness Score = 78.49297409136412
# Generation 25: Best Fitness Score = 78.49297409136412
# Generation 26: Best Fitness Score = 78.49297409136412
# Generation 27: Best Fitness Score = 78.49297409136412
# Generation 28: Best Fitness Score = 78.49297409136412
# Generation 29: Best Fitness Score = 78.49297409136412
# Generation 30: Best Fitness Score = 78.49297409136412
# Generation 31: Best Fitness Score = 78.49297409136412
# Generation 32: Best Fitness Score = 78.49297409136412
# Generation 33: Best Fitness Score = 78.49297409136412
# Generation 34: Best Fitness Score = 78.49297409136412
# Generation 35: Best Fitness Score = 78.49297409136412
# Generation 36: Best Fitness Score = 78.49297409136412
# Generation 37: Best Fitness Score = 78.49297409136412
# Generation 38: Best Fitness Score = 78.49297409136412
# Generation 39: Best Fitness Score = 78.49297409136412
# Generation 40: Best Fitness Score = 78.49297409136412
# Generation 41: Best Fitness Score = 78.49297409136412
# Generation 42: Best Fitness Score = 78.49297409136412
# Generation 43: Best Fitness Score = 78.49297409136412
# Generation 44: Best Fitness Score = 78.49297409136412
# Generation 45: Best Fitness Score = 78.49297409136412
# Generation 46: Best Fitness Score = 78.49297409136412
# Generation 47: Best Fitness Score = 78.49297409136412
# Generation 48: Best Fitness Score = 78.49297409136412
# Generation 49: Best Fitness Score = 78.49297409136412
# Generation 50: Best Fitness Score = 78.49297409136412
# Generation 51: Best Fitness Score = 78.49297409136412
# Generation 52: Best Fitness Score = 78.49297409136412
# Generation 53: Best Fitness Score = 78.49297409136412
# Generation 54: Best Fitness Score = 78.49297409136412
# Generation 55: Best Fitness Score = 78.49297409136412
# Generation 56: Best Fitness Score = 78.49297409136412
# Generation 57: Best Fitness Score = 78.49297409136412
# Generation 58: Best Fitness Score = 78.49297409136412
# Generation 59: Best Fitness Score = 78.49297409136412
# Generation 60: Best Fitness Score = 78.49297409136412
# Generation 61: Best Fitness Score = 78.49297409136412
# Generation 62: Best Fitness Score = 78.49297409136412
# Generation 63: Best Fitness Score = 78.49297409136412
# Generation 64: Best Fitness Score = 78.49297409136412
# Generation 65: Best Fitness Score = 78.49297409136412
# Generation 66: Best Fitness Score = 78.49297409136412
# Generation 67: Best Fitness Score = 78.49297409136412
# Generation 68: Best Fitness Score = 78.49297409136412
# Generation 69: Best Fitness Score = 78.49297409136412
# Generation 70: Best Fitness Score = 78.49297409136412
# Generation 71: Best Fitness Score = 78.49297409136412
# Generation 72: Best Fitness Score = 78.49297409136412
# Generation 73: Best Fitness Score = 78.49297409136412
# Generation 74: Best Fitness Score = 78.49297409136412
# Generation 75: Best Fitness Score = 78.49297409136412
# Generation 76: Best Fitness Score = 78.49297409136412
# Generation 77: Best Fitness Score = 78.49297409136412
# Generation 78: Best Fitness Score = 78.49297409136412
# Generation 79: Best Fitness Score = 78.49297409136412
# Generation 80: Best Fitness Score = 78.49297409136412
# Generation 81: Best Fitness Score = 78.49297409136412
# Generation 82: Best Fitness Score = 78.49297409136412
# Generation 83: Best Fitness Score = 78.49297409136412
# Generation 84: Best Fitness Score = 78.49297409136412
# Generation 85: Best Fitness Score = 78.49297409136412
# Generation 86: Best Fitness Score = 78.49297409136412
# Generation 87: Best Fitness Score = 78.49297409136412
# Generation 88: Best Fitness Score = 78.49297409136412
# Generation 89: Best Fitness Score = 78.49297409136412
# Generation 90: Best Fitness Score = 78.49297409136412
# Generation 91: Best Fitness Score = 78.49297409136412
# Generation 92: Best Fitness Score = 78.49297409136412
# Generation 93: Best Fitness Score = 78.49297409136412
# Generation 94: Best Fitness Score = 78.49297409136412
# Generation 95: Best Fitness Score = 78.49297409136412
# Generation 96: Best Fitness Score = 78.49297409136412
# Generation 97: Best Fitness Score = 78.49297409136412
# Generation 98: Best Fitness Score = 78.49297409136412
# Generation 99: Best Fitness Score = 78.49297409136412
# Generation 100: Best Fitness Score = 78.49297409136412
# Generation 1: Best Fitness Score = 11.020439076503015
# Generation 2: Best Fitness Score = 11.892876405276787
# Generation 3: Best Fitness Score = 11.892876405276787
# Generation 4: Best Fitness Score = 11.892876405276787
# Generation 5: Best Fitness Score = 11.892876405276787
# Generation 6: Best Fitness Score = 11.892876405276787
# Generation 7: Best Fitness Score = 11.892876405276787
# Generation 8: Best Fitness Score = 11.892876405276787
# Generation 9: Best Fitness Score = 11.892876405276787
# Generation 10: Best Fitness Score = 11.892876405276787
# Generation 11: Best Fitness Score = 11.892876405276787
# Generation 12: Best Fitness Score = 11.892876405276787
# Generation 13: Best Fitness Score = 11.892876405276787
# Generation 14: Best Fitness Score = 11.892876405276787
# Generation 15: Best Fitness Score = 11.892876405276787
# Generation 16: Best Fitness Score = 11.892876405276787
# Generation 17: Best Fitness Score = 11.892876405276787
# Generation 18: Best Fitness Score = 11.892876405276787
# Generation 19: Best Fitness Score = 11.892876405276787
# Generation 20: Best Fitness Score = 11.892876405276787
# Generation 21: Best Fitness Score = 11.892876405276787
# Generation 22: Best Fitness Score = 11.892876405276787
# Generation 23: Best Fitness Score = 11.892876405276787
# Generation 24: Best Fitness Score = 11.892876405276787
# Generation 25: Best Fitness Score = 11.892876405276787
# Generation 26: Best Fitness Score = 11.892876405276787
# Generation 27: Best Fitness Score = 11.892876405276787
# Generation 28: Best Fitness Score = 11.892876405276787
# Generation 29: Best Fitness Score = 11.892876405276787
# Generation 30: Best Fitness Score = 11.892876405276787
# Generation 31: Best Fitness Score = 11.892876405276787
# Generation 32: Best Fitness Score = 11.892876405276787
# Generation 33: Best Fitness Score = 11.892876405276787
# Generation 34: Best Fitness Score = 11.892876405276787
# Generation 35: Best Fitness Score = 11.892876405276787
# Generation 36: Best Fitness Score = 11.892876405276787
# Generation 37: Best Fitness Score = 11.892876405276787
# Generation 38: Best Fitness Score = 11.892876405276787
# Generation 39: Best Fitness Score = 11.892876405276787
# Generation 40: Best Fitness Score = 11.892876405276787
# Generation 41: Best Fitness Score = 11.892876405276787
# Generation 42: Best Fitness Score = 11.892876405276787
# Generation 43: Best Fitness Score = 11.892876405276787
# Generation 44: Best Fitness Score = 11.892876405276787
# Generation 45: Best Fitness Score = 11.892876405276787
# Generation 46: Best Fitness Score = 11.892876405276787
# Generation 47: Best Fitness Score = 11.892876405276787
# Generation 48: Best Fitness Score = 11.892876405276787
# Generation 49: Best Fitness Score = 11.892876405276787
# Generation 50: Best Fitness Score = 11.892876405276787
# Generation 51: Best Fitness Score = 11.892876405276787
# Generation 52: Best Fitness Score = 11.892876405276787
# Generation 53: Best Fitness Score = 11.892876405276787
# Generation 54: Best Fitness Score = 11.892876405276787
# Generation 55: Best Fitness Score = 11.892876405276787
# Generation 56: Best Fitness Score = 11.892876405276787
# Generation 57: Best Fitness Score = 11.892876405276787
# Generation 58: Best Fitness Score = 11.892876405276787
# Generation 59: Best Fitness Score = 11.892876405276787
# Generation 60: Best Fitness Score = 11.892876405276787
# Generation 61: Best Fitness Score = 11.892876405276787
# Generation 62: Best Fitness Score = 11.892876405276787
# Generation 63: Best Fitness Score = 11.892876405276787
# Generation 64: Best Fitness Score = 11.892876405276787
# Generation 65: Best Fitness Score = 11.892876405276787
# Generation 66: Best Fitness Score = 11.892876405276787
# Generation 67: Best Fitness Score = 11.892876405276787
# Generation 68: Best Fitness Score = 11.892876405276787
# Generation 69: Best Fitness Score = 11.892876405276787
# Generation 70: Best Fitness Score = 11.892876405276787
# Generation 71: Best Fitness Score = 11.892876405276787
# Generation 72: Best Fitness Score = 11.892876405276787
# Generation 73: Best Fitness Score = 11.892876405276787
# Generation 74: Best Fitness Score = 11.892876405276787
# Generation 75: Best Fitness Score = 11.892876405276787
# Generation 76: Best Fitness Score = 11.892876405276787
# Generation 77: Best Fitness Score = 11.892876405276787
# Generation 78: Best Fitness Score = 11.892876405276787
# Generation 79: Best Fitness Score = 11.892876405276787
# Generation 80: Best Fitness Score = 11.892876405276787
# Generation 81: Best Fitness Score = 11.892876405276787
# Generation 82: Best Fitness Score = 11.892876405276787
# Generation 83: Best Fitness Score = 11.892876405276787
# Generation 84: Best Fitness Score = 11.892876405276787
# Generation 85: Best Fitness Score = 11.892876405276787
# Generation 86: Best Fitness Score = 11.892876405276787
# Generation 87: Best Fitness Score = 11.892876405276787
# Generation 88: Best Fitness Score = 11.892876405276787
# Generation 89: Best Fitness Score = 11.892876405276787
# Generation 90: Best Fitness Score = 11.892876405276787
# Generation 91: Best Fitness Score = 11.892876405276787
# Generation 92: Best Fitness Score = 11.892876405276787
# Generation 93: Best Fitness Score = 11.892876405276787
# Generation 94: Best Fitness Score = 11.892876405276787
# Generation 95: Best Fitness Score = 11.892876405276787
# Generation 96: Best Fitness Score = 11.892876405276787
# Generation 97: Best Fitness Score = 11.892876405276787
# Generation 98: Best Fitness Score = 11.892876405276787
# Generation 99: Best Fitness Score = 11.892876405276787
# Generation 100: Best Fitness Score = 11.892876405276787
# Generation 1: Best Fitness Score = 29.5004326005135
# Generation 2: Best Fitness Score = 29.5004326005135
# Generation 3: Best Fitness Score = 29.5004326005135
# Generation 4: Best Fitness Score = 31.21442215080922
# Generation 5: Best Fitness Score = 31.21442215080922
# Generation 6: Best Fitness Score = 31.21442215080922
# Generation 7: Best Fitness Score = 31.21442215080922
# Generation 8: Best Fitness Score = 31.21442215080922
# Generation 9: Best Fitness Score = 31.21442215080922
# Generation 10: Best Fitness Score = 31.21442215080922
# Generation 11: Best Fitness Score = 31.21442215080922
# Generation 12: Best Fitness Score = 31.21442215080922
# Generation 13: Best Fitness Score = 31.21442215080922
# Generation 14: Best Fitness Score = 31.21442215080922
# Generation 15: Best Fitness Score = 31.21442215080922
# Generation 16: Best Fitness Score = 31.21442215080922
# Generation 17: Best Fitness Score = 31.21442215080922
# Generation 18: Best Fitness Score = 31.21442215080922
# Generation 19: Best Fitness Score = 31.21442215080922
# Generation 20: Best Fitness Score = 31.21442215080922
# Generation 21: Best Fitness Score = 31.21442215080922
# Generation 22: Best Fitness Score = 31.21442215080922
# Generation 23: Best Fitness Score = 31.21442215080922
# Generation 24: Best Fitness Score = 31.21442215080922
# Generation 25: Best Fitness Score = 31.21442215080922
# Generation 26: Best Fitness Score = 31.21442215080922
# Generation 27: Best Fitness Score = 31.21442215080922
# Generation 28: Best Fitness Score = 31.21442215080922
# Generation 29: Best Fitness Score = 31.21442215080922
# Generation 30: Best Fitness Score = 31.21442215080922
# Generation 31: Best Fitness Score = 31.21442215080922
# Generation 32: Best Fitness Score = 31.21442215080922
# Generation 33: Best Fitness Score = 31.21442215080922
# Generation 34: Best Fitness Score = 31.21442215080922
# Generation 35: Best Fitness Score = 31.21442215080922
# Generation 36: Best Fitness Score = 31.21442215080922
# Generation 37: Best Fitness Score = 31.21442215080922
# Generation 38: Best Fitness Score = 31.21442215080922
# Generation 39: Best Fitness Score = 31.21442215080922
# Generation 40: Best Fitness Score = 31.21442215080922
# Generation 41: Best Fitness Score = 31.21442215080922
# Generation 42: Best Fitness Score = 31.21442215080922
# Generation 43: Best Fitness Score = 31.21442215080922
# Generation 44: Best Fitness Score = 31.21442215080922
# Generation 45: Best Fitness Score = 31.21442215080922
# Generation 46: Best Fitness Score = 31.21442215080922
# Generation 47: Best Fitness Score = 31.21442215080922
# Generation 48: Best Fitness Score = 31.21442215080922
# Generation 49: Best Fitness Score = 31.21442215080922
# Generation 50: Best Fitness Score = 31.21442215080922
# Generation 51: Best Fitness Score = 31.21442215080922
# Generation 52: Best Fitness Score = 31.21442215080922
# Generation 53: Best Fitness Score = 31.21442215080922
# Generation 54: Best Fitness Score = 31.21442215080922
# Generation 55: Best Fitness Score = 31.21442215080922
# Generation 56: Best Fitness Score = 31.21442215080922
# Generation 57: Best Fitness Score = 31.21442215080922
# Generation 58: Best Fitness Score = 31.21442215080922
# Generation 59: Best Fitness Score = 31.21442215080922
# Generation 60: Best Fitness Score = 31.21442215080922
# Generation 61: Best Fitness Score = 31.21442215080922
# Generation 62: Best Fitness Score = 31.21442215080922
# Generation 63: Best Fitness Score = 31.21442215080922
# Generation 64: Best Fitness Score = 31.21442215080922
# Generation 65: Best Fitness Score = 31.21442215080922
# Generation 66: Best Fitness Score = 31.21442215080922
# Generation 67: Best Fitness Score = 31.21442215080922
# Generation 68: Best Fitness Score = 31.21442215080922
# Generation 69: Best Fitness Score = 31.21442215080922
# Generation 70: Best Fitness Score = 31.21442215080922
# Generation 71: Best Fitness Score = 31.21442215080922
# Generation 72: Best Fitness Score = 31.21442215080922
# Generation 73: Best Fitness Score = 31.21442215080922
# Generation 74: Best Fitness Score = 31.21442215080922
# Generation 75: Best Fitness Score = 31.21442215080922
# Generation 76: Best Fitness Score = 31.21442215080922
# Generation 77: Best Fitness Score = 31.21442215080922
# Generation 78: Best Fitness Score = 31.21442215080922
# Generation 79: Best Fitness Score = 31.21442215080922
# Generation 80: Best Fitness Score = 31.21442215080922
# Generation 81: Best Fitness Score = 31.21442215080922
# Generation 82: Best Fitness Score = 31.21442215080922
# Generation 83: Best Fitness Score = 31.21442215080922
# Generation 84: Best Fitness Score = 31.21442215080922
# Generation 85: Best Fitness Score = 31.21442215080922
# Generation 86: Best Fitness Score = 31.21442215080922
# Generation 87: Best Fitness Score = 31.21442215080922
# Generation 88: Best Fitness Score = 31.21442215080922
# Generation 89: Best Fitness Score = 31.21442215080922
# Generation 90: Best Fitness Score = 31.21442215080922
# Generation 91: Best Fitness Score = 31.21442215080922
# Generation 92: Best Fitness Score = 31.21442215080922
# Generation 93: Best Fitness Score = 31.21442215080922
# Generation 94: Best Fitness Score = 31.21442215080922
# Generation 95: Best Fitness Score = 31.21442215080922
# Generation 96: Best Fitness Score = 31.21442215080922
# Generation 97: Best Fitness Score = 31.21442215080922
# Generation 98: Best Fitness Score = 31.21442215080922
# Generation 99: Best Fitness Score = 31.21442215080922
# Generation 100: Best Fitness Score = 31.21442215080922
# Generation 1: Best Fitness Score = 33.29937527762527
# Generation 2: Best Fitness Score = 33.29937527762527
# Generation 3: Best Fitness Score = 33.29937527762527
# Generation 4: Best Fitness Score = 33.29937527762527
# Generation 5: Best Fitness Score = 33.29937527762527
# Generation 6: Best Fitness Score = 33.29937527762527
# Generation 7: Best Fitness Score = 33.29937527762527
# Generation 8: Best Fitness Score = 33.29937527762527
# Generation 9: Best Fitness Score = 33.29937527762527
# Generation 10: Best Fitness Score = 33.29937527762527
# Generation 11: Best Fitness Score = 33.29937527762527
# Generation 12: Best Fitness Score = 33.29937527762527
# Generation 13: Best Fitness Score = 33.29937527762527
# Generation 14: Best Fitness Score = 33.29937527762527
# Generation 15: Best Fitness Score = 33.29937527762527
# Generation 16: Best Fitness Score = 33.29937527762527
# Generation 17: Best Fitness Score = 33.29937527762527
# Generation 18: Best Fitness Score = 33.29937527762527
# Generation 19: Best Fitness Score = 33.29937527762527
# Generation 20: Best Fitness Score = 33.29937527762527
# Generation 21: Best Fitness Score = 33.29937527762527
# Generation 22: Best Fitness Score = 33.29937527762527
# Generation 23: Best Fitness Score = 33.29937527762527
# Generation 24: Best Fitness Score = 33.29937527762527
# Generation 25: Best Fitness Score = 33.29937527762527
# Generation 26: Best Fitness Score = 33.29937527762527
# Generation 27: Best Fitness Score = 33.29937527762527
# Generation 28: Best Fitness Score = 33.29937527762527
# Generation 29: Best Fitness Score = 33.29937527762527
# Generation 30: Best Fitness Score = 33.29937527762527
# Generation 31: Best Fitness Score = 33.29937527762527
# Generation 32: Best Fitness Score = 33.29937527762527
# Generation 33: Best Fitness Score = 33.29937527762527
# Generation 34: Best Fitness Score = 33.29937527762527
# Generation 35: Best Fitness Score = 33.29937527762527
# Generation 36: Best Fitness Score = 33.29937527762527
# Generation 37: Best Fitness Score = 33.29937527762527
# Generation 38: Best Fitness Score = 33.29937527762527
# Generation 39: Best Fitness Score = 33.29937527762527
# Generation 40: Best Fitness Score = 33.29937527762527
# Generation 41: Best Fitness Score = 33.29937527762527
# Generation 42: Best Fitness Score = 33.29937527762527
# Generation 43: Best Fitness Score = 33.29937527762527
# Generation 44: Best Fitness Score = 33.29937527762527
# Generation 45: Best Fitness Score = 33.29937527762527
# Generation 46: Best Fitness Score = 33.29937527762527
# Generation 47: Best Fitness Score = 33.29937527762527
# Generation 48: Best Fitness Score = 33.29937527762527
# Generation 49: Best Fitness Score = 33.29937527762527
# Generation 50: Best Fitness Score = 33.29937527762527
# Generation 51: Best Fitness Score = 33.29937527762527
# Generation 52: Best Fitness Score = 33.29937527762527
# Generation 53: Best Fitness Score = 33.29937527762527
# Generation 54: Best Fitness Score = 33.29937527762527
# Generation 55: Best Fitness Score = 33.29937527762527
# Generation 56: Best Fitness Score = 33.29937527762527
# Generation 57: Best Fitness Score = 33.29937527762527
# Generation 58: Best Fitness Score = 33.29937527762527
# Generation 59: Best Fitness Score = 33.29937527762527
# Generation 60: Best Fitness Score = 33.29937527762527
# Generation 61: Best Fitness Score = 33.29937527762527
# Generation 62: Best Fitness Score = 33.29937527762527
# Generation 63: Best Fitness Score = 33.29937527762527
# Generation 64: Best Fitness Score = 33.29937527762527
# Generation 65: Best Fitness Score = 33.29937527762527
# Generation 66: Best Fitness Score = 33.29937527762527
# Generation 67: Best Fitness Score = 33.29937527762527
# Generation 68: Best Fitness Score = 33.29937527762527
# Generation 69: Best Fitness Score = 33.29937527762527
# Generation 70: Best Fitness Score = 33.29937527762527
# Generation 71: Best Fitness Score = 33.29937527762527
# Generation 72: Best Fitness Score = 33.29937527762527
# Generation 73: Best Fitness Score = 33.29937527762527
# Generation 74: Best Fitness Score = 33.29937527762527
# Generation 75: Best Fitness Score = 33.29937527762527
# Generation 76: Best Fitness Score = 33.29937527762527
# Generation 77: Best Fitness Score = 33.29937527762527
# Generation 78: Best Fitness Score = 33.29937527762527
# Generation 79: Best Fitness Score = 33.29937527762527
# Generation 80: Best Fitness Score = 33.29937527762527
# Generation 81: Best Fitness Score = 33.29937527762527
# Generation 82: Best Fitness Score = 33.29937527762527
# Generation 83: Best Fitness Score = 33.29937527762527
# Generation 84: Best Fitness Score = 33.29937527762527
# Generation 85: Best Fitness Score = 33.29937527762527
# Generation 86: Best Fitness Score = 33.29937527762527
# Generation 87: Best Fitness Score = 33.29937527762527
# Generation 88: Best Fitness Score = 33.29937527762527
# Generation 89: Best Fitness Score = 33.29937527762527
# Generation 90: Best Fitness Score = 33.29937527762527
# Generation 91: Best Fitness Score = 33.29937527762527
# Generation 92: Best Fitness Score = 33.29937527762527
# Generation 93: Best Fitness Score = 33.29937527762527
# Generation 94: Best Fitness Score = 33.29937527762527
# Generation 95: Best Fitness Score = 33.29937527762527
# Generation 96: Best Fitness Score = 33.29937527762527
# Generation 97: Best Fitness Score = 33.29937527762527
# Generation 98: Best Fitness Score = 33.29937527762527
# Generation 99: Best Fitness Score = 33.29937527762527
# Generation 100: Best Fitness Score = 33.29937527762527
# Generation 1: Best Fitness Score = 19.02821505679853
# Generation 2: Best Fitness Score = 19.02821505679853
# Generation 3: Best Fitness Score = 19.02821505679853
# Generation 4: Best Fitness Score = 19.02821505679853
# Generation 5: Best Fitness Score = 19.02821505679853
# Generation 6: Best Fitness Score = 19.02821505679853
# Generation 7: Best Fitness Score = 19.02821505679853
# Generation 8: Best Fitness Score = 19.02821505679853
# Generation 9: Best Fitness Score = 19.02821505679853
# Generation 10: Best Fitness Score = 19.02821505679853
# Generation 11: Best Fitness Score = 19.02821505679853
# Generation 12: Best Fitness Score = 19.02821505679853
# Generation 13: Best Fitness Score = 19.02821505679853
# Generation 14: Best Fitness Score = 19.02821505679853
# Generation 15: Best Fitness Score = 19.02821505679853
# Generation 16: Best Fitness Score = 19.02821505679853
# Generation 17: Best Fitness Score = 19.02821505679853
# Generation 18: Best Fitness Score = 19.02821505679853
# Generation 19: Best Fitness Score = 19.02821505679853
# Generation 20: Best Fitness Score = 19.02821505679853
# Generation 21: Best Fitness Score = 19.02821505679853
# Generation 22: Best Fitness Score = 19.02821505679853
# Generation 23: Best Fitness Score = 19.02821505679853
# Generation 24: Best Fitness Score = 19.02821505679853
# Generation 25: Best Fitness Score = 19.02821505679853
# Generation 26: Best Fitness Score = 19.02821505679853
# Generation 27: Best Fitness Score = 19.02821505679853
# Generation 28: Best Fitness Score = 19.02821505679853
# Generation 29: Best Fitness Score = 19.02821505679853
# Generation 30: Best Fitness Score = 19.02821505679853
# Generation 31: Best Fitness Score = 19.02821505679853
# Generation 32: Best Fitness Score = 19.02821505679853
# Generation 33: Best Fitness Score = 19.02821505679853
# Generation 34: Best Fitness Score = 19.02821505679853
# Generation 35: Best Fitness Score = 19.02821505679853
# Generation 36: Best Fitness Score = 19.02821505679853
# Generation 37: Best Fitness Score = 19.02821505679853
# Generation 38: Best Fitness Score = 19.02821505679853
# Generation 39: Best Fitness Score = 19.02821505679853
# Generation 40: Best Fitness Score = 19.02821505679853
# Generation 41: Best Fitness Score = 19.02821505679853
# Generation 42: Best Fitness Score = 19.02821505679853
# Generation 43: Best Fitness Score = 19.02821505679853
# Generation 44: Best Fitness Score = 19.02821505679853
# Generation 45: Best Fitness Score = 19.02821505679853
# Generation 46: Best Fitness Score = 19.02821505679853
# Generation 47: Best Fitness Score = 19.02821505679853
# Generation 48: Best Fitness Score = 19.02821505679853
# Generation 49: Best Fitness Score = 19.02821505679853
# Generation 50: Best Fitness Score = 19.02821505679853
# Generation 51: Best Fitness Score = 19.02821505679853
# Generation 52: Best Fitness Score = 19.02821505679853
# Generation 53: Best Fitness Score = 19.02821505679853
# Generation 54: Best Fitness Score = 19.02821505679853
# Generation 55: Best Fitness Score = 19.02821505679853
# Generation 56: Best Fitness Score = 19.02821505679853
# Generation 57: Best Fitness Score = 19.02821505679853
# Generation 58: Best Fitness Score = 19.02821505679853
# Generation 59: Best Fitness Score = 19.02821505679853
# Generation 60: Best Fitness Score = 19.02821505679853
# Generation 61: Best Fitness Score = 19.02821505679853
# Generation 62: Best Fitness Score = 19.02821505679853
# Generation 63: Best Fitness Score = 19.02821505679853
# Generation 64: Best Fitness Score = 19.02821505679853
# Generation 65: Best Fitness Score = 19.02821505679853
# Generation 66: Best Fitness Score = 19.02821505679853
# Generation 67: Best Fitness Score = 19.02821505679853
# Generation 68: Best Fitness Score = 19.02821505679853
# Generation 69: Best Fitness Score = 19.02821505679853
# Generation 70: Best Fitness Score = 19.02821505679853
# Generation 71: Best Fitness Score = 19.02821505679853
# Generation 72: Best Fitness Score = 19.02821505679853
# Generation 73: Best Fitness Score = 19.02821505679853
# Generation 74: Best Fitness Score = 19.02821505679853
# Generation 75: Best Fitness Score = 19.02821505679853
# Generation 76: Best Fitness Score = 19.02821505679853
# Generation 77: Best Fitness Score = 19.02821505679853
# Generation 78: Best Fitness Score = 19.02821505679853
# Generation 79: Best Fitness Score = 19.02821505679853
# Generation 80: Best Fitness Score = 19.02821505679853
# Generation 81: Best Fitness Score = 19.02821505679853
# Generation 82: Best Fitness Score = 19.02821505679853
# Generation 83: Best Fitness Score = 19.02821505679853
# Generation 84: Best Fitness Score = 19.02821505679853
# Generation 85: Best Fitness Score = 19.02821505679853
# Generation 86: Best Fitness Score = 19.02821505679853
# Generation 87: Best Fitness Score = 19.02821505679853
# Generation 88: Best Fitness Score = 19.02821505679853
# Generation 89: Best Fitness Score = 19.02821505679853
# Generation 90: Best Fitness Score = 19.02821505679853
# Generation 91: Best Fitness Score = 19.02821505679853
# Generation 92: Best Fitness Score = 19.02821505679853
# Generation 93: Best Fitness Score = 19.02821505679853
# Generation 94: Best Fitness Score = 19.02821505679853
# Generation 95: Best Fitness Score = 19.02821505679853
# Generation 96: Best Fitness Score = 19.02821505679853
# Generation 97: Best Fitness Score = 19.02821505679853
# Generation 98: Best Fitness Score = 19.02821505679853
# Generation 99: Best Fitness Score = 19.02821505679853
# Generation 100: Best Fitness Score = 19.02821505679853
# Generation 1: Best Fitness Score = 4.757057174374477
# Generation 2: Best Fitness Score = 4.757057174374477
# Generation 3: Best Fitness Score = 4.757057174374477
# Generation 4: Best Fitness Score = 4.757057174374477
# Generation 5: Best Fitness Score = 4.757057174374477
# Generation 6: Best Fitness Score = 4.757057174374477
# Generation 7: Best Fitness Score = 4.757057174374477
# Generation 8: Best Fitness Score = 4.757057174374477
# Generation 9: Best Fitness Score = 4.757057174374477
# Generation 10: Best Fitness Score = 4.757057174374477
# Generation 11: Best Fitness Score = 4.757057174374477
# Generation 12: Best Fitness Score = 4.757057174374477
# Generation 13: Best Fitness Score = 4.757057174374477
# Generation 14: Best Fitness Score = 4.757057174374477
# Generation 15: Best Fitness Score = 4.757057174374477
# Generation 16: Best Fitness Score = 4.757057174374477
# Generation 17: Best Fitness Score = 4.757057174374477
# Generation 18: Best Fitness Score = 4.757057174374477
# Generation 19: Best Fitness Score = 4.757057174374477
# Generation 20: Best Fitness Score = 4.757057174374477
# Generation 21: Best Fitness Score = 4.757057174374477
# Generation 22: Best Fitness Score = 4.757057174374477
# Generation 23: Best Fitness Score = 4.757057174374477
# Generation 24: Best Fitness Score = 4.757057174374477
# Generation 25: Best Fitness Score = 4.757057174374477
# Generation 26: Best Fitness Score = 4.757057174374477
# Generation 27: Best Fitness Score = 4.757057174374477
# Generation 28: Best Fitness Score = 4.757057174374477
# Generation 29: Best Fitness Score = 4.757057174374477
# Generation 30: Best Fitness Score = 4.757057174374477
# Generation 31: Best Fitness Score = 4.757057174374477
# Generation 32: Best Fitness Score = 4.757057174374477
# Generation 33: Best Fitness Score = 4.757057174374477
# Generation 34: Best Fitness Score = 4.757057174374477
# Generation 35: Best Fitness Score = 4.757057174374477
# Generation 36: Best Fitness Score = 4.757057174374477
# Generation 37: Best Fitness Score = 4.757057174374477
# Generation 38: Best Fitness Score = 4.757057174374477
# Generation 39: Best Fitness Score = 4.757057174374477
# Generation 40: Best Fitness Score = 4.757057174374477
# Generation 41: Best Fitness Score = 4.757057174374477
# Generation 42: Best Fitness Score = 4.757057174374477
# Generation 43: Best Fitness Score = 4.757057174374477
# Generation 44: Best Fitness Score = 4.757057174374477
# Generation 45: Best Fitness Score = 4.757057174374477
# Generation 46: Best Fitness Score = 4.757057174374477
# Generation 47: Best Fitness Score = 4.757057174374477
# Generation 48: Best Fitness Score = 4.757057174374477
# Generation 49: Best Fitness Score = 4.757057174374477
# Generation 50: Best Fitness Score = 4.757057174374477
# Generation 51: Best Fitness Score = 4.757057174374477
# Generation 52: Best Fitness Score = 4.757057174374477
# Generation 53: Best Fitness Score = 4.757057174374477
# Generation 54: Best Fitness Score = 4.757057174374477
# Generation 55: Best Fitness Score = 4.757057174374477
# Generation 56: Best Fitness Score = 4.757057174374477
# Generation 57: Best Fitness Score = 4.757057174374477
# Generation 58: Best Fitness Score = 4.757057174374477
# Generation 59: Best Fitness Score = 4.757057174374477
# Generation 60: Best Fitness Score = 4.757057174374477
# Generation 61: Best Fitness Score = 4.757057174374477
# Generation 62: Best Fitness Score = 4.757057174374477
# Generation 63: Best Fitness Score = 4.757057174374477
# Generation 64: Best Fitness Score = 4.757057174374477
# Generation 65: Best Fitness Score = 4.757057174374477
# Generation 66: Best Fitness Score = 4.757057174374477
# Generation 67: Best Fitness Score = 4.757057174374477
# Generation 68: Best Fitness Score = 4.757057174374477
# Generation 69: Best Fitness Score = 4.757057174374477
# Generation 70: Best Fitness Score = 4.757057174374477
# Generation 71: Best Fitness Score = 4.757057174374477
# Generation 72: Best Fitness Score = 4.757057174374477
# Generation 73: Best Fitness Score = 4.757057174374477
# Generation 74: Best Fitness Score = 4.757057174374477
# Generation 75: Best Fitness Score = 4.757057174374477
# Generation 76: Best Fitness Score = 4.757057174374477
# Generation 77: Best Fitness Score = 4.757057174374477
# Generation 78: Best Fitness Score = 4.757057174374477
# Generation 79: Best Fitness Score = 4.757057174374477
# Generation 80: Best Fitness Score = 4.757057174374477
# Generation 81: Best Fitness Score = 4.757057174374477
# Generation 82: Best Fitness Score = 4.757057174374477
# Generation 83: Best Fitness Score = 4.757057174374477
# Generation 84: Best Fitness Score = 4.757057174374477
# Generation 85: Best Fitness Score = 4.757057174374477
# Generation 86: Best Fitness Score = 4.757057174374477
# Generation 87: Best Fitness Score = 4.757057174374477
# Generation 88: Best Fitness Score = 4.757057174374477
# Generation 89: Best Fitness Score = 4.757057174374477
# Generation 90: Best Fitness Score = 4.757057174374477
# Generation 91: Best Fitness Score = 4.757057174374477
# Generation 92: Best Fitness Score = 4.757057174374477
# Generation 93: Best Fitness Score = 4.757057174374477
# Generation 94: Best Fitness Score = 4.757057174374477
# Generation 95: Best Fitness Score = 4.757057174374477
# Generation 96: Best Fitness Score = 4.757057174374477
# Generation 97: Best Fitness Score = 4.757057174374477
# Generation 98: Best Fitness Score = 4.757057174374477
# Generation 99: Best Fitness Score = 4.757057174374477
# Generation 100: Best Fitness Score = 4.757057174374477
# Generation 1: Best Fitness Score = 77.53116244661173
# Generation 2: Best Fitness Score = 77.53116244661173
# Generation 3: Best Fitness Score = 79.70440186870115
# Generation 4: Best Fitness Score = 88.40372111823545
# Generation 5: Best Fitness Score = 88.40372111823545
# Generation 6: Best Fitness Score = 89.2736530440218
# Generation 7: Best Fitness Score = 89.76637922263183
# Generation 8: Best Fitness Score = 91.45627991871731
# Generation 9: Best Fitness Score = 91.45627991871731
# Generation 10: Best Fitness Score = 91.45627991871731
# Generation 11: Best Fitness Score = 91.45627991871731
# Generation 12: Best Fitness Score = 92.32621184470445
# Generation 13: Best Fitness Score = 92.32621184470445
# Generation 14: Best Fitness Score = 92.32621184470445
# Generation 15: Best Fitness Score = 92.32621184470445
# Generation 16: Best Fitness Score = 92.32621184470445
# Generation 17: Best Fitness Score = 92.32621184470445
# Generation 18: Best Fitness Score = 92.32621184470445
# Generation 19: Best Fitness Score = 92.32621184470445
# Generation 20: Best Fitness Score = 92.32621184470445
# Generation 21: Best Fitness Score = 92.32621184470445
# Generation 22: Best Fitness Score = 92.32621184470445
# Generation 23: Best Fitness Score = 92.32621184470445
# Generation 24: Best Fitness Score = 92.32621184470445
# Generation 25: Best Fitness Score = 92.32621184470445
# Generation 26: Best Fitness Score = 92.32621184470445
# Generation 27: Best Fitness Score = 92.32621184470445
# Generation 28: Best Fitness Score = 92.32621184470445
# Generation 29: Best Fitness Score = 92.32621184470445
# Generation 30: Best Fitness Score = 92.32621184470445
# Generation 31: Best Fitness Score = 92.32621184470445
# Generation 32: Best Fitness Score = 92.32621184470445
# Generation 33: Best Fitness Score = 92.32621184470445
# Generation 34: Best Fitness Score = 92.32621184470445
# Generation 35: Best Fitness Score = 92.32621184470445
# Generation 36: Best Fitness Score = 92.32621184470445
# Generation 37: Best Fitness Score = 92.32621184470445
# Generation 38: Best Fitness Score = 92.32621184470445
# Generation 39: Best Fitness Score = 92.32621184470445
# Generation 40: Best Fitness Score = 92.32621184470445
# Generation 41: Best Fitness Score = 92.32621184470445
# Generation 42: Best Fitness Score = 92.32621184470445
# Generation 43: Best Fitness Score = 92.32621184470445
# Generation 44: Best Fitness Score = 92.32621184470445
# Generation 45: Best Fitness Score = 92.32621184470445
# Generation 46: Best Fitness Score = 92.32621184470445
# Generation 47: Best Fitness Score = 92.32621184470445
# Generation 48: Best Fitness Score = 92.32621184470445
# Generation 49: Best Fitness Score = 92.32621184470445
# Generation 50: Best Fitness Score = 92.32621184470445
# Generation 51: Best Fitness Score = 92.32621184470445
# Generation 52: Best Fitness Score = 92.32621184470445
# Generation 53: Best Fitness Score = 92.32621184470445
# Generation 54: Best Fitness Score = 92.32621184470445
# Generation 55: Best Fitness Score = 92.32621184470445
# Generation 56: Best Fitness Score = 92.32621184470445
# Generation 57: Best Fitness Score = 92.32621184470445
# Generation 58: Best Fitness Score = 92.32621184470445
# Generation 59: Best Fitness Score = 92.32621184470445
# Generation 60: Best Fitness Score = 92.32621184470445
# Generation 61: Best Fitness Score = 92.32621184470445
# Generation 62: Best Fitness Score = 92.32621184470445
# Generation 63: Best Fitness Score = 92.32621184470445
# Generation 64: Best Fitness Score = 92.32621184470445
# Generation 65: Best Fitness Score = 92.32621184470445
# Generation 66: Best Fitness Score = 92.32621184470445
# Generation 67: Best Fitness Score = 92.32621184470445
# Generation 68: Best Fitness Score = 92.32621184470445
# Generation 69: Best Fitness Score = 92.32621184470445
# Generation 70: Best Fitness Score = 92.32621184470445
# Generation 71: Best Fitness Score = 92.32621184470445
# Generation 72: Best Fitness Score = 92.32621184470445
# Generation 73: Best Fitness Score = 92.32621184470445
# Generation 74: Best Fitness Score = 92.32621184470445
# Generation 75: Best Fitness Score = 92.32621184470445
# Generation 76: Best Fitness Score = 92.32621184470445
# Generation 77: Best Fitness Score = 92.32621184470445
# Generation 78: Best Fitness Score = 92.32621184470445
# Generation 79: Best Fitness Score = 92.32621184470445
# Generation 80: Best Fitness Score = 92.32621184470445
# Generation 81: Best Fitness Score = 92.32621184470445
# Generation 82: Best Fitness Score = 92.32621184470445
# Generation 83: Best Fitness Score = 92.32621184470445
# Generation 84: Best Fitness Score = 92.32621184470445
# Generation 85: Best Fitness Score = 92.32621184470445
# Generation 86: Best Fitness Score = 92.32621184470445
# Generation 87: Best Fitness Score = 92.32621184470445
# Generation 88: Best Fitness Score = 92.32621184470445
# ...
# Generation 56: Best Fitness Score = 16.59853939300253
# Generation 57: Best Fitness Score = 16.59853939300253
# Generation 58: Best Fitness Score = 16.59853939300253
# Generation 59: Best Fitness Score = 16.59853939300253
# Generation 60: Best Fitness Score = 16.59853939300253
# Generation 61: Best Fitness Score = 16.59853939300253
# Generation 62: Best Fitness Score = 16.59853939300253
# Generation 63: Best Fitness Score = 16.59853939300253
# Generation 64: Best Fitness Score = 16.59853939300253
# Generation 65: Best Fitness Score = 16.59853939300253
# Generation 66: Best Fitness Score = 16.59853939300253
# Generation 67: Best Fitness Score = 16.59853939300253
# Generation 68: Best Fitness Score = 16.59853939300253
# Generation 69: Best Fitness Score = 16.59853939300253
# Generation 70: Best Fitness Score = 16.59853939300253
# Generation 71: Best Fitness Score = 16.59853939300253
# Generation 72: Best Fitness Score = 16.59853939300253
# Generation 73: Best Fitness Score = 16.59853939300253
# Generation 74: Best Fitness Score = 16.59853939300253
# Generation 75: Best Fitness Score = 16.59853939300253
# Generation 76: Best Fitness Score = 16.59853939300253
# Generation 77: Best Fitness Score = 16.59853939300253
# Generation 78: Best Fitness Score = 16.59853939300253
# Generation 79: Best Fitness Score = 16.59853939300253
# Generation 80: Best Fitness Score = 16.59853939300253
# Generation 81: Best Fitness Score = 16.59853939300253
# Generation 82: Best Fitness Score = 16.59853939300253
# Generation 83: Best Fitness Score = 16.59853939300253
# Generation 84: Best Fitness Score = 16.59853939300253
# Generation 85: Best Fitness Score = 16.59853939300253
# Generation 86: Best Fitness Score = 16.59853939300253
# Generation 87: Best Fitness Score = 16.59853939300253
# Generation 88: Best Fitness Score = 16.59853939300253
# Generation 89: Best Fitness Score = 16.59853939300253
# Generation 90: Best Fitness Score = 16.59853939300253
# Generation 91: Best Fitness Score = 16.59853939300253
# Generation 92: Best Fitness Score = 16.59853939300253
# Generation 93: Best Fitness Score = 16.59853939300253
# Generation 94: Best Fitness Score = 16.59853939300253
# Generation 95: Best Fitness Score = 16.59853939300253
# Generation 96: Best Fitness Score = 16.59853939300253
# Generation 97: Best Fitness Score = 16.59853939300253
# Generation 98: Best Fitness Score = 16.59853939300253
# Generation 99: Best Fitness Score = 16.59853939300253
# Generation 100: Best Fitness Score = 16.59853939300253
# Generation 1: Best Fitness Score = 4.742442671833848
# Generation 2: Best Fitness Score = 4.742442671833848
# Generation 3: Best Fitness Score = 4.742442671833848
# Generation 4: Best Fitness Score = 4.742442671833848
# Generation 5: Best Fitness Score = 4.742442671833848
# Generation 6: Best Fitness Score = 4.742442671833848
# Generation 7: Best Fitness Score = 4.742442671833848
# Generation 8: Best Fitness Score = 4.742442671833848
# Generation 9: Best Fitness Score = 4.742442671833848
# Generation 10: Best Fitness Score = 4.742442671833848
# Generation 11: Best Fitness Score = 4.742442671833848
# Generation 12: Best Fitness Score = 4.742442671833848
# Generation 13: Best Fitness Score = 4.742442671833848
# Generation 14: Best Fitness Score = 4.742442671833848
# Generation 15: Best Fitness Score = 4.742442671833848
# Generation 16: Best Fitness Score = 4.742442671833848
# Generation 17: Best Fitness Score = 4.742442671833848
# Generation 18: Best Fitness Score = 4.742442671833848
# Generation 19: Best Fitness Score = 4.742442671833848
# Generation 20: Best Fitness Score = 4.742442671833848
# Generation 21: Best Fitness Score = 4.742442671833848
# Generation 22: Best Fitness Score = 4.742442671833848
# Generation 23: Best Fitness Score = 4.742442671833848
# Generation 24: Best Fitness Score = 4.742442671833848
# Generation 25: Best Fitness Score = 4.742442671833848
# Generation 26: Best Fitness Score = 4.742442671833848
# Generation 27: Best Fitness Score = 4.742442671833848
# Generation 28: Best Fitness Score = 4.742442671833848
# Generation 29: Best Fitness Score = 4.742442671833848
# Generation 30: Best Fitness Score = 4.742442671833848
# Generation 31: Best Fitness Score = 4.742442671833848
# Generation 32: Best Fitness Score = 4.742442671833848
# Generation 33: Best Fitness Score = 4.742442671833848
# Generation 34: Best Fitness Score = 4.742442671833848
# Generation 35: Best Fitness Score = 4.742442671833848
# Generation 36: Best Fitness Score = 4.742442671833848
# Generation 37: Best Fitness Score = 4.742442671833848
# Generation 38: Best Fitness Score = 4.742442671833848
# Generation 39: Best Fitness Score = 4.742442671833848
# Generation 40: Best Fitness Score = 4.742442671833848
# Generation 41: Best Fitness Score = 4.742442671833848
# Generation 42: Best Fitness Score = 4.742442671833848
# Generation 43: Best Fitness Score = 4.742442671833848
# Generation 44: Best Fitness Score = 4.742442671833848
# Generation 45: Best Fitness Score = 4.742442671833848
# Generation 46: Best Fitness Score = 4.742442671833848
# Generation 47: Best Fitness Score = 4.742442671833848
# Generation 48: Best Fitness Score = 4.742442671833848
# Generation 49: Best Fitness Score = 4.742442671833848
# Generation 50: Best Fitness Score = 4.742442671833848
# Generation 51: Best Fitness Score = 4.742442671833848
# Generation 52: Best Fitness Score = 4.742442671833848
# Generation 53: Best Fitness Score = 4.742442671833848
# Generation 54: Best Fitness Score = 4.742442671833848
# Generation 55: Best Fitness Score = 4.742442671833848
# Generation 56: Best Fitness Score = 4.742442671833848
# Generation 57: Best Fitness Score = 4.742442671833848
# Generation 58: Best Fitness Score = 4.742442671833848
# Generation 59: Best Fitness Score = 4.742442671833848
# Generation 60: Best Fitness Score = 4.742442671833848
# Generation 61: Best Fitness Score = 4.742442671833848
# Generation 62: Best Fitness Score = 4.742442671833848
# Generation 63: Best Fitness Score = 4.742442671833848
# Generation 64: Best Fitness Score = 4.742442671833848
# Generation 65: Best Fitness Score = 4.742442671833848
# Generation 66: Best Fitness Score = 4.742442671833848
# Generation 67: Best Fitness Score = 4.742442671833848
# Generation 68: Best Fitness Score = 4.742442671833848
# Generation 69: Best Fitness Score = 4.742442671833848
# Generation 70: Best Fitness Score = 4.742442671833848
# Generation 71: Best Fitness Score = 4.742442671833848
# Generation 72: Best Fitness Score = 4.742442671833848
# Generation 73: Best Fitness Score = 4.742442671833848
# Generation 74: Best Fitness Score = 4.742442671833848
# Generation 75: Best Fitness Score = 4.742442671833848
# Generation 76: Best Fitness Score = 4.742442671833848
# Generation 77: Best Fitness Score = 4.742442671833848
# Generation 78: Best Fitness Score = 4.742442671833848
# Generation 79: Best Fitness Score = 4.742442671833848
# Generation 80: Best Fitness Score = 4.742442671833848
# Generation 81: Best Fitness Score = 4.742442671833848
# Generation 82: Best Fitness Score = 4.742442671833848
# Generation 83: Best Fitness Score = 4.742442671833848
# Generation 84: Best Fitness Score = 4.742442671833848
# Generation 85: Best Fitness Score = 4.742442671833848
# Generation 86: Best Fitness Score = 4.742442671833848
# Generation 87: Best Fitness Score = 4.742442671833848
# Generation 88: Best Fitness Score = 4.742442671833848
# Generation 89: Best Fitness Score = 4.742442671833848
# Generation 90: Best Fitness Score = 4.742442671833848
# Generation 91: Best Fitness Score = 4.742442671833848
# Generation 92: Best Fitness Score = 4.742442671833848
# Generation 93: Best Fitness Score = 4.742442671833848
# Generation 94: Best Fitness Score = 4.742442671833848
# Generation 95: Best Fitness Score = 4.742442671833848
# Generation 96: Best Fitness Score = 4.742442671833848
# Generation 97: Best Fitness Score = 4.742442671833848
# Generation 98: Best Fitness Score = 4.742442671833848
# Generation 99: Best Fitness Score = 4.742442671833848
# Generation 100: Best Fitness Score = 4.742442671833848
# Generation 1: Best Fitness Score = 2.371225983159413
# Generation 2: Best Fitness Score = 2.371225983159413
# Generation 3: Best Fitness Score = 2.371225983159413
# Generation 4: Best Fitness Score = 2.371225983159413
# Generation 5: Best Fitness Score = 2.371225983159413
# Generation 6: Best Fitness Score = 2.371225983159413
# Generation 7: Best Fitness Score = 2.371225983159413
# Generation 8: Best Fitness Score = 2.371225983159413
# Generation 9: Best Fitness Score = 2.371225983159413
# Generation 10: Best Fitness Score = 2.371225983159413
# Generation 11: Best Fitness Score = 2.371225983159413
# Generation 12: Best Fitness Score = 2.371225983159413
# Generation 13: Best Fitness Score = 2.371225983159413
# Generation 14: Best Fitness Score = 2.371225983159413
# Generation 15: Best Fitness Score = 2.371225983159413
# Generation 16: Best Fitness Score = 2.371225983159413
# Generation 17: Best Fitness Score = 2.371225983159413
# Generation 18: Best Fitness Score = 2.371225983159413
# Generation 19: Best Fitness Score = 2.371225983159413
# Generation 20: Best Fitness Score = 2.371225983159413
# Generation 21: Best Fitness Score = 2.371225983159413
# Generation 22: Best Fitness Score = 2.371225983159413
# Generation 23: Best Fitness Score = 2.371225983159413
# Generation 24: Best Fitness Score = 2.371225983159413
# Generation 25: Best Fitness Score = 2.371225983159413
# Generation 26: Best Fitness Score = 2.371225983159413
# Generation 27: Best Fitness Score = 2.371225983159413
# Generation 28: Best Fitness Score = 2.371225983159413
# Generation 29: Best Fitness Score = 2.371225983159413
# Generation 30: Best Fitness Score = 2.371225983159413
# Generation 31: Best Fitness Score = 2.371225983159413
# Generation 32: Best Fitness Score = 2.371225983159413
# Generation 33: Best Fitness Score = 2.371225983159413
# Generation 34: Best Fitness Score = 2.371225983159413
# Generation 35: Best Fitness Score = 2.371225983159413
# Generation 36: Best Fitness Score = 2.371225983159413
# Generation 37: Best Fitness Score = 2.371225983159413
# Generation 38: Best Fitness Score = 2.371225983159413
# Generation 39: Best Fitness Score = 2.371225983159413
# Generation 40: Best Fitness Score = 2.371225983159413
# Generation 41: Best Fitness Score = 2.371225983159413
# Generation 42: Best Fitness Score = 2.371225983159413
# Generation 43: Best Fitness Score = 2.371225983159413
# Generation 44: Best Fitness Score = 2.371225983159413
# Generation 45: Best Fitness Score = 2.371225983159413
# Generation 46: Best Fitness Score = 2.371225983159413
# Generation 47: Best Fitness Score = 2.371225983159413
# Generation 48: Best Fitness Score = 2.371225983159413
# Generation 49: Best Fitness Score = 2.371225983159413
# Generation 50: Best Fitness Score = 2.371225983159413
# Generation 51: Best Fitness Score = 2.371225983159413
# Generation 52: Best Fitness Score = 2.371225983159413
# Generation 53: Best Fitness Score = 2.371225983159413
# Generation 54: Best Fitness Score = 2.371225983159413
# Generation 55: Best Fitness Score = 2.371225983159413
# Generation 56: Best Fitness Score = 2.371225983159413
# Generation 57: Best Fitness Score = 2.371225983159413
# Generation 58: Best Fitness Score = 2.371225983159413
# Generation 59: Best Fitness Score = 2.371225983159413
# Generation 60: Best Fitness Score = 2.371225983159413
# Generation 61: Best Fitness Score = 2.371225983159413
# Generation 62: Best Fitness Score = 2.371225983159413
# Generation 63: Best Fitness Score = 2.371225983159413
# Generation 64: Best Fitness Score = 2.371225983159413
# Generation 65: Best Fitness Score = 2.371225983159413
# Generation 66: Best Fitness Score = 2.371225983159413
# Generation 67: Best Fitness Score = 2.371225983159413
# Generation 68: Best Fitness Score = 2.371225983159413
# Generation 69: Best Fitness Score = 2.371225983159413
# Generation 70: Best Fitness Score = 2.371225983159413
# Generation 71: Best Fitness Score = 2.371225983159413
# Generation 72: Best Fitness Score = 2.371225983159413
# Generation 73: Best Fitness Score = 2.371225983159413
# Generation 74: Best Fitness Score = 2.371225983159413
# Generation 75: Best Fitness Score = 2.371225983159413
# Generation 76: Best Fitness Score = 2.371225983159413
# Generation 77: Best Fitness Score = 2.371225983159413
# Generation 78: Best Fitness Score = 2.371225983159413
# Generation 79: Best Fitness Score = 2.371225983159413
# Generation 80: Best Fitness Score = 2.371225983159413
# Generation 81: Best Fitness Score = 2.371225983159413
# Generation 82: Best Fitness Score = 2.371225983159413
# Generation 83: Best Fitness Score = 2.371225983159413
# Generation 84: Best Fitness Score = 2.371225983159413
# Generation 85: Best Fitness Score = 2.371225983159413
# Generation 86: Best Fitness Score = 2.371225983159413
# Generation 87: Best Fitness Score = 2.371225983159413
# Generation 88: Best Fitness Score = 2.371225983159413
# Generation 89: Best Fitness Score = 2.371225983159413
# Generation 90: Best Fitness Score = 2.371225983159413
# Generation 91: Best Fitness Score = 2.371225983159413
# Generation 92: Best Fitness Score = 2.371225983159413
# Generation 93: Best Fitness Score = 2.371225983159413
# Generation 94: Best Fitness Score = 2.371225983159413
# Generation 95: Best Fitness Score = 2.371225983159413
# Generation 96: Best Fitness Score = 2.371225983159413
# Generation 97: Best Fitness Score = 2.371225983159413
# Generation 98: Best Fitness Score = 2.371225983159413
# Generation 99: Best Fitness Score = 2.371225983159413
# Generation 100: Best Fitness Score = 2.371225983159413
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     BEV   258212.85  Electricity               9
# 1   Size S1, Distance D1  Diesel   295840.97          B20               9
# 2   Size S1, Distance D1     LNG   207700.92          LNG               9
# 3   Size S1, Distance D2  Diesel   854651.70          B20              26
# 4   Size S1, Distance D2     LNG   600024.87          LNG              26
# 5   Size S1, Distance D3  Diesel  1084750.23          B20              33
# 6   Size S1, Distance D3     LNG   761570.02          LNG              33
# 7   Size S1, Distance D4  Diesel   164356.10          B20               5
# 8   Size S1, Distance D4     LNG   115389.40          LNG               5
# 9   Size S2, Distance D1     BEV   345518.06  Electricity              10
# 10  Size S2, Distance D1  Diesel   352084.72          B20              10
# 11  Size S2, Distance D1     LNG   256988.62          LNG              10
# 12  Size S2, Distance D2  Diesel   492918.61          B20              14
# 13  Size S2, Distance D2     LNG   359784.07          LNG              14
# 14  Size S2, Distance D3  Diesel   281667.78          B20               8
# 15  Size S2, Distance D3     LNG   205590.90          LNG               8
# 16  Size S2, Distance D4  Diesel    70416.94          B20               2
# 17  Size S2, Distance D4     LNG    51397.72          LNG               2
# 18  Size S3, Distance D1     BEV   933543.28  Electricity              30
# 19  Size S3, Distance D1  Diesel   811840.31          B20              30
# 20  Size S3, Distance D1     LNG   637201.55          LNG              30
# 21  Size S3, Distance D2  Diesel   920085.68          B20              34
# 22  Size S3, Distance D2     LNG   722161.76          LNG              34
# 23  Size S3, Distance D3  Diesel   378858.81          B20              14
# 24  Size S3, Distance D3     LNG   297360.72          LNG              14
# 25  Size S3, Distance D4  Diesel    81184.03          B20               3
# 26  Size S3, Distance D4     LNG    63720.16          LNG               3
# 27  Size S4, Distance D1     BEV    44121.39  Electricity               1
# 28  Size S4, Distance D1  Diesel    40744.40          B20               1
# 29  Size S4, Distance D1     LNG    31574.93          LNG               1
# 30  Size S4, Distance D2  Diesel   285210.83          B20               7
# 31  Size S4, Distance D2     LNG   221024.52          LNG               7
# 32  Size S4, Distance D3  Diesel    81488.81          B20               2
# 33  Size S4, Distance D3     LNG    63149.86          LNG               2
# 34  Size S4, Distance D4  Diesel    40744.40          B20               1
# 35  Size S4, Distance D4     LNG    31574.93          LNG               1

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',  # Keeping as requested
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups

    def calculate_required_vehicles(self, vehicle: Dict) -> int:
        """Calculate required number of vehicles based on demand and yearly range"""
        return int(np.ceil(vehicle['demand'] / vehicle['yearly_range']))

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        
        for _ in range(population_size):
            solution = {
                v['vehicle_type']: random.randint(0, self.calculate_required_vehicles(v))
                for v in vehicles
            }
            population.append(solution)
        
        return population

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost (insurance + maintenance + fuel)
        """
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def crossover(self, parent1: Dict, parent2: Dict) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions"""
        crossover_point = random.randint(1, len(parent1) - 1)
        child1 = {}
        child2 = {}

        for i, vehicle_type in enumerate(parent1.keys()):
            if i < crossover_point:
                child1[vehicle_type] = parent1[vehicle_type]
                child2[vehicle_type] = parent2[vehicle_type]
            else:
                child1[vehicle_type] = parent2[vehicle_type]
                child2[vehicle_type] = parent1[vehicle_type]

        return child1, child2

    def mutate(self, solution: Dict, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution by randomly adjusting the number of vehicles"""
        mutated_solution = solution.copy()
        for vehicle_type in mutated_solution.keys():
            if random.random() < mutation_rate:
                mutated_solution[vehicle_type] = max(0, mutated_solution[vehicle_type] + random.choice([-1, 1]))

        return mutated_solution

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                              for solution in population]
            
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1)
                child2 = self.mutate(child2)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    print(results_df)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     BEV   946780.44  Electricity              33
# 1   Size S1, Distance D1  Diesel   854651.70          B20              26
# 2   Size S1, Distance D1     LNG   784647.90          LNG              34
# 3   Size S1, Distance D2  Diesel  1512076.08          B20              46
# 4   Size S1, Distance D2     LNG  1153893.98          LNG              50
# 5   Size S1, Distance D3  Diesel  1709303.39          B20              52
# 6   Size S1, Distance D3     LNG  1338517.01          LNG              58
# 7   Size S1, Distance D4  Diesel   887522.91          B20              27
# 8   Size S1, Distance D4     LNG   623102.75          LNG              27
# 9   Size S2, Distance D1     BEV  1105657.79  Electricity              32
# 10  Size S2, Distance D1  Diesel   809794.87          B20              23
# 11  Size S2, Distance D1     LNG   796664.73          LNG              31
# 12  Size S2, Distance D2  Diesel  1302713.48          B20              37
# 13  Size S2, Distance D2     LNG  1027954.49          LNG              40
# 14  Size S2, Distance D3  Diesel  1056254.17          B20              30
# 15  Size S2, Distance D3     LNG   822363.59          LNG              32
# 16  Size S2, Distance D4  Diesel   845003.34          B20              24
# 17  Size S2, Distance D4     LNG   693869.28          LNG              27
# 18  Size S3, Distance D1     BEV  1400314.91  Electricity              45
# 19  Size S3, Distance D1  Diesel  1298944.49          B20              48
# 20  Size S3, Distance D1     LNG  1040762.54          LNG              49
# 21  Size S3, Distance D2  Diesel  1515435.24          B20              56
# 22  Size S3, Distance D2     LNG  1146962.79          LNG              54
# 23  Size S3, Distance D3  Diesel   947147.03          B20              35
# 24  Size S3, Distance D3     LNG   849602.07          LNG              40
# 25  Size S3, Distance D4  Diesel   568288.22          B20              21
# 26  Size S3, Distance D4     LNG   615961.50          LNG              29
# 27  Size S4, Distance D1     BEV   970670.61  Electricity              22
# 28  Size S4, Distance D1  Diesel   855632.49          B20              21
# 29  Size S4, Distance D1     LNG   789373.29          LNG              25
# 30  Size S4, Distance D2  Diesel  1426054.15          B20              35
# 31  Size S4, Distance D2     LNG   978822.87          LNG              31
# 32  Size S4, Distance D3  Diesel   896376.89          B20              22
# 33  Size S4, Distance D3     LNG   884098.08          LNG              28
# 34  Size S4, Distance D4  Diesel   937121.30          B20              23
# 35  Size S4, Distance D4     LNG   789373.29          LNG              25
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     BEV   946780.44  Electricity              33
# 1   Size S1, Distance D1  Diesel   854651.70          B20              26
# 2   Size S1, Distance D1     LNG   784647.90          LNG              34
# 3   Size S1, Distance D2  Diesel  1512076.08          B20              46
# 4   Size S1, Distance D2     LNG  1153893.98          LNG              50
# 5   Size S1, Distance D3  Diesel  1709303.39          B20              52
# 6   Size S1, Distance D3     LNG  1338517.01          LNG              58
# 7   Size S1, Distance D4  Diesel   887522.91          B20              27
# 8   Size S1, Distance D4     LNG   623102.75          LNG              27
# 9   Size S2, Distance D1     BEV  1105657.79  Electricity              32
# 10  Size S2, Distance D1  Diesel   809794.87          B20              23
# 11  Size S2, Distance D1     LNG   796664.73          LNG              31
# 12  Size S2, Distance D2  Diesel  1302713.48          B20              37
# 13  Size S2, Distance D2     LNG  1027954.49          LNG              40
# 14  Size S2, Distance D3  Diesel  1056254.17          B20              30
# 15  Size S2, Distance D3     LNG   822363.59          LNG              32
# 16  Size S2, Distance D4  Diesel   845003.34          B20              24
# 17  Size S2, Distance D4     LNG   693869.28          LNG              27
# 18  Size S3, Distance D1     BEV  1400314.91  Electricity              45
# 19  Size S3, Distance D1  Diesel  1298944.49          B20              48
# 20  Size S3, Distance D1     LNG  1040762.54          LNG              49
# 21  Size S3, Distance D2  Diesel  1515435.24          B20              56
# 22  Size S3, Distance D2     LNG  1146962.79          LNG              54
# 23  Size S3, Distance D3  Diesel   947147.03          B20              35
# 24  Size S3, Distance D3     LNG   849602.07          LNG              40
# 25  Size S3, Distance D4  Diesel   568288.22          B20              21
# 26  Size S3, Distance D4     LNG   615961.50          LNG              29
# 27  Size S4, Distance D1     BEV   970670.61  Electricity              22
# 28  Size S4, Distance D1  Diesel   855632.49          B20              21
# 29  Size S4, Distance D1     LNG   789373.29          LNG              25
# 30  Size S4, Distance D2  Diesel  1426054.15          B20              35
# 31  Size S4, Distance D2     LNG   978822.87          LNG              31
# 32  Size S4, Distance D3  Diesel   896376.89          B20              22
# 33  Size S4, Distance D3     LNG   884098.08          LNG              28
# 34  Size S4, Distance D4  Diesel   937121.30          B20              23
# 35  Size S4, Distance D4     LNG   789373.29          LNG              25

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame, max_total_vehicles_per_bucket: int = 10):
        self.data = data
        self.max_total_vehicles_per_bucket = max_total_vehicles_per_bucket
        self.vehicles_by_size_distance = self._group_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups

    def is_valid_solution(self, solution: Dict) -> bool:
        """Check if the total number of vehicles in the solution is within the maximum limit"""
        return sum(solution.values()) <= self.max_total_vehicles_per_bucket

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = self.max_total_vehicles_per_bucket
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting total vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if self.is_valid_solution(child1) and self.is_valid_solution(child2):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the total vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < self.max_total_vehicles_per_bucket) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1)
                child2 = self.mutate(child2)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles
                    })

        return pd.DataFrame(results)

def main(csv_path: str, max_vehicles: int = 10):
    """Main function to run the optimization"""
    print(f"\nRunning optimization with maximum {max_vehicles} vehicles per bucket...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df, max_total_vehicles_per_bucket=max_vehicles)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path, max_vehicles=10)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Running optimization with maximum 10 vehicles per bucket...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle   Cost ($) Fuel  no_of_vehicles
# 0   Size S1, Distance D1     LNG  230778.80  LNG              10
# 1   Size S1, Distance D2     LNG  230778.80  LNG              10
# 2   Size S1, Distance D3  Diesel   65742.44  B20               2
# 3   Size S1, Distance D3     LNG  184623.04  LNG               8
# 4   Size S1, Distance D4     LNG  230778.80  LNG              10
# 5   Size S2, Distance D1     LNG  256988.62  LNG              10
# 6   Size S2, Distance D2     LNG  256988.62  LNG              10
# 7   Size S2, Distance D3     LNG  256988.62  LNG              10
# 8   Size S2, Distance D4     LNG  256988.62  LNG              10
# 9   Size S3, Distance D1  Diesel   54122.69  B20               2
# 10  Size S3, Distance D1     LNG  169920.41  LNG               8
# 11  Size S3, Distance D2     LNG  212400.52  LNG              10
# 12  Size S3, Distance D3     LNG  212400.52  LNG              10
# 13  Size S3, Distance D4     LNG  212400.52  LNG              10
# 14  Size S4, Distance D1     LNG  315749.31  LNG              10
# 15  Size S4, Distance D2     LNG  315749.31  LNG              10
# 16  Size S4, Distance D3  Diesel  162977.62  B20               4
# 17  Size S4, Distance D3     LNG  189449.59  LNG               6
# 18  Size S4, Distance D4  Diesel   40744.40  B20               1
# 19  Size S4, Distance D4     LNG  284174.38  LNG               9

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

class FleetEvaluator:
    def __init__(self, solution: Dict, vehicles_data: List[Dict], size_distance: Tuple):
        self.solution = solution
        self.vehicles_data = vehicles_data
        self.size_distance = size_distance
        self.demand = vehicles_data[0]['demand']  # Demand is same for all vehicles in bucket
        
    def evaluate_demand_coverage(self) -> Dict:
        """Evaluate how well the solution meets the demand"""
        total_capacity = 0
        for vehicle in self.vehicles_data:
            num_vehicles = self.solution[vehicle['vehicle_type']]
            total_capacity += num_vehicles * vehicle['yearly_range']
        
        coverage_ratio = total_capacity / self.demand if self.demand > 0 else 0
        
        return {
            'total_capacity': total_capacity,
            'demand': self.demand,
            'coverage_ratio': coverage_ratio,
            'is_demand_met': coverage_ratio >= 1,
            'capacity_surplus': max(0, total_capacity - self.demand),
            'capacity_deficit': max(0, self.demand - total_capacity)
        }
    
    def evaluate_costs(self) -> Dict:
        """Evaluate cost metrics of the solution"""
        total_cost = 0
        cost_breakdown = {
            'insurance': 0,
            'maintenance': 0,
            'fuel': 0
        }
        
        for vehicle in self.vehicles_data:
            num_vehicles = self.solution[vehicle['vehicle_type']]
            cost_breakdown['insurance'] += num_vehicles * vehicle['insurance_cost']
            cost_breakdown['maintenance'] += num_vehicles * vehicle['maintenance_cost']
            cost_breakdown['fuel'] += num_vehicles * vehicle['fuel_costs']
            
        total_cost = sum(cost_breakdown.values())
        
        return {
            'total_cost': total_cost,
            'cost_breakdown': cost_breakdown,
            'cost_per_km': total_cost / self.demand if self.demand > 0 else 0
        }
    
    def evaluate_fleet_composition(self) -> Dict:
        """Evaluate the composition of the fleet"""
        total_vehicles = sum(self.solution.values())
        composition = {}
        
        for vehicle in self.vehicles_data:
            vehicle_type = vehicle['vehicle_type']
            num_vehicles = self.solution[vehicle_type]
            composition[vehicle_type] = {
                'count': num_vehicles,
                'percentage': (num_vehicles / total_vehicles * 100) if total_vehicles > 0 else 0,
                'topsis_score': vehicle['topsis_score'],
                'weighted_topsis': vehicle['topsis_score'] * num_vehicles
            }
            
        return {
            'total_vehicles': total_vehicles,
            'composition': composition,
            'average_topsis': sum(v['weighted_topsis'] for v in composition.values()) / total_vehicles if total_vehicles > 0 else 0
        }
    
    def evaluate_sustainability(self) -> Dict:
        """Evaluate sustainability metrics"""
        fuel_types = {}
        for vehicle in self.vehicles_data:
            num_vehicles = self.solution[vehicle['vehicle_type']]
            fuel_type = vehicle['fuel']
            if fuel_type not in fuel_types:
                fuel_types[fuel_type] = 0
            fuel_types[fuel_type] += num_vehicles
            
        total_vehicles = sum(self.solution.values())
        
        return {
            'fuel_distribution': {
                fuel: {
                    'count': count,
                    'percentage': (count / total_vehicles * 100) if total_vehicles > 0 else 0
                }
                for fuel, count in fuel_types.items()
            }
        }
    
    def get_comprehensive_evaluation(self) -> Dict:
        """Get comprehensive evaluation of all metrics"""
        demand_eval = self.evaluate_demand_coverage()
        cost_eval = self.evaluate_costs()
        fleet_eval = self.evaluate_fleet_composition()
        sustainability_eval = self.evaluate_sustainability()
        
        solution_score = self._calculate_solution_score(
            demand_eval, cost_eval, fleet_eval, sustainability_eval
        )
        
        return {
            'size_distance': self.size_distance,
            'solution_score': solution_score,
            'demand_evaluation': demand_eval,
            'cost_evaluation': cost_eval,
            'fleet_evaluation': fleet_eval,
            'sustainability_evaluation': sustainability_eval
        }
    
    def _calculate_solution_score(self, demand_eval, cost_eval, fleet_eval, sustainability_eval) -> float:
        """Calculate an overall solution score (0-100)"""
        score = 0
        
        # Demand coverage (40 points)
        coverage_ratio = min(demand_eval['coverage_ratio'], 1.2)  # Cap at 120%
        score += (coverage_ratio / 1.2) * 40
        
        # Cost efficiency (30 points)
        # Assuming a benchmark cost_per_km (you may need to adjust this)
        benchmark_cost_per_km = 1.0
        cost_ratio = min(benchmark_cost_per_km / cost_eval['cost_per_km'], 1)
        score += cost_ratio * 30
        
        # TOPSIS score (20 points)
        score += (fleet_eval['average_topsis'] / 100) * 20
        
        # Sustainability (10 points)
        # Assuming electric/hybrid vehicles are more sustainable
        sustainable_fuels = {'Electric', 'Hybrid'}
        sustainable_percentage = sum(
            data['percentage'] 
            for fuel, data in sustainability_eval['fuel_distribution'].items()
            if fuel in sustainable_fuels
        )
        score += (sustainable_percentage / 100) * 10
        
        return round(score, 2)

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame, max_total_vehicles_per_bucket: int = 10):
        self.data = data
        self.max_total_vehicles_per_bucket = max_total_vehicles_per_bucket
        self.vehicles_by_size_distance = self._group_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups

    def is_valid_solution(self, solution: Dict) -> bool:
        """Check if the total number of vehicles in the solution is within the maximum limit"""
        return sum(solution.values()) <= self.max_total_vehicles_per_bucket

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = self.max_total_vehicles_per_bucket
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting total vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if self.is_valid_solution(child1) and self.is_valid_solution(child2):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the total vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < self.max_total_vehicles_per_bucket) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1)
                child2 = self.mutate(child2)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def evaluate_solution(self, solution: Dict, size_distance: Tuple) -> Dict:
    # """Evaluate a given solution using the FleetEvaluator"""
        vehicles = self.vehicles_by_size_distance[size_distance]
        evaluator = FleetEvaluator(solution, vehicles, size_distance)
        return evaluator.get_comprehensive_evaluation()

    def get_optimized_results(self) -> pd.DataFrame:
    # """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            # Get vehicle data for this bucket
            vehicles = self.vehicles_by_size_distance[size_distance]
            
            # Initialize solution with all vehicle types set to 0
            initial_solution = {v['vehicle_type']: 0 for v in vehicles}
            
            # Get optimized solution
            best_solution = self.optimize(size_distance)
            
            # Update initial solution with optimized values
            initial_solution.update(best_solution)
            
            # Create results entries
            for vehicle_type, num_vehicles in initial_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in vehicles if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles
                    })

        return pd.DataFrame(results)

def main(csv_path: str, max_vehicles: int = 10):
    # """Main function to run the optimization with evaluation"""
    print(f"\nRunning optimization with maximum {max_vehicles} vehicles per bucket...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df, max_total_vehicles_per_bucket=max_vehicles)
    optimized_results = optimizer.get_optimized_results()
    
    # Evaluate solutions for each size-distance bucket
    evaluations = []
    for size_distance in optimizer.vehicles_by_size_distance.keys():
        # Get all vehicles for this bucket
        vehicles = optimizer.vehicles_by_size_distance[size_distance]
        
        # Create solution dictionary with all vehicle types initialized to 0
        solution = {v['vehicle_type']: 0 for v in vehicles}
        
        # Update with optimized results
        bucket_results = optimized_results[
            optimized_results['Allocation'] == f"Size {size_distance[0]}, Distance {size_distance[1]}"
        ]
        for _, row in bucket_results.iterrows():
            solution[row['Vehicle']] = row['no_of_vehicles']
        
        evaluation = optimizer.evaluate_solution(solution, size_distance)
        evaluations.append(evaluation)
        
        print(f"\nEvaluation for Size {size_distance[0]}, Distance {size_distance[1]}:")
        print(f"Solution Score: {evaluation['solution_score']}/100")
        print(f"Demand Coverage: {evaluation['demand_evaluation']['coverage_ratio']:.2f}")
        print(f"Cost per km: ${evaluation['cost_evaluation']['cost_per_km']:.2f}")
        print(f"Average TOPSIS Score: {evaluation['fleet_evaluation']['average_topsis']:.2f}")
    
    return optimized_results, evaluations

# 6. Existing if __name__ == "__main__" block
if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df, evaluations = main(csv_path, max_vehicles=10)
    print(results_df)
    print(evaluations)
# Out:
# Running optimization with maximum 10 vehicles per bucket...
#
# Evaluation for Size S1, Distance D1:
# Solution Score: 70.18/100
# Demand Coverage: 2.35
# Cost per km: $0.55
# Average TOPSIS Score: 0.91
#
# Evaluation for Size S1, Distance D2:
# Solution Score: 56.38/100
# Demand Coverage: 0.79
# Cost per km: $0.18
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S1, Distance D3:
# Solution Score: 50.85/100
# Demand Coverage: 0.62
# Cost per km: $0.14
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S1, Distance D4:
# Solution Score: 66.42/100
# Demand Coverage: 4.92
# Cost per km: $1.14
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S2, Distance D1:
# Solution Score: 70.18/100
# Demand Coverage: 2.02
# Cost per km: $0.51
# Average TOPSIS Score: 0.91
#
# Evaluation for Size S2, Distance D2:
# Solution Score: 70.19/100
# Demand Coverage: 1.53
# Cost per km: $0.41
# Average TOPSIS Score: 0.94
#
# Evaluation for Size S2, Distance D3:
# Solution Score: 70.19/100
# Demand Coverage: 2.72
# Cost per km: $0.68
# Average TOPSIS Score: 0.97
#
# Evaluation for Size S2, Distance D4:
# Solution Score: 47.77/100
# Demand Coverage: 15.86
# Cost per km: $3.96
# Average TOPSIS Score: 0.97
#
# Evaluation for Size S3, Distance D1:
# Solution Score: 52.47/100
# Demand Coverage: 0.67
# Cost per km: $0.21
# Average TOPSIS Score: 0.89
#
# Evaluation for Size S3, Distance D2:
# Solution Score: 50.21/100
# Demand Coverage: 0.60
# Cost per km: $0.18
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S3, Distance D3:
# Solution Score: 70.19/100
# Demand Coverage: 1.46
# Cost per km: $0.45
# Average TOPSIS Score: 0.95
#
# Evaluation for Size S3, Distance D4:
# Solution Score: 54.4/100
# Demand Coverage: 7.11
# Cost per km: $2.11
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S4, Distance D1:
# Solution Score: 40.79/100
# Demand Coverage: 161.91
# Cost per km: $48.70
# Average TOPSIS Score: 0.87
#
# Evaluation for Size S4, Distance D2:
# Solution Score: 70.19/100
# Demand Coverage: 3.13
# Cost per km: $0.90
# Average TOPSIS Score: 0.95
#
# Evaluation for Size S4, Distance D3:
# Solution Score: 45.73/100
# Demand Coverage: 19.85
# Cost per km: $5.42
# Average TOPSIS Score: 0.98
#
# Evaluation for Size S4, Distance D4:
# Solution Score: 40.28/100
# Demand Coverage: 1304.59
# Cost per km: $356.56
# Average TOPSIS Score: 0.98
#               Allocation Vehicle   Cost ($)         Fuel  no_of_vehicles
# 0   Size S1, Distance D1     LNG  230778.80          LNG              10
# 1   Size S1, Distance D2     LNG  230778.80          LNG              10
# 2   Size S1, Distance D3     LNG  230778.80          LNG              10
# 3   Size S1, Distance D4     LNG  230778.80          LNG              10
# 4   Size S2, Distance D1     BEV   34551.81  Electricity               1
# 5   Size S2, Distance D1     LNG  231289.76          LNG               9
# 6   Size S2, Distance D2  Diesel   35208.47          B20               1
# 7   Size S2, Distance D2     LNG  231289.76          LNG               9
# 8   Size S2, Distance D3     LNG  256988.62          LNG              10
# 9   Size S2, Distance D4     LNG  256988.62          LNG              10
# 10  Size S3, Distance D1  Diesel   27061.34          B20               1
# 11  Size S3, Distance D1     LNG  191160.47          LNG               9
# 12  Size S3, Distance D2     LNG  212400.52          LNG              10
# 13  Size S3, Distance D3  Diesel   27061.34          B20               1
# 14  Size S3, Distance D3     LNG  191160.47          LNG               9
# 15  Size S3, Distance D4     LNG  212400.52          LNG              10
# 16  Size S4, Distance D1  Diesel   81488.81          B20               2
# 17  Size S4, Distance D1     LNG  252599.45          LNG               8
# 18  Size S4, Distance D2  Diesel   40744.40          B20               1
# 19  Size S4, Distance D2     LNG  284174.38          LNG               9
# 20  Size S4, Distance D3     LNG  315749.31          LNG              10
# 21  Size S4, Distance D4     LNG  315749.31          LNG              10
# [{'size_distance': ('S1', 'D1'), 'solution_score': 70.18, 'demand_evaluation': {'total_capacity': 2040000, 'demand': 869181, 'coverage_ratio': 2.3470370383153796, 'is_demand_met': True, 'capacity_surplus': 1170819, 'capacity_deficit': 0}, 'cost_evaluation': {'total_cost': 474035.3238144, 'cost_breakdown': {'insurance': 100000.0, 'maintenance': 20000.0, 'fuel': 354035.3238144}, 'cost_per_km': 0.5453815992461869}, 'fleet_evaluation': {'total_vehicles': 10, 'composition': {'BEV': {'count': 0, 'percentage': 0.0, 'topsis_score': 0.9185906587600152, 'weighted_topsis': 0.0}, 'Diesel': {'count': 0, 'percentage': 0.0, 'topsis_score': 0.6692797328648972, 'weighted_topsis': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0, 'topsis_score': 0.9121291046947534, 'weighted_topsis': 9.121291046947533}}, 'average_topsis': 0.9121291046947533}, 'sustainability_evaluation': {'fuel_distribution': {'Electricity': {'count': 0, 'percentage': 0.0}, 'B20': {'count': 0, 'percentage': 0.0}, 'HVO': {'count': 0, 'percentage': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0}, 'BioLNG': {'count': 10, 'percentage': 100.0}}}}, {'size_distance': ('S1', 'D2'), 'solution_score': 56.38, 'demand_evaluation': {'total_capacity': 2040000, 'demand': 2597094, 'coverage_ratio': 0.7854933244618794, 'is_demand_met': False, 'capacity_surplus': 0, 'capacity_deficit': 557094}, 'cost_evaluation': {'total_cost': 474035.3238144, 'cost_breakdown': {'insurance': 100000.0, 'maintenance': 20000.0, 'fuel': 354035.3238144}, 'cost_per_km': 0.182525285497714}, 'fleet_evaluation': {'total_vehicles': 10, 'composition': {'Diesel': {'count': 0, 'percentage': 0.0, 'topsis_score': 0.6649982889603409, 'weighted_topsis': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0, 'topsis_score': 0.977907476157084, 'weighted_topsis': 9.77907476157084}}, 'average_topsis': 0.977907476157084}, 'sustainability_evaluation': {'fuel_distribution': {'B20': {'count': 0, 'percentage': 0.0}, 'HVO': {'count': 0, 'percentage': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0}, 'BioLNG': {'count': 10, 'percentage': 100.0}}}}, {'size_distance': ('S1', 'D3'), 'solution_score': 50.85, 'demand_evaluation': {'total_capacity': 2040000, 'demand': 3292011, 'coverage_ratio': 0.6196820119981373, 'is_demand_met': False, 'capacity_surplus': 0, 'capacity_deficit': 1252011}, 'cost_evaluation': {'total_cost': 474035.3238144, 'cost_breakdown': {'insurance': 100000.0, 'maintenance': 20000.0, 'fuel': 354035.3238144}, 'cost_per_km': 0.14399566824485094}, 'fleet_evaluation': {'total_vehicles': 10, 'composition': {'Diesel': {'count': 0, 'percentage': 0.0, 'topsis_score': 0.6649982889603409, 'weighted_topsis': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0, 'topsis_score': 0.977907476157084, 'weighted_topsis': 9.77907476157084}}, 'average_topsis': 0.977907476157084}, 'sustainability_evaluation': {'fuel_distribution': {'B20': {'count': 0, 'percentage': 0.0}, 'HVO': {'count': 0, 'percentage': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0}, 'BioLNG': {'count': 10, 'percentage': 100.0}}}}, {'size_distance': ('S1', 'D4'), 'solution_score': 66.42, 'demand_evaluation': {'total_capacity': 2040000, 'demand': 414315, 'coverage_ratio': 4.923789870026429, 'is_demand_met': True, 'capacity_surplus': 1625685, 'capacity_deficit': 0}, 'cost_evaluation': {'total_cost': 474035.3238144, 'cost_breakdown': {'insurance': 100000.0, 'maintenance': 20000.0, 'fuel': 354035.3238144}, 'cost_per_km': 1.1441423163882554}, 'fleet_evaluation': {'total_vehicles': 10, 'composition': {'Diesel': {'count': 0, 'percentage': 0.0, 'topsis_score': 0.6649982889603409, 'weighted_topsis': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0, 'topsis_score': 0.977907476157084, 'weighted_topsis': 9.77907476157084}}, 'average_topsis': 0.977907476157084}, 'sustainability_evaluation': {'fuel_distribution': {'B20': {'count': 0, 'percentage': 0.0}, 'HVO': {'count': 0, 'percentage': 0.0}, 'LNG': {'count': 10, 'percentage': 100.0}, 'BioLNG': {'count': 10, 'percentage': 100.0}}}}, {'size_distance': ('S2', ' ...

# %%
# 1. Existing imports
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np

# 2. Add FleetEvaluator class here
class FleetEvaluator:
    # [Paste the entire FleetEvaluator class code here]

# 3. Existing load_and_preprocess_data function
def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    # [Your existing function code]

# 4. Existing FleetOptimizer class
class FleetOptimizer:
    # [All your existing FleetOptimizer methods]
    
    # Add this new method inside the FleetOptimizer class
    def evaluate_solution(self, solution: Dict, size_distance: Tuple) -> Dict:
        """Evaluate a given solution using the FleetEvaluator"""
        vehicles = self.vehicles_by_size_distance[size_distance]
        evaluator = FleetEvaluator(solution, vehicles, size_distance)
        return evaluator.get_comprehensive_evaluation()

    # Your existing get_optimized_results method
    def get_optimized_results(self):
        # [Your existing method code]

# 5. Replace your existing main function with this version
def main(csv_path: str, max_vehicles: int = 10):
    """Main function to run the optimization with evaluation"""
    print(f"\nRunning optimization with maximum {max_vehicles} vehicles per bucket...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df, max_total_vehicles_per_bucket=max_vehicles)
    optimized_results = optimizer.get_optimized_results()
    
    # Evaluate solutions for each size-distance bucket
    evaluations = []
    for size_distance in optimizer.vehicles_by_size_distance.keys():
        solution = {row['Vehicle']: row['no_of_vehicles'] 
                   for _, row in optimized_results.iterrows() 
                   if row['Allocation'] == f"Size {size_distance[0]}, Distance {size_distance[1]}"}
        evaluation = optimizer.evaluate_solution(solution, size_distance)
        evaluations.append(evaluation)
        
        print(f"\nEvaluation for Size {size_distance[0]}, Distance {size_distance[1]}:")
        print(f"Solution Score: {evaluation['solution_score']}/100")
        print(f"Demand Coverage: {evaluation['demand_evaluation']['coverage_ratio']:.2f}")
        print(f"Cost per km: ${evaluation['cost_evaluation']['cost_per_km']:.2f}")
        print(f"Average TOPSIS Score: {evaluation['fleet_evaluation']['average_topsis']:.2f}")
    
    return optimized_results, evaluations

# 6. Existing if __name__ == "__main__" block
if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df, evaluations = main(csv_path, max_vehicles=10)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    if 'Total_Cost' not in df.columns:
        df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range']
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "data/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle   Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  207700.92          LNG               9
# 1   Size S1, Distance D2  Diesel  262969.75          B20               8
# 2   Size S1, Distance D2     LNG  415401.83          LNG              18
# 3   Size S1, Distance D3  Diesel  525939.50          B20              16
# 4   Size S1, Distance D3     LNG  392323.95          LNG              17
# 5   Size S1, Distance D4     LNG  115389.40          LNG               5
# 6   Size S2, Distance D1     LNG  256988.62          LNG              10
# 7   Size S2, Distance D2     LNG  359784.07          LNG              14
# 8   Size S2, Distance D3     LNG  205590.90          LNG               8
# 9   Size S2, Distance D4     LNG   51397.72          LNG               2
# 10  Size S3, Distance D1     BEV   93354.33  Electricity               3
# 11  Size S3, Distance D1  Diesel  243552.09          B20               9
# 12  Size S3, Distance D1     LNG  382320.93          LNG              18
# 13  Size S3, Distance D2  Diesel  324736.12          B20              12
# 14  Size S3, Distance D2     LNG  467281.14          LNG              22
# 15  Size S3, Distance D3     LNG  297360.72          LNG              14
# 16  Size S3, Distance D4     LNG   63720.16          LNG               3
# 17  Size S4, Distance D1     LNG   31574.93          LNG               1
# 18  Size S4, Distance D2     LNG  221024.52          LNG               7
# 19  Size S4, Distance D3     LNG   63149.86          LNG               2
# 20  Size S4, Distance D4     LNG   31574.93          LNG               1
#
#     Max Vehicles   Demand  Yearly Range
# 0              9   869181        102000
# 1             26  2597094        102000
# 2             26  2597094        102000
# 3             33  3292011        102000
# 4             33  3292011        102000
# 5              5   414315        102000
# 6             10   995694        106000
# 7             14  1383196        106000
# 8              8   778008        106000
# 9              2   133677        106000
# 10            30  2183475         73000
# 11            30  2183475         73000
# 12            30  2183475         73000
# 13            34  2431901         73000
# 14            34  2431901         73000
# 15            14  1002466         73000
# 16             3   205426         73000
# 17             1    14576        118000
# 18             7   754717        118000
# 19             2   118899        118000
# 20             1     1809        118000

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_x': 'Distance_x',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')

    # Calculate Total Cost if missing
    # if 'Total_Cost' not in df.columns:
    #     df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_x) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_x'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost ($)'],
                'fuel_costs': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs']+
            vehicle['Cost ($)']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        "Total_Cost":vehicle_data['Total_Cost']
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    # results_df.to_csv("optimized_fleet_allocation.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distance_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 272
#     270 if __name__ == "__main__":
#     271     csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
# --> 272     results_df = main(csv_path)
#
# Cell In[1], line 264, in main(csv_path)
#     262 print("\nRunning optimization with dynamic maximum vehicles...")
#     263 data_df = load_and_preprocess_data(csv_path)
# --> 264 optimizer = FleetOptimizer(data_df)
#     265 optimized_results = optimizer.get_optimized_results()
#     266 print("\nOptimized Fleet Allocation:")
#
# Cell In[1], line 37, in FleetOptimizer.__init__(self, data)
#      35 def __init__(self, data: pd.DataFrame):
#      36     self.data = data
# ---> 37     self.vehicles_by_size_distance = self._group_vehicles()
#      38     self.max_vehicles_by_group = self._calculate_max_vehicles()
#
# Cell In[1], line 44, in FleetOptimizer._group_vehicles(self)
#      42 groups = {}
#      43 for _, row in self.data.iterrows():
# ---> 44     key = (row['Size'], row['Distance_x'])
#      45     if key not in groups:
#      46         groups[key] = []
#
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\hjain\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Distance_x'
