# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    print("Columns after renaming:", df.columns)


    # Calculate Total Cost if missing
    # if 'Total_Cost' not in df.columns:
    #     df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs_per_km']+
            vehicle['Cost ($)']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        # "Total_Cost":vehicle_data['Total_Cost']
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    results_df
    results_df.to_csv("optimized_fleet_allocation_2023.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
# Columns after renaming: Index(['Allocation', 'Operating Year', 'Size', 'Distance_demand', 'Demand',
#        'ID', 'Vehicle', 'Available Year', 'Cost', 'Yearly_Range',
#        'Distance_vehicle', 'Fuel', 'carbon_emissions_per_km', 'Insurance_Cost',
#        'Maintenance_Cost', 'Fuel_Costs', 'Total_Cost', 'Topsis_Score', 'Rank',
#        'Distance'],
#       dtype='object')
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG   954001.51          LNG               9
# 1   Size S1, Distance D2  Diesel   720802.18          B20               8
# 2   Size S1, Distance D2     LNG  1908003.01          LNG              18
# 3   Size S1, Distance D3  Diesel  1081203.27          B20              12
# 4   Size S1, Distance D3     LNG  2226003.52          LNG              21
# 5   Size S1, Distance D4     LNG   530000.84          LNG               5
# 6   Size S2, Distance D1  Diesel   551201.37          B20               5
# 7   Size S2, Distance D1     LNG   704900.84          LNG               5
# 8   Size S2, Distance D2  Diesel   661441.64          B20               6
# 9   Size S2, Distance D2     LNG  1127841.34          LNG               8
# 10  Size S2, Distance D3     LNG  1127841.34          LNG               8
# 11  Size S2, Distance D4     LNG   281960.33          LNG               2
# 12  Size S3, Distance D1     BEV  1638177.86  Electricity               5
# 13  Size S3, Distance D1  Diesel  1252721.34          B20              10
# 14  Size S3, Distance D1     LNG  2403064.90          LNG              15
# 15  Size S3, Distance D2  Diesel  1503265.60          B20              12
# 16  Size S3, Distance D2     LNG  3524495.19          LNG              22
# 17  Size S3, Distance D3  Diesel   876904.93          B20               7
# 18  Size S3, Distance D3     LNG  1121430.29          LNG               7
# 19  Size S3, Distance D4     LNG   480612.98          LNG               3
# 20  Size S4, Distance D1     LNG   205061.41          LNG               1
# 21  Size S4, Distance D2     LNG  1435429.86          LNG               7
# 22  Size S4, Distance D3     LNG   410122.82          LNG               2
# 23  Size S4, Distance D4     LNG   205061.41          LNG               1
#
#     Max Vehicles   Demand  Yearly Range
# 0              9   869181        102000
# 1             26  2597094        102000
# 2             26  2597094        102000
# 3             33  3292011        102000
# 4             33  3292011        102000
# 5              5   414315        102000
# 6             10   995694        106000
# 7             10   995694        106000
# 8             14  1383196        106000
# 9             14  1383196        106000
# 10             8   778008        106000
# 11             2   133677        106000
# 12            30  2183475         73000
# 13            30  2183475         73000
# 14            30  2183475         73000
# 15            34  2431901         73000
# 16            34  2431901         73000
# 17            14  1002466         73000
# 18            14  1002466         73000
# 19             3   205426         73000
# 20             1    14576        118000
# 21             7   754717        118000
# 22             2   118899        118000
# 23             1     1809        118000

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    return df

def load_previous_optimization(csv_path: str) -> pd.DataFrame:
    """Load the previously optimized fleet allocation results."""
    try:
        return pd.read_csv(csv_path)
    except FileNotFoundError:
        print(f"Warning: Previous optimization file {csv_path} not found.")
        return None

def extract_size_number(size_str: str) -> int:
    """Extract the numeric part from size string (e.g., 'S1' -> 1)"""
    return int(size_str.replace('S', ''))

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame, previous_optimization: pd.DataFrame = None):
        self.data = data
        self.previous_optimization = previous_optimization
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
        self.previous_allocation = self._process_previous_allocation()
    
    def _process_previous_allocation(self) -> Dict:
        """Process previous year's allocation into a usable format"""
        if self.previous_optimization is None:
            return {}
        
        previous_allocation = {}
        for _, row in self.previous_optimization.iterrows():
            try:
                # Extract size and distance from allocation string
                allocation_parts = row['Allocation'].split(', ')
                # Handle 'Size S1' format
                size_str = allocation_parts[0].split(' ')[1]  # Gets 'S1'
                size = extract_size_number(size_str)  # Converts 'S1' to 1
                distance = allocation_parts[1].split(' ')[1]
                
                key = (size, distance)
                if key not in previous_allocation:
                    previous_allocation[key] = {}
                
                previous_allocation[key][row['Vehicle']] = {
                    'num_vehicles': row['no_of_vehicles'],
                    'yearly_range': row['Yearly Range'],
                    'demand': row['Demand']
                }
            except (IndexError, ValueError) as e:
                print(f"Warning: Could not process row {row['Allocation']}: {e}")
                continue
        
        return previous_allocation

    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)': row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            demand = vehicles[0]['demand']
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        return max_vehicles

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population with bias towards previous year's allocation"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        # Add previous year's allocation if available
        if size_distance in self.previous_allocation:
            prev_solution = {v['vehicle_type']: 0 for v in vehicles}
            for vehicle_type, data in self.previous_allocation[size_distance].items():
                if vehicle_type in prev_solution:
                    prev_solution[vehicle_type] = data['num_vehicles']
            if self.is_valid_solution(prev_solution, size_distance):
                population.append(prev_solution)
        
        # Generate rest of the population
        while len(population) < population_size:
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs_per_km'] +
            vehicle['Cost ($)']
        )

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """Enhanced fitness function considering previous year's allocation"""
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        cost_score = 1 / (total_cost + 1)
        
        alignment_bonus = 0
        if size_distance in self.previous_allocation:
            prev_allocation = self.previous_allocation[size_distance]
            for vehicle_type, num_vehicles in solution.items():
                if vehicle_type in prev_allocation:
                    prev_num = prev_allocation[vehicle_type]['num_vehicles']
                    alignment_bonus += 10 / (abs(num_vehicles - prev_num) + 1)
        
        return weighted_topsis + cost_score - demand_penalty + alignment_bonus

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results with year-over-year comparison"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)
                    
                    # Get previous year's allocation for comparison
                    prev_vehicles = 0
                    if (size_distance in self.previous_allocation and 
                        vehicle_type in self.previous_allocation[size_distance]):
                        prev_vehicles = self.previous_allocation[size_distance][vehicle_type]['num_vehicles']

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Previous_Year_Vehicles": prev_vehicles,
                        "Vehicle_Change": num_vehicles - prev_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range']
                    })

        return pd.DataFrame(results)

def main(csv_path_2024: str, previous_optimization_path: str):
    """Main function to run the optimization with year-over-year comparison"""
    print("\nLoading 2024 data and previous optimization results...")
    data_df_2024 = load_and_preprocess_data(csv_path_2024)
    previous_optimization = load_previous_optimization(previous_optimization_path)
    
    print("\nRunning optimization for 2024 fleet...")
    optimizer = FleetOptimizer(data_df_2024, previous_optimization)
    optimized_results = optimizer.get_optimized_results()
    
    print("\nOptimized Fleet Allocation for 2024:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path_2024 = "topsis_result/topsis_results_2024.csv"
    previous_optimization_path = "optimized_fleet_allocation.csv"
    results_df = main(csv_path_2024, previous_optimization_path)
    results_df.to_csv("optimized_fleet_allocation_2024.csv", index=False)
# Out:
# Loading 2024 data and previous optimization results...
#
# Running optimization for 2024 fleet...
#
# Optimized Fleet Allocation for 2024:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG   982621.50          LNG               9
# 1   Size S1, Distance D2  Diesel  1113639.34          B20              12
# 2   Size S1, Distance D2     LNG  1637702.50          LNG              15
# 3   Size S1, Distance D3  Diesel  1299245.89          B20              14
# 4   Size S1, Distance D3     LNG  2074423.16          LNG              19
# 5   Size S1, Distance D4     LNG   545900.83          LNG               5
# 6   Size S2, Distance D1  Diesel   340642.44          B20               3
# 7   Size S2, Distance D1     LNG  1016466.96          LNG               7
# 8   Size S2, Distance D2  Diesel   454189.92          B20               4
# 9   Size S2, Distance D2     LNG  1452095.66          LNG              10
# 10  Size S2, Distance D3     LNG  1161676.53          LNG               8
# 11  Size S2, Distance D4     LNG   290419.13          LNG               2
# 12  Size S3, Distance D1     BEV   622508.65  Electricity               2
# 13  Size S3, Distance D1  Diesel  1548370.79          B20              12
# 14  Size S3, Distance D1     LNG  2805176.22          LNG              17
# 15  Size S3, Distance D2  Diesel  1161278.09          B20               9
# 16  Size S3, Distance D2     LNG  4125259.14          LNG              25
# 17  Size S3, Distance D3  Diesel   258061.80          B20               2
# 18  Size S3, Distance D3     LNG  2145134.75          LNG              13
# 19  Size S3, Distance D4     LNG   495031.10          LNG               3
# 20  Size S4, Distance D1     LNG   211213.65          LNG               1
# 21  Size S4, Distance D2     LNG  1478495.54          LNG               7
# 22  Size S4, Distance D3     LNG   422427.30          LNG               2
# 23  Size S4, Distance D4     LNG   211213.65          LNG               1
#
#     Previous_Year_Vehicles  Vehicle_Change  Max Vehicles   Demand  \
# 0                        0               9             9   877242
# 1                        0              12            27  2716195
# 2                        0              15            27  2716195
# 3                        0              14            33  3336604
# 4                        0              19            33  3336604
# 5                        0               5             5   419981
# 6                        0               3            10  1043209
# 7                        0               7            10  1043209
# 8                        0               4            14  1391987
# 9                        0              10            14  1391987
# 10                       0               8             8   807076
# 11                       0               2             2   133712
# 12                       0               2            31  2239440
# 13                       0              12            31  2239440
# 14                       0              17            31  2239440
# 15                       0               9            34  2453497
# 16                       0              25            34  2453497
# 17                       0               2            15  1029375
# 18                       0              13            15  1029375
# 19                       0               3             3   208440
# 20                       0               1             1    15200
# 21                       0               7             7   780979
# 22                       0               2             2   122186
# 23                       0               1             1     1893
#
#     Yearly Range
# 0         102000
# 1         102000
# 2         102000
# 3         102000
# 4         102000
# 5         102000
# 6         106000
# 7         106000
# 8         106000
# 9         106000
# 10        106000
# 11        106000
# 12         73000
# 13         73000
# 14         73000
# 15         73000
# 16         73000
# 17         73000
# 18         73000
# 19         73000
# 20        118000
# 21        118000
# 22        118000
# 23        118000

# %%
import pandas as pd
import numpy as np
from typing import Tuple, Dict

def compare_fleet_allocations(results_2023: pd.DataFrame, results_2024: pd.DataFrame) -> pd.DataFrame:
    """
    Compare fleet allocations between 2023 and 2024 and identify improvements
    
    Parameters:
    results_2023: DataFrame with 2023 optimization results
    results_2024: DataFrame with 2024 optimization results
    
    Returns:
    DataFrame with side-by-side comparison and improvement metrics
    """
    # Create a unique identifier for each size-distance combination
    def extract_size_distance(allocation: str) -> Tuple[str, str]:
        size = allocation.split(',')[0].replace('Size ', '').strip()
        distance = allocation.split(',')[1].replace('Distance ', '').strip()
        return (size, distance)
    
    # Process each year's results
    def process_results(df: pd.DataFrame) -> Dict:
        processed = {}
        for _, row in df.iterrows():
            key = extract_size_distance(row['Allocation'])
            if key not in processed:
                processed[key] = {
                    'total_cost': 0,
                    'total_vehicles': 0,
                    'vehicles': [],
                    'demand': row['Demand'],
                    'yearly_range': 0
                }
            processed[key]['total_cost'] += row['Cost ($)']
            processed[key]['total_vehicles'] += row['no_of_vehicles']
            processed[key]['vehicles'].append(f"{row['Vehicle']} ({row['no_of_vehicles']})")
            processed[key]['yearly_range'] += row['Yearly Range'] * row['no_of_vehicles']
        return processed

    results_2023_proc = process_results(results_2023)
    results_2024_proc = process_results(results_2024)

    # Create comparison DataFrame
    comparison_data = []
    all_keys = set(results_2023_proc.keys()) | set(results_2024_proc.keys())
    
    for key in all_keys:
        data_2023 = results_2023_proc.get(key, {})
        data_2024 = results_2024_proc.get(key, {})
        
        if data_2023 and data_2024:
            cost_diff = data_2024['total_cost'] - data_2023['total_cost']
            cost_pct_change = (cost_diff / data_2023['total_cost']) * 100
            vehicle_diff = data_2024['total_vehicles'] - data_2023['total_vehicles']
            
            comparison_data.append({
                'Size': key[0],
                'Distance': key[1],
                '2023_Cost': data_2023['total_cost'],
                '2024_Cost': data_2024['total_cost'],
                'Cost_Difference': cost_diff,
                'Cost_Change_%': cost_pct_change,
                '2023_Vehicles': data_2023['total_vehicles'],
                '2024_Vehicles': data_2024['total_vehicles'],
                'Vehicle_Difference': vehicle_diff,
                '2023_Fleet_Mix': ', '.join(data_2023['vehicles']),
                '2024_Fleet_Mix': ', '.join(data_2024['vehicles']),
                'Demand': data_2023['demand'],
                '2023_Yearly_Range': data_2023['yearly_range'],
                '2024_Yearly_Range': data_2024['yearly_range']
            })
    
    comparison_df = pd.DataFrame(comparison_data)
    comparison_df.sort_values(['Size', 'Distance'], inplace=True)
    
    # Add analysis flags
    comparison_df['Better_In_2024'] = comparison_df.apply(
        lambda x: 'Yes' if x['Cost_Difference'] < 0 and 
                          x['2024_Yearly_Range'] >= x['Demand'] else 'No', 
        axis=1
    )
    
    return comparison_df

def main():
    # Load the optimization results
    results_2023 = pd.read_csv("optimized_fleet_allocation_2023.csv")
    results_2024 = pd.read_csv("optimized_fleet_allocation_2024.csv")
    
    # Compare the results
    comparison = compare_fleet_allocations(results_2023, results_2024)
    
    # Display summary of improvements
    print("\nFleet Allocation Comparison Summary:")
    print(f"Total combinations analyzed: {len(comparison)}")
    improved_count = len(comparison[comparison['Better_In_2024'] == 'Yes'])
    print(f"Combinations with improvements in 2024: {improved_count}")
    
    # Display detailed improvements
    print("\nDetailed improvements (where 2024 allocation is better):")
    improvements = comparison[comparison['Better_In_2024'] == 'Yes'].copy()
    improvements['Cost_Savings'] = -improvements['Cost_Difference']
    
    if len(improvements) > 0:
        print(improvements[[
            'Size', 'Distance', '2023_Cost', '2024_Cost', 
            'Cost_Savings', '2023_Fleet_Mix', '2024_Fleet_Mix'
        ]].to_string())
    else:
        print("No combinations showed improvement in 2024")
    
    # Save detailed comparison
    comparison.to_csv("fleet_allocation_comparison.csv", index=False)
    return comparison

if __name__ == "__main__":
    comparison_results = main()
# Out:
# Fleet Allocation Comparison Summary:
# Total combinations analyzed: 16
# Combinations with improvements in 2024: 1
#
# Detailed improvements (where 2024 allocation is better):
#   Size Distance  2023_Cost   2024_Cost  Cost_Savings                  2023_Fleet_Mix                  2024_Fleet_Mix
# 3   S3       D1  5293964.1  4976055.66     317908.44  BEV (5), Diesel (10), LNG (15)  BEV (2), Diesel (12), LNG (17)

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    print("Columns after renaming:", df.columns)


    # Calculate Total Cost if missing
    # if 'Total_Cost' not in df.columns:
    #     df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def calculate_utilization(self, demand: float, num_vehicles: int, yearly_range: float) -> float:
        """Calculate utilization metric for a vehicle type"""
        if num_vehicles == 0 or yearly_range == 0:
            return 0
        return (demand / num_vehicles) / yearly_range * 100

    def calculate_demand_fulfillment(self, num_vehicles: int, max_vehicles: int) -> float:
        """Calculate demand fulfillment by fuel type"""
        if max_vehicles == 0:
            return 0
        return num_vehicles / max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs_per_km']+
            vehicle['Cost ($)']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    # Calculate evaluation metrics
                    utilization = self.calculate_utilization(
                        vehicle_data['demand'],
                        num_vehicles,
                        vehicle_data['yearly_range']
                    )
                    
                    demand_fulfillment = self.calculate_demand_fulfillment(
                        num_vehicles,
                        max_vehicles
                    )

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        "Utilization": round(utilization, 2),
                        "Demand_Fulfillment": round(demand_fulfillment, 2)
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    return optimized_results

if __name__ == "__main__":
    csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    # results_df.to_csv("optimized_fleet_allocation_2023.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
# Columns after renaming: Index(['Allocation', 'Operating Year', 'Size', 'Distance_demand', 'Demand',
#        'ID', 'Vehicle', 'Available Year', 'Cost', 'Yearly_Range',
#        'Distance_vehicle', 'Fuel', 'carbon_emissions_per_km', 'Insurance_Cost',
#        'Maintenance_Cost', 'Fuel_Costs', 'Total_Cost', 'Topsis_Score', 'Rank',
#        'Distance'],
#       dtype='object')
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG   954001.51          LNG               9
# 1   Size S1, Distance D2  Diesel   901002.72          B20              10
# 2   Size S1, Distance D2     LNG  1696002.68          LNG              16
# 3   Size S1, Distance D3  Diesel  1351504.08          B20              15
# 4   Size S1, Distance D3     LNG  1908003.01          LNG              18
# 5   Size S1, Distance D4     LNG   530000.84          LNG               5
# 6   Size S2, Distance D1     LNG  1409801.67          LNG              10
# 7   Size S2, Distance D2  Diesel   220480.55          B20               2
# 8   Size S2, Distance D2     LNG  1691762.01          LNG              12
# 9   Size S2, Distance D3  Diesel   220480.55          B20               2
# 10  Size S2, Distance D3     LNG   845881.00          LNG               6
# 11  Size S2, Distance D4     LNG   281960.33          LNG               2
# 12  Size S3, Distance D1     BEV  1638177.86  Electricity               5
# 13  Size S3, Distance D1  Diesel  1252721.34          B20              10
# 14  Size S3, Distance D1     LNG  2403064.90          LNG              15
# 15  Size S3, Distance D2  Diesel  1127449.20          B20               9
# 16  Size S3, Distance D2     LNG  4005108.17          LNG              25
# 17  Size S3, Distance D3  Diesel   375816.40          B20               3
# 18  Size S3, Distance D3     LNG  1762247.59          LNG              11
# 19  Size S3, Distance D4     LNG   480612.98          LNG               3
# 20  Size S4, Distance D1     LNG   205061.41          LNG               1
# 21  Size S4, Distance D2     LNG  1435429.86          LNG               7
# 22  Size S4, Distance D3     LNG   410122.82          LNG               2
# 23  Size S4, Distance D4     LNG   205061.41          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   869181        102000        94.68                1.00
# 1             26  2597094        102000       254.62                0.38
# 2             26  2597094        102000       159.14                0.62
# 3             33  3292011        102000       215.16                0.45
# 4             33  3292011        102000       179.30                0.55
# 5              5   414315        102000        81.24                1.00
# 6             10   995694        106000        93.93                1.00
# 7             14  1383196        106000       652.45                0.14
# 8             14  1383196        106000       108.74                0.86
# 9              8   778008        106000       366.98                0.25
# 10             8   778008        106000       122.33                0.75
# 11             2   133677        106000        63.06                1.00
# 12            30  2183475         73000       598.21                0.17
# 13            30  2183475         73000       299.11                0.33
# 14            30  2183475         73000       199.40                0.50
# 15            34  2431901         73000       370.15                0.26
# 16            34  2431901         73000       133.25                0.74
# 17            14  1002466         73000       457.75                0.21
# 18            14  1002466         73000       124.84                0.79
# 19             3   205426         73000        93.80                1.00
# 20             1    14576        118000        12.35                1.00
# 21             7   754717        118000        91.37                1.00
# 22             2   118899        118000        50.38                1.00
# 23             1     1809        118000         1.53                1.00

# %%
# DONE DONE DONE!!!!!!!1

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math
import os


def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    # print("Columns after renaming:", df.columns)


    # Calculate Total Cost if missing
    # if 'Total_Cost' not in df.columns:
    #     df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def calculate_utilization(self, demand: float, num_vehicles: int, yearly_range: float) -> float:
        """Calculate utilization metric for a vehicle type"""
        if num_vehicles == 0 or yearly_range == 0:
            return 0
        return (demand / num_vehicles) / yearly_range * 100

    def calculate_demand_fulfillment(self, num_vehicles: int, max_vehicles: int) -> float:
        """Calculate demand fulfillment by fuel type"""
        if max_vehicles == 0:
            return 0
        return num_vehicles / max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    # def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
    #     """Calculate total cost including insurance, maintenance, and fuel costs"""
    #     return num_vehicles * (
    #         vehicle['insurance_cost'] + 
    #         vehicle['maintenance_cost'] + 
    #         vehicle['fuel_costs_per_km']+
    #         vehicle['Cost ($)']
    #     )

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        if num_vehicles == 0:
            return 0
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['Cost ($)']
        ) + vehicle['fuel_costs_per_km'] * (vehicle['demand'] / num_vehicles)


    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. TOPSIS score
        2. Meeting demand requirements
        3. Total cost
        4. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        weighted_topsis = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
            weighted_topsis += num_vehicles * vehicle['topsis_score']
        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        return weighted_topsis + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    # Calculate evaluation metrics
                    utilization = self.calculate_utilization(
                        vehicle_data['demand'],
                        num_vehicles,
                        vehicle_data['yearly_range']
                    )
                    
                    demand_fulfillment = self.calculate_demand_fulfillment(
                        num_vehicles,
                        max_vehicles
                    )

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        "Utilization": round(utilization, 2),
                        "Demand_Fulfillment": round(demand_fulfillment, 2)
                    })

        return pd.DataFrame(results)


def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    
    # Calculate and print the total cost across all allocations
    total_cost = optimized_results["Cost ($)"].sum()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    print(f"\nTotal Fleet Cost: ${total_cost:,.2f}")
    
    return optimized_results

def process_all_years(input_folder: str, output_folder: str):
    """Process all CSV files in the input folder and save results in the output folder."""
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)  # Create output directory if it doesn't exist
    
    csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]  # List all CSV files
    yearly_costs = []  # Store total cost for each year
    
    for csv_file in csv_files:
        year = csv_file.split('_')[-1].replace('.csv', '')  # Extract year from filename
        csv_path = os.path.join(input_folder, csv_file)
        
        print(f"\nProcessing {csv_file}...")
        results_df = main(csv_path)  # Run optimization
        
        # Calculate total fleet cost
        total_cost = results_df["Cost ($)"].sum()
        yearly_costs.append({"Year": year, "Total Cost ($)": round(total_cost, 2)})
        
        # Save results
        output_file = os.path.join(output_folder, f"optimized_fleet_allocation_{year}.csv")
        results_df.to_csv(output_file, index=False)
        print(f"Results saved to {output_file}")
    
    # Save yearly total cost summary
    # summary_df = pd.DataFrame(yearly_costs)
    # summary_file = os.path.join(output_folder, "yearly_total_cost_summary.csv")
    # summary_df.to_csv(summary_file, index=False)
    # print(f"\nYearly total cost summary saved to {summary_file}")


# def process_all_years(input_folder: str, output_folder: str):
#     """Process all CSV files in the input folder and save results in the output folder."""
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)  # Create output directory if it doesn't exist
    
#     csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]  # List all CSV files
    
#     for csv_file in csv_files:
#         year = csv_file.split('_')[-1].replace('.csv', '')  # Extract year from filename
#         csv_path = os.path.join(input_folder, csv_file)
        
#         print(f"\nProcessing {csv_file}...")
#         results_df = main(csv_path)  # Run optimization
        
#         # Save results
#         output_file = os.path.join(output_folder, f"optimized_fleet_allocation_{year}.csv")
#         results_df.to_csv(output_file, index=False)
#         print(f"Results saved to {output_file}")


if __name__ == "__main__":
    input_folder = "topsis_result"
    output_folder = "fleet_optimization_results"
    process_all_years(input_folder, output_folder)


# if __name__ == "__main__":
#     csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
#     results_df = main(csv_path)
#     # results_df.to_csv("optimized_fleet_allocation_2023.csv", index=False)
# Out:
# Processing topsis_results_2023.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($) Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1  Diesel   298524.59  B20               2
# 1   Size S1, Distance D1     LNG   762789.59  LNG               7
# 2   Size S1, Distance D2  Diesel   971710.26  B20              10
# 3   Size S1, Distance D2     LNG  1723177.00  LNG              16
# 4   Size S1, Distance D3  Diesel  1072582.32  B20              11
# 5   Size S1, Distance D3     LNG  2357053.73  LNG              22
# 6   Size S1, Distance D4     LNG   543873.77  LNG               5
# 7   Size S2, Distance D1     LNG  1426443.93  LNG              10
# 8   Size S2, Distance D2     LNG  1990235.27  LNG              14
# 9   Size S2, Distance D3  Diesel   322859.84  B20               1
# 10  Size S2, Distance D3     LNG  1005438.73  LNG               7
# 11  Size S2, Distance D4     LNG   293132.66  LNG               2
# 12  Size S3, Distance D1  Diesel  1076841.06  B20               8
# 13  Size S3, Distance D1     LNG  3541040.10  LNG              22
# 14  Size S3, Distance D2  Diesel  2291854.09  B20              18
# 15  Size S3, Distance D2     LNG  2588609.74  LNG              16
# 16  Size S3, Distance D3  Diesel   797338.31  B20               6
# 17  Size S3, Distance D3     LNG  1302526.96  LNG               8
# 18  Size S3, Distance D4     LNG   492029.94  LNG               3
# 19  Size S4, Distance D1     LNG   207527.76  LNG               1
# 20  Size S4, Distance D2     LNG  1453673.18  LNG               7
# 21  Size S4, Distance D3     LNG   420182.39  LNG               2
# 22  Size S4, Distance D4     LNG   205367.35  LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   869181        102000       426.07                0.22
# 1              9   869181        102000       121.73                0.78
# 2             26  2597094        102000       254.62                0.38
# 3             26  2597094        102000       159.14                0.62
# 4             33  3292011        102000       293.41                0.33
# 5             33  3292011        102000       146.70                0.67
# 6              5   414315        102000        81.24                1.00
# 7             10   995694        106000        93.93                1.00
# 8             14  1383196        106000        93.21                1.00
# 9              8   778008        106000       733.97                0.12
# 10             8   778008        106000       104.85                0.88
# 11             2   133677        106000        63.06                1.00
# 12            30  2183475         73000       373.88                0.27
# 13            30  2183475         73000       135.96                0.73
# 14            34  2431901         73000       185.08                0.53
# 15            34  2431901         73000       208.21                0.47
# 16            14  1002466         73000       228.87                0.43
# 17            14  1002466         73000       171.66                0.57
# 18             3   205426         73000        93.80                1.00
# 19             1    14576        118000        12.35                1.00
# 20             7   754717        118000        91.37                1.00
# 21             2   118899        118000        50.38                1.00
# 22             1     1809        118000         1.53                1.00
#
# Total Fleet Cost: $27,144,812.57
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2023.csv
#
# Processing topsis_results_2024.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($) Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG   998844.30  LNG               9
# 1   Size S1, Distance D2  Diesel  1264535.56  B20              13
# 2   Size S1, Distance D2     LNG  1560814.02  LNG              14
# 3   Size S1, Distance D3  Diesel  1190949.66  B20              12
# 4   Size S1, Distance D3     LNG  2319226.88  LNG              21
# 5   Size S1, Distance D4     LNG   559881.34  LNG               5
# 6   Size S2, Distance D1     LNG  1469430.31  LNG              10
# 7   Size S2, Distance D2  Diesel   470142.18  B20               3
# 8   Size S2, Distance D2     LNG  1618332.85  LNG              11
# 9   Size S2, Distance D3     LNG  1178440.44  LNG               8
# 10  Size S2, Distance D4     LNG   301529.10  LNG               2
# 11  Size S3, Distance D1  Diesel  1600506.35  B20              12
# 12  Size S3, Distance D1     LNG  3154731.63  LNG              19
# 13  Size S3, Distance D2  Diesel  1358853.33  B20              10
# 14  Size S3, Distance D2     LNG  3977190.71  LNG              24
# 15  Size S3, Distance D3  Diesel   482955.99  B20               3
# 16  Size S3, Distance D3     LNG  1994341.86  LNG              12
# 17  Size S3, Distance D4     LNG   506547.89  LNG               3
# 18  Size S4, Distance D1     LNG   213770.56  LNG               1
# 19  Size S4, Distance D2     LNG  1497263.42  LNG               7
# 20  Size S4, Distance D3     LNG   432704.58  LNG               2
# 21  Size S4, Distance D4     LNG   211531.94  LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   877242        102000        95.56                1.00
# 1             27  2716195        102000       204.84                0.48
# 2             27  2716195        102000       190.21                0.52
# 3             33  3336604        102000       272.60                0.36
# 4             33  3336604        102000       155.77                0.64
# 5              5   419981        102000        82.35                1.00
# 6             10  1043209        106000        98.42                1.00
# 7             14  1391987        106000       437.73                0.21
# 8             14  1391987        106000       119.38                0.79
# 9              8   807076        106000        95.17                1.00
# 10             2   133712        106000        63.07                1.00
# 11            31  2239440         73000       255.64                0.39
# 12            31  2239440         73000       161.46                0.61
# 13            34  2453497         73000       336.10                0.29
# 14            34  2453497         73000       140.04                0.71
# 15            15  1029375         73000       470.03                0.20
# 16            15  1029375         73000       117.51                0.80
# 17             3   208440         73000        95.18                1.00
# 18             1    15200        118000        12.88                1.00
# 19             7   780979        118000        94.55                1.00
# 20             2   122186        118000        51.77                1.00
# 21             1     1893        118000         1.60                1.00
#
# Total Fleet Cost: $28,362,524.90
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2024.csv
#
# Processing topsis_results_2025.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1028236.63          LNG               9
# 1   Size S1, Distance D2  Diesel   865367.23          B20               8
# 2   Size S1, Distance D2     LNG  2272574.79          LNG              20
# 3   Size S1, Distance D3  Diesel  1317901.25          B20              13
# 4   Size S1, Distance D3     LNG  2388718.64          LNG              21
# 5   Size S1, Distance D4     LNG   576831.46          LNG               5
# 6   Size S2, Distance D1     LNG  1661466.09          LNG              11
# 7   Size S2, Distance D2  Diesel   434937.45          B20               2
# 8   Size S2, Distance D2     LNG  1814199.64          LNG              12
# 9   Size S2, Distance D3     LNG  1213488.33          LNG               8
# 10  Size S2, Distance D4     LNG   310465.93          LNG               2
# 11  Size S3, Distance D1     BEV  1006381.57  Electricity               3
# 12  Size S3, Distance D1  Diesel  1393362.26          B20              10
# 13  Size S3, Distance D1     LNG  3079933.64          LNG              18
# 14  Size S3, Distance D2  Diesel  1654292.94          B20              12
# 15  Size S3, Distance D2     LNG  3927010.53          LNG              23
# 16  Size S3, Distance D3  Diesel   498917.56          B20               3
# 17  Size S3, Distance D3     LNG  2053994.68          LNG              12
# 18  Size S3, Distance D4     LNG   521885.82          LNG               3
# 19  Size S4, Distance D1     LNG   220160.64          LNG               1
# 20  Size S4, Distance D2     LNG  1541744.37          LNG               7
# 21  Size S4, Distance D3     LNG   445404.90          LNG               2
# 22  Size S4, Distance D4     LNG   217871.38          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   877707        102000        95.61                1.00
# 1             28  2836223        102000       347.58                0.29
# 2             28  2836223        102000       139.03                0.71
# 3             34  3446113        102000       259.89                0.38
# 4             34  3446113        102000       160.88                0.62
# 5              5   439767        102000        86.23                1.00
# 6             11  1082065        106000        92.80                1.00
# 7             14  1410584        106000       665.37                0.14
# 8             14  1410584        106000       110.89                0.86
# 9              8   821678        106000        96.90                1.00
# 10             2   137231        106000        64.73                1.00
# 11            31  2255136         73000      1029.74                0.10
# 12            31  2255136         73000       308.92                0.32
# 13            31  2255136         73000       171.62                0.58
# 14            35  2501227         73000       285.53                0.34
# 15            35  2501227         73000       148.97                0.66
# 16            15  1053662         73000       481.12                0.20
# 17            15  1053662         73000       120.28                0.80
# 18             3   218537         73000        99.79                1.00
# 19             1    15615        118000        13.23                1.00
# 20             7   791079        118000        95.77                1.00
# 21             2   123252        118000        52.23                1.00
# 22             1     1927        118000         1.63                1.00
#
# Total Fleet Cost: $30,445,147.73
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2025.csv
#
# Processing topsis_results_2026.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1058534.74          LNG               9
# 1   Size S1, Distance D2     BEV   656776.75  Electricity               3
# 2   Size S1, Distance D2  Diesel  1533052.54          B20              15
# 3   Size S1, Distance D2     LNG  1317402.70          LNG              11
# 4   Size S1, Distance D3  Diesel  1087114.43          B20              10
# 5   Size S1, Distance D3     LNG  2918867.26          LNG              25
# 6   Size S1, Distance D4     LNG   593758.52          LNG               5
# 7   Size S2, Distance D1  Diesel   399670.98          B20               2
# 8   Size S2, Distance D1     LNG  1406133.38          LNG               9
# 9   Size S2, Distance D2     LNG  2173565.14          LNG              14
# 10  Size S2, Distance D3     LNG  1249169.12          LNG               8
# 11  Size S2, Distance D4     LNG   319554.68          LNG               2
# 12  Size S3, Distance D1     BEV  1212366.83  Electricity               4
# 13  Size S3, Distance D1  Diesel  1964928.79          B20              14
# 14  Size S3, Distance D1     LNG  2477961.41          LNG              14
# 15  Size S3, Distance D2     BEV  1481470.63  Electricity               5
# 16  Size S3, Distance D2  Diesel  1836144.05          B20              13
# 17  Size S3, Distance D2     LNG  3000221.36          LNG              17
# 18  Size S3, Distance D3  Diesel  1004172.40          B20               7
# 19  Size S3, Distance D3     LNG  1595531.86          LNG               9
# 20  Size S3, Distance D4     LNG   709170.98          LNG               4
# 21  Size S4, Distance D1     LNG   226679.24          LNG               1
# 22  Size S4, Distance D2     LNG  1587094.45          LNG               7
# 23  Size S4, Distance D3     LNG   458513.66          LNG               2
# 24  Size S4, Distance D4     LNG   224401.83          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   884095        102000        96.31                1.00
# 1             29  2909150        102000       950.70                0.10
# 2             29  2909150        102000       190.14                0.52
# 3             29  2909150        102000       259.28                0.38
# 4             35  3537030        102000       346.77                0.29
# 5             35  3537030        102000       138.71                0.71
# 6              5   446478        102000        87.54                1.00
# 7             11  1090703        106000       514.48                0.18
# 8             11  1090703        106000       114.33                0.82
# 9             14  1452683        106000        97.89                1.00
# 10             8   825939        106000        97.40                1.00
# 11             2   141128        106000        66.57                1.00
# 12            32  2329773         73000       797.87                0.12
# 13            32  2329773         73000       227.96                0.44
# 14            32  2329773         73000       227.96                0.44
# 15            35  2524893         73000       691.75                0.14
# 16            35  2524893         73000       266.06                0.37
# 17            35  2524893         73000       203.46                0.49
# 18            16  1103927         73000       216.03                0.44
# 19            16  1103927         73000       168.03                0.56
# 20             4   219181         73000        75.06                1.00
# 21             1    15916        118000        13.49                1.00
# 22             7   794430        118000        96.18                1.00
# 23             2   126715        118000        53.69                1.00
# 24             1     1989        118000         1.69                1.00
#
# Total Fleet Cost: $32,492,257.73
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2026.csv
#
# Processing topsis_results_2027.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1207802.79          LNG              10
# 1   Size S1, Distance D2     BEV  1039949.95  Electricity               6
# 2   Size S1, Distance D2  Diesel   686115.02          B20               5
# 3   Size S1, Distance D2     LNG  2292223.28          LNG              19
# 4   Size S1, Distance D3  Diesel  1495484.08          B20              14
# 5   Size S1, Distance D3     LNG  2650722.93          LNG              22
# 6   Size S1, Distance D4     LNG   611469.35          LNG               5
# 7   Size S2, Distance D1  Diesel   482710.97          B20               3
# 8   Size S2, Distance D1     LNG  1291763.02          LNG               8
# 9   Size S2, Distance D2  Diesel   931383.05          B20               7
# 10  Size S2, Distance D2     LNG  1144659.85          LNG               7
# 11  Size S2, Distance D3  Diesel   376405.35          B20               2
# 12  Size S2, Distance D3     LNG  1130503.92          LNG               7
# 13  Size S2, Distance D4     LNG   329102.67          LNG               2
# 14  Size S3, Distance D1     BEV  1400981.30  Electricity               5
# 15  Size S3, Distance D1  Diesel  2162167.00          B20              15
# 16  Size S3, Distance D1     LNG  2373206.87          LNG              13
# 17  Size S3, Distance D2     BEV  2968456.63  Electricity              11
# 18  Size S3, Distance D2  Diesel  1354644.44          B20               9
# 19  Size S3, Distance D2     LNG  2910764.54          LNG              16
# 20  Size S3, Distance D3  Diesel  1035321.61          B20               7
# 21  Size S3, Distance D3     LNG  1642920.88          LNG               9
# 22  Size S3, Distance D4     LNG   730196.88          LNG               4
# 23  Size S4, Distance D1     LNG   233451.51          LNG               1
# 24  Size S4, Distance D2     LNG  1863023.59          LNG               8
# 25  Size S4, Distance D3     LNG   472010.03          LNG               2
# 26  Size S4, Distance D4     LNG   231122.10          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             10   923004        102000        90.49                1.00
# 1             30  3023153        102000       493.98                0.20
# 2             30  3023153        102000       592.78                0.17
# 3             30  3023153        102000       155.99                0.63
# 4             36  3581681        102000       250.82                0.39
# 5             36  3581681        102000       159.61                0.61
# 6              5   467174        102000        91.60                1.00
# 7             11  1114957        106000       350.62                0.27
# 8             11  1114957        106000       131.48                0.73
# 9             14  1480077        106000       199.47                0.50
# 10            14  1480077        106000       199.47                0.50
# 11             9   862851        106000       407.01                0.22
# 12             9   862851        106000       116.29                0.78
# 13             2   146448        106000        69.08                1.00
# 14            33  2381369         73000       652.43                0.15
# 15            33  2381369         73000       217.48                0.45
# 16            33  2381369         73000       250.93                0.39
# 17            36  2591566         73000       322.74                0.31
# 18            36  2591566         73000       394.45                0.25
# 19            36  2591566         73000       221.88                0.44
# 20            16  1137494         73000       222.60                0.44
# 21            16  1137494         73000       173.13                0.56
# 22             4   224937         73000        77.03                1.00
# 23             1    16532        118000        14.01                1.00
# 24             8   829347        118000        87.85                1.00
# 25             2   129765        118000        54.99                1.00
# 26             1     2019        118000         1.71                1.00
#
# Total Fleet Cost: $35,048,563.61
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2027.csv
#
# Processing topsis_results_2028.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1  Diesel   410960.89          B20               3
# 1   Size S1, Distance D1     LNG   881572.44          LNG               7
# 2   Size S1, Distance D2     BEV  1134039.08  Electricity               7
# 3   Size S1, Distance D2  Diesel   783690.22          B20               6
# 4   Size S1, Distance D2     LNG  2238649.43          LNG              18
# 5   Size S1, Distance D3  Diesel  1741741.25          B20              16
# 6   Size S1, Distance D3     LNG  2608019.81          LNG              21
# 7   Size S1, Distance D4     LNG   628927.98          LNG               5
# 8   Size S2, Distance D1     LNG  1813669.59          LNG              11
# 9   Size S2, Distance D2  Diesel   845050.60          B20               6
# 10  Size S2, Distance D2     LNG  1497214.92          LNG               9
# 11  Size S2, Distance D3     LNG  1486255.71          LNG               9
# 12  Size S2, Distance D4     LNG   338199.24          LNG               2
# 13  Size S3, Distance D1     BEV  1333398.98  Electricity               5
# 14  Size S3, Distance D1  Diesel  2227987.74          B20              15
# 15  Size S3, Distance D1     LNG  2626956.48          LNG              14
# 16  Size S3, Distance D2     BEV  1339297.28  Electricity               5
# 17  Size S3, Distance D2  Diesel  2374280.92          B20              16
# 18  Size S3, Distance D2     LNG  2997145.97          LNG              16
# 19  Size S3, Distance D3  Diesel   496345.33          B20               1
# 20  Size S3, Distance D3     LNG  2797640.64          LNG              15
# 21  Size S3, Distance D4     LNG   751849.04          LNG               4
# 22  Size S4, Distance D1     LNG   240335.62          LNG               1
# 23  Size S4, Distance D2     LNG  1918281.63          LNG               8
# 24  Size S4, Distance D3     LNG   485823.02          LNG               2
# 25  Size S4, Distance D4     LNG   238042.18          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             10   968137        102000       316.38                0.30
# 1             10   968137        102000       135.59                0.70
# 2             31  3114155        102000       436.16                0.23
# 3             31  3114155        102000       508.85                0.19
# 4             31  3114155        102000       169.62                0.58
# 5             37  3731269        102000       228.63                0.43
# 6             37  3731269        102000       174.20                0.57
# 7              5   469168        102000        91.99                1.00
# 8             11  1142178        106000        97.96                1.00
# 9             15  1546703        106000       243.19                0.40
# 10            15  1546703        106000       162.13                0.60
# 11             9   902415        106000        94.59                1.00
# 12             2   148036        106000        69.83                1.00
# 13            34  2448472         73000       670.81                0.15
# 14            34  2448472         73000       223.60                0.44
# 15            34  2448472         73000       239.58                0.41
# 16            37  2667924         73000       730.94                0.14
# 17            37  2667924         73000       228.42                0.43
# 18            37  2667924         73000       228.42                0.43
# 19            16  1155329         73000      1582.64                0.06
# 20            16  1155329         73000       105.51                0.94
# 21             4   233462         73000        79.95                1.00
# 22             1    16863        118000        14.29                1.00
# 23             8   851953        118000        90.25                1.00
# 24             2   133929        118000        56.75                1.00
# 25             1     2066        118000         1.75                1.00
#
# Total Fleet Cost: $36,235,375.99
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2028.csv
#
# Processing topsis_results_2029.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1280951.04          LNG              10
# 1   Size S1, Distance D2     BEV   811639.54  Electricity               5
# 2   Size S1, Distance D2  Diesel  1077683.79          B20               9
# 3   Size S1, Distance D2     LNG  2305016.28          LNG              18
# 4   Size S1, Distance D3     BEV  1092422.62  Electricity               7
# 5   Size S1, Distance D3  Diesel  1391197.74          B20              12
# 6   Size S1, Distance D3     LNG  2560797.21          LNG              20
# 7   Size S1, Distance D4     LNG   647495.70          LNG               5
# 8   Size S2, Distance D1  Diesel   445207.89          B20               2
# 9   Size S2, Distance D1     LNG  1701219.39          LNG              10
# 10  Size S2, Distance D2  Diesel   630376.25          B20               1
# 11  Size S2, Distance D2     LNG  2541361.50          LNG              15
# 12  Size S2, Distance D3     LNG  1530522.52          LNG               9
# 13  Size S2, Distance D4     LNG   347955.30          LNG               2
# 14  Size S3, Distance D1     BEV  1498747.08  Electricity               6
# 15  Size S3, Distance D1  Diesel  1859570.83          B20              12
# 16  Size S3, Distance D1     LNG  3274046.93          LNG              17
# 17  Size S3, Distance D2     BEV  1971814.18  Electricity               8
# 18  Size S3, Distance D2  Diesel  1867277.33          B20              12
# 19  Size S3, Distance D2     LNG  3656663.62          LNG              19
# 20  Size S3, Distance D3  Diesel   958300.68          B20               6
# 21  Size S3, Distance D3     LNG  2120277.96          LNG              11
# 22  Size S3, Distance D4     LNG   773968.87          LNG               4
# 23  Size S4, Distance D1     LNG   247497.15          LNG               1
# 24  Size S4, Distance D2     LNG  1975514.22          LNG               8
# 25  Size S4, Distance D3     LNG   499938.60          LNG               2
# 26  Size S4, Distance D4     LNG   245172.02          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             10  1009629        102000        98.98                1.00
# 1             32  3188349        102000       625.17                0.16
# 2             32  3188349        102000       347.31                0.28
# 3             32  3188349        102000       173.66                0.56
# 4             39  3892298        102000       545.14                0.18
# 5             39  3892298        102000       318.00                0.31
# 6             39  3892298        102000       190.80                0.51
# 7              5   484671        102000        95.03                1.00
# 8             12  1173616        106000       553.59                0.17
# 9             12  1173616        106000       110.72                0.83
# 10            16  1608555        106000      1517.50                0.06
# 11            16  1608555        106000       101.17                0.94
# 12             9   916617        106000        96.08                1.00
# 13             2   148322        106000        69.96                1.00
# 14            35  2497153         73000       570.13                0.17
# 15            35  2497153         73000       285.06                0.34
# 16            35  2497153         73000       201.22                0.49
# 17            39  2795108         73000       478.61                0.21
# 18            39  2795108         73000       319.08                0.31
# 19            39  2795108         73000       201.52                0.49
# 20            17  1175528         73000       268.39                0.35
# 21            17  1175528         73000       146.39                0.65
# 22             4   234155         73000        80.19                1.00
# 23             1    17544        118000        14.87                1.00
# 24             8   885863        118000        93.84                1.00
# 25             2   135803        118000        57.54                1.00
# 26             1     2113        118000         1.79                1.00
#
# Total Fleet Cost: $39,312,636.24
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2029.csv
#
# Processing topsis_results_2030.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1  Diesel   380901.80          B20               2
# 1   Size S1, Distance D1     LNG  1061894.05          LNG               8
# 2   Size S1, Distance D2     BEV   552279.16  Electricity               3
# 3   Size S1, Distance D2  Diesel  1313159.23          B20              11
# 4   Size S1, Distance D2     LNG  2502941.03          LNG              19
# 5   Size S1, Distance D3     BEV  1433771.87  Electricity              10
# 6   Size S1, Distance D3  Diesel  1042627.86          B20               8
# 7   Size S1, Distance D3     LNG  2766018.54          LNG              21
# 8   Size S1, Distance D4     LNG   666743.34          LNG               5
# 9   Size S2, Distance D1  Diesel   525469.10          B20               1
# 10  Size S2, Distance D1     LNG  1924190.82          LNG              11
# 11  Size S2, Distance D2  Diesel   649895.07          B20               1
# 12  Size S2, Distance D2     LNG  2617187.82          LNG              15
# 13  Size S2, Distance D3     LNG  1576139.84          LNG               9
# 14  Size S2, Distance D4     LNG   358538.92          LNG               2
# 15  Size S3, Distance D1     BEV  1869381.59  Electricity               8
# 16  Size S3, Distance D1  Diesel  1767321.60          B20              11
# 17  Size S3, Distance D1     LNG  3176016.30          LNG              16
# 18  Size S3, Distance D2     BEV  1873751.80  Electricity               8
# 19  Size S3, Distance D2  Diesel  2370212.43          B20              15
# 20  Size S3, Distance D2     LNG  3178653.69          LNG              16
# 21  Size S3, Distance D3  Diesel   590747.37          B20               3
# 22  Size S3, Distance D3     LNG  2771418.58          LNG              14
# 23  Size S3, Distance D4     LNG   797119.89          LNG               4
# 24  Size S4, Distance D1     LNG   254920.98          LNG               1
# 25  Size S4, Distance D2     LNG  2034809.06          LNG               8
# 26  Size S4, Distance D3     LNG   514610.95          LNG               2
# 27  Size S4, Distance D4     LNG   252516.11          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             10  1009798        102000       495.00                0.20
# 1             10  1009798        102000       123.75                0.80
# 2             33  3285854        102000      1073.81                0.09
# 3             33  3285854        102000       292.86                0.33
# 4             33  3285854        102000       169.55                0.58
# 5             39  3959514        102000       388.19                0.26
# 6             39  3959514        102000       485.23                0.21
# 7             39  3959514        102000       184.85                0.54
# 8              5   496273        102000        97.31                1.00
# 9             12  1231293        106000      1161.60                0.08
# 10            12  1231293        106000       105.60                0.92
# 11            16  1624238        106000      1532.30                0.06
# 12            16  1624238        106000       102.15                0.94
# 13             9   931478        106000        97.64                1.00
# 14             2   155565        106000        73.38                1.00
# 15            35  2518188         73000       431.20                0.23
# 16            35  2518188         73000       313.60                0.31
# 17            35  2518188         73000       215.60                0.46
# 18            39  2800498         73000       479.54                0.21
# 19            39  2800498         73000       255.75                0.38
# 20            39  2800498         73000       239.77                0.41
# 21            17  1216569         73000       555.51                0.18
# 22            17  1216569         73000       119.04                0.82
# 23             4   240767         73000        82.45                1.00
# 24             1    18168        118000        15.40                1.00
# 25             8   919290        118000        97.38                1.00
# 26             2   136344        118000        57.77                1.00
# 27             1     2114        118000         1.79                1.00
#
# Total Fleet Cost: $40,823,238.80
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2030.csv
#
# Processing topsis_results_2031.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1491206.12          LNG              11
# 1   Size S1, Distance D2     BEV   653084.86  Electricity               4
# 2   Size S1, Distance D2  Diesel  1458512.05          B20              12
# 3   Size S1, Distance D2     LNG  2311807.99          LNG              17
# 4   Size S1, Distance D3     BEV  1168356.91  Electricity               8
# 5   Size S1, Distance D3  Diesel  1691361.27          B20              14
# 6   Size S1, Distance D3     LNG  2450699.17          LNG              18
# 7   Size S1, Distance D4     LNG   818577.06          LNG               6
# 8   Size S2, Distance D1  Diesel   540773.95          B20               1
# 9   Size S2, Distance D1     LNG  1981432.04          LNG              11
# 10  Size S2, Distance D2  Diesel   695159.01          B20               4
# 11  Size S2, Distance D2     LNG  2164231.32          LNG              12
# 12  Size S2, Distance D3  Diesel   444751.74          B20               1
# 13  Size S2, Distance D3     LNG  1446443.03          LNG               8
# 14  Size S2, Distance D4     LNG   369355.08          LNG               2
# 15  Size S3, Distance D1     BEV  1206275.02  Electricity               5
# 16  Size S3, Distance D1  Diesel  2128210.34          B20              13
# 17  Size S3, Distance D1     LNG  3674584.33          LNG              18
# 18  Size S3, Distance D2     BEV  2096372.68  Electricity               9
# 19  Size S3, Distance D2  Diesel  1678014.27          B20              10
# 20  Size S3, Distance D2     LNG  4079755.50          LNG              20
# 21  Size S3, Distance D3  Diesel   558204.48          B20               1
# 22  Size S3, Distance D3     LNG  3258539.09          LNG              16
# 23  Size S3, Distance D4     LNG   820789.82          LNG               4
# 24  Size S4, Distance D1     LNG   262557.59          LNG               1
# 25  Size S4, Distance D2     LNG  2095660.74          LNG               8
# 26  Size S4, Distance D3     LNG   529933.44          LNG               2
# 27  Size S4, Distance D4     LNG   260093.05          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             11  1042251        102000        92.89                1.00
# 1             33  3310718        102000       811.45                0.12
# 2             33  3310718        102000       270.48                0.36
# 3             33  3310718        102000       190.93                0.52
# 4             40  4061449        102000       497.73                0.20
# 5             40  4061449        102000       284.42                0.35
# 6             40  4061449        102000       221.21                0.45
# 7              6   518651        102000        84.75                1.00
# 8             12  1240402        106000      1170.19                0.08
# 9             12  1240402        106000       106.38                0.92
# 10            16  1689196        106000       398.40                0.25
# 11            16  1689196        106000       132.80                0.75
# 12             9   943472        106000       890.07                0.11
# 13             9   943472        106000       111.26                0.89
# 14             2   161977        106000        76.40                1.00
# 15            36  2619164         73000       717.58                0.14
# 16            36  2619164         73000       275.99                0.36
# 17            36  2619164         73000       199.33                0.50
# 18            39  2814164         73000       428.34                0.23
# 19            39  2814164         73000       385.50                0.26
# 20            39  2814164         73000       192.75                0.51
# 21            17  1234148         73000      1690.61                0.06
# 22            17  1234148         73000       105.66                0.94
# 23             4   242813         73000        83.16                1.00
# 24             1    18747        118000        15.89                1.00
# 25             8   941960        118000        99.78                1.00
# 26             2   139696        118000        59.19                1.00
# 27             1     2198        118000         1.86                1.00
#
# Total Fleet Cost: $42,334,741.95
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2031.csv
#
# Processing topsis_results_2032.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1535802.51          LNG              11
# 1   Size S1, Distance D2     BEV  1156831.34  Electricity               8
# 2   Size S1, Distance D2  Diesel  1081582.04          B20               8
# 3   Size S1, Distance D2     LNG  2517804.79          LNG              18
# 4   Size S1, Distance D3     BEV  1433084.73  Electricity              10
# 5   Size S1, Distance D3  Diesel  1526885.35          B20              12
# 6   Size S1, Distance D3     LNG  2797570.57          LNG              20
# 7   Size S1, Distance D4     LNG   843270.27          LNG               6
# 8   Size S2, Distance D1  Diesel   679208.04          B20               4
# 9   Size S2, Distance D1     LNG  1495072.33          LNG               8
# 10  Size S2, Distance D2  Diesel   625178.11          B20               3
# 11  Size S2, Distance D2     LNG  2594028.22          LNG              14
# 12  Size S2, Distance D3  Diesel   539444.83          B20               3
# 13  Size S2, Distance D3     LNG  1308558.96          LNG               7
# 14  Size S2, Distance D4     LNG   380084.29          LNG               2
# 15  Size S3, Distance D1     BEV  2771354.71  Electricity              12
# 16  Size S3, Distance D1  Diesel  1129928.84          B20               6
# 17  Size S3, Distance D1     LNG  4200601.72          LNG              20
# 18  Size S3, Distance D2     BEV  1209362.95  Electricity               5
# 19  Size S3, Distance D2  Diesel  2197700.80          B20              13
# 20  Size S3, Distance D2     LNG  4617887.40          LNG              22
# 21  Size S3, Distance D3  Diesel   628574.37          B20               3
# 22  Size S3, Distance D3     LNG  3147801.30          LNG              15
# 23  Size S3, Distance D4     LNG   845370.56          LNG               4
# 24  Size S4, Distance D1     LNG   270415.97          LNG               1
# 25  Size S4, Distance D2     LNG  2423944.64          LNG               9
# 26  Size S4, Distance D3     LNG   545584.37          LNG               2
# 27  Size S4, Distance D4     LNG   267889.00          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             11  1069740        102000        95.34                1.00
# 1             34  3430934        102000       420.46                0.24
# 2             34  3430934        102000       420.46                0.24
# 3             34  3430934        102000       186.87                0.53
# 4             42  4237026        102000       415.39                0.24
# 5             42  4237026        102000       346.16                0.29
# 6             42  4237026        102000       207.70                0.48
# 7              6   542921        102000        88.71                1.00
# 8             12  1257890        106000       296.67                0.33
# 9             12  1257890        106000       148.34                0.67
# 10            17  1759215        106000       553.21                0.18
# 11            17  1759215        106000       118.55                0.82
# 12            10   980430        106000       308.31                0.30
# 13            10   980430        106000       132.13                0.70
# 14             2   163126        106000        76.95                1.00
# 15            38  2708133         73000       309.15                0.32
# 16            38  2708133         73000       618.30                0.16
# 17            38  2708133         73000       185.49                0.53
# 18            40  2863674         73000       784.57                0.12
# 19            40  2863674         73000       301.76                0.33
# 20            40  2863674         73000       178.31                0.55
# 21            18  1254261         73000       572.72                0.17
# 22            18  1254261         73000       114.54                0.83
# 23             4   250479         73000        85.78                1.00
# 24             1    19298        118000        16.35                1.00
# 25             9   967461        118000        91.10                1.00
# 26             2   141391        118000        59.91                1.00
# 27             1     2230        118000         1.89                1.00
#
# Total Fleet Cost: $44,770,823.01
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2032.csv
#
# Processing topsis_results_2033.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1581371.14          LNG              11
# 1   Size S1, Distance D2     BEV  1693292.37  Electricity              12
# 2   Size S1, Distance D2  Diesel  1015222.16          B20               7
# 3   Size S1, Distance D2     LNG  2311489.28          LNG              16
# 4   Size S1, Distance D3     BEV  1971850.05  Electricity              14
# 5   Size S1, Distance D3  Diesel  1249946.12          B20               9
# 6   Size S1, Distance D3     LNG  2880755.19          LNG              20
# 7   Size S1, Distance D4     LNG   868586.53          LNG               6
# 8   Size S2, Distance D1  Diesel   580892.09          B20               1
# 9   Size S2, Distance D1     LNG  2289461.87          LNG              12
# 10  Size S2, Distance D2  Diesel   645738.12          B20               3
# 11  Size S2, Distance D2     LNG  2671505.62          LNG              14
# 12  Size S2, Distance D3     LNG  1909612.75          LNG              10
# 13  Size S2, Distance D4     LNG   391422.41          LNG               2
# 14  Size S3, Distance D1     BEV  1645750.36  Electricity               7
# 15  Size S3, Distance D1  Diesel  1465899.68          B20               8
# 16  Size S3, Distance D1     LNG  5184483.50          LNG              24
# 17  Size S3, Distance D2     BEV  2999463.61  Electricity              13
# 18  Size S3, Distance D2  Diesel  1321940.19          B20               7
# 19  Size S3, Distance D2     LNG  4542118.48          LNG              21
# 20  Size S3, Distance D3  Diesel   597188.26          B20               1
# 21  Size S3, Distance D3     LNG  3671087.57          LNG              17
# 22  Size S3, Distance D4     LNG   870834.87          LNG               4
# 23  Size S4, Distance D1     LNG   278521.71          LNG               1
# 24  Size S4, Distance D2     LNG  2496836.13          LNG               9
# 25  Size S4, Distance D3     LNG   561934.93          LNG               2
# 26  Size S4, Distance D4     LNG   275914.27          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             11  1070915        102000        95.45                1.00
# 1             35  3491886        102000       285.28                0.34
# 2             35  3491886        102000       489.06                0.20
# 3             35  3491886        102000       213.96                0.46
# 4             43  4290083        102000       300.43                0.33
# 5             43  4290083        102000       467.33                0.21
# 6             43  4290083        102000       210.30                0.47
# 7              6   563313        102000        92.04                1.00
# 8             13  1283026        106000      1210.40                0.08
# 9             13  1283026        106000       100.87                0.92
# 10            17  1790314        106000       562.99                0.18
# 11            17  1790314        106000       120.64                0.82
# 12            10  1007259        106000        95.02                1.00
# 13             2   168141        106000        79.31                1.00
# 14            39  2820991         73000       552.05                0.18
# 15            39  2820991         73000       483.05                0.21
# 16            39  2820991         73000       161.02                0.62
# 17            41  2974170         73000       313.40                0.32
# 18            41  2974170         73000       582.03                0.17
# 19            41  2974170         73000       194.01                0.51
# 20            18  1270139         73000      1739.92                0.06
# 21            18  1270139         73000       102.35                0.94
# 22             4   262313         73000        89.83                1.00
# 23             1    19951        118000        16.91                1.00
# 24             9  1013174        118000        95.40                1.00
# 25             2   146270        118000        61.98                1.00
# 26             1     2236        118000         1.89                1.00
#
# Total Fleet Cost: $47,973,119.26
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2033.csv
#
# Processing topsis_results_2034.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1628424.15          LNG              11
# 1   Size S1, Distance D2     BEV  1557499.10  Electricity              11
# 2   Size S1, Distance D2  Diesel   954600.63          B20               6
# 3   Size S1, Distance D2     LNG  2815699.53          LNG              19
# 4   Size S1, Distance D3     BEV  1836081.19  Electricity              13
# 5   Size S1, Distance D3  Diesel  1293086.41          B20               9
# 6   Size S1, Distance D3     LNG  3257875.43          LNG              22
# 7   Size S1, Distance D4     LNG   894445.82          LNG               6
# 8   Size S2, Distance D1  Diesel   726194.07          B20               4
# ...
# 2             37  3746146        102000       367.27                0.27
# 3             37  3746146        102000       244.85                0.41
# 4             44  4476447        102000       398.97                0.25
# 5             44  4476447        102000       438.87                0.23
# 6             44  4476447        102000       190.81                0.52
# 7              6   588196        102000        96.11                1.00
# 8             13  1350533        106000        98.01                1.00
# 9             19  1934621        106000      1825.11                0.05
# 10            19  1934621        106000       101.40                0.95
# 11            10  1053870        106000        99.42                1.00
# 12             2   176929        106000        83.46                1.00
# 13            40  2908543         73000       664.05                0.15
# 14            40  2908543         73000       249.02                0.40
# 15            40  2908543         73000       221.35                0.45
# 16            45  3247401         73000       296.57                0.33
# 17            45  3247401         73000       494.28                0.20
# 18            45  3247401         73000       211.83                0.47
# 19            19  1360337         73000       232.93                0.42
# 20            19  1360337         73000       169.41                0.58
# 21             4   274741         73000        94.09                1.00
# 22             1    21666        118000        18.36                1.00
# 23            10  1107787        118000        93.88                1.00
# 24             2   147590        118000        62.54                1.00
# 25             1     2369        118000         2.01                1.00
#
# Total Fleet Cost: $51,613,134.50
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2035.csv
#
# Processing topsis_results_2036.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  1881794.83          LNG              12
# 1   Size S1, Distance D2     BEV  1692265.49  Electricity              12
# 2   Size S1, Distance D2  Diesel  1229481.15          B20               8
# 3   Size S1, Distance D2     LNG  2832749.69          LNG              18
# 4   Size S1, Distance D3     BEV  1834148.96  Electricity              13
# 5   Size S1, Distance D3  Diesel  1724950.13          B20              12
# 6   Size S1, Distance D3     LNG  3300715.63          LNG              21
# 7   Size S1, Distance D4     LNG   948552.08          LNG               6
# 8   Size S2, Distance D1  Diesel   573234.02          B20               2
# 9   Size S2, Distance D1     LNG  2501292.51          LNG              12
# 10  Size S2, Distance D2  Diesel  1384143.50          B20               8
# 11  Size S2, Distance D2     LNG  2303675.25          LNG              11
# 12  Size S2, Distance D3     LNG  2292005.60          LNG              11
# 13  Size S2, Distance D4     LNG   427217.63          LNG               2
# 14  Size S3, Distance D1     BEV  2543084.41  Electricity              11
# 15  Size S3, Distance D1  Diesel  1946949.81          B20              10
# 16  Size S3, Distance D1     LNG  4726824.16          LNG              20
# 17  Size S3, Distance D2     BEV  2319689.84  Electricity              10
# 18  Size S3, Distance D2  Diesel  2130529.75          B20              11
# 19  Size S3, Distance D2     LNG  5666018.76          LNG              24
# 20  Size S3, Distance D3     LNG  4480493.97          LNG              19
# 21  Size S3, Distance D4     LNG   951194.28          LNG               4
# 22  Size S4, Distance D1     LNG   304428.38          LNG               1
# 23  Size S4, Distance D2     LNG  3027800.14          LNG              10
# 24  Size S4, Distance D3     LNG   613204.86          LNG               2
# 25  Size S4, Distance D4     LNG   301488.47          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             12  1143702        102000        93.44                1.00
# 1             38  3821393        102000       312.21                0.32
# 2             38  3821393        102000       468.31                0.21
# 3             38  3821393        102000       208.14                0.47
# 4             46  4599217        102000       346.85                0.28
# 5             46  4599217        102000       375.75                0.26
# 6             46  4599217        102000       214.72                0.46
# 7              6   602557        102000        98.46                1.00
# 8             14  1388729        106000       655.06                0.14
# 9             14  1388729        106000       109.18                0.86
# 10            19  1982301        106000       233.76                0.42
# 11            19  1982301        106000       170.01                0.58
# 12            11  1103197        106000        94.61                1.00
# 13             2   180140        106000        84.97                1.00
# 14            41  2983351         73000       371.53                0.27
# 15            41  2983351         73000       408.68                0.24
# 16            41  2983351         73000       204.34                0.49
# 17            45  3269872         73000       447.93                0.22
# 18            45  3269872         73000       407.21                0.24
# 19            45  3269872         73000       186.64                0.53
# 20            19  1377326         73000        99.30                1.00
# 21             4   280914         73000        96.20                1.00
# 22             1    22740        118000        19.27                1.00
# 23            10  1134238        118000        96.12                1.00
# 24             2   151090        118000        64.02                1.00
# 25             1     2412        118000         2.04                1.00
#
# Total Fleet Cost: $53,937,933.30
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2036.csv
#
# Processing topsis_results_2037.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     BEV   250840.17  Electricity               1
# 1   Size S1, Distance D1     LNG  1779350.70          LNG              11
# 2   Size S1, Distance D2     BEV  1964474.87  Electricity              14
# 3   Size S1, Distance D2  Diesel  1270889.04          B20               8
# 4   Size S1, Distance D2     LNG  2759201.35          LNG              17
# 5   Size S1, Distance D3     BEV  2242182.18  Electricity              16
# 6   Size S1, Distance D3  Diesel  1533319.75          B20              10
# 7   Size S1, Distance D3     LNG  3240297.81          LNG              20
# 8   Size S1, Distance D4     LNG  1135314.65          LNG               7
# 9   Size S2, Distance D1  Diesel   590691.49          B20               2
# 10  Size S2, Distance D1     LNG  2575893.90          LNG              12
# 11  Size S2, Distance D2     BEV   853456.34  Electricity               4
# 12  Size S2, Distance D2  Diesel   929552.85          B20               1
# 13  Size S2, Distance D2     LNG  3218787.64          LNG              15
# 14  Size S2, Distance D3     LNG  2360625.54          LNG              11
# 15  Size S2, Distance D4     LNG   440042.53          LNG               2
# 16  Size S3, Distance D1     BEV  2543262.50  Electricity              11
# 17  Size S3, Distance D1  Diesel  2188806.69          B20              11
# 18  Size S3, Distance D1     LNG  5110167.34          LNG              21
# 19  Size S3, Distance D2     BEV  2770990.45  Electricity              12
# 20  Size S3, Distance D2  Diesel  2193687.05          B20              11
# 21  Size S3, Distance D2     LNG  5352472.37          LNG              22
# 22  Size S3, Distance D3     BEV   522027.16  Electricity               2
# 23  Size S3, Distance D3  Diesel   633302.20          B20               2
# 24  Size S3, Distance D3     LNG  3648098.07          LNG              15
# 25  Size S3, Distance D4     LNG  1220020.20          LNG               5
# 26  Size S4, Distance D1     LNG   313517.44          LNG               1
# 27  Size S4, Distance D2     LNG  3118224.69          LNG              10
# 28  Size S4, Distance D3     LNG   631600.00          LNG               2
# 29  Size S4, Distance D4     LNG   310521.10          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             12  1196265        102000      1172.81                0.08
# 1             12  1196265        102000       106.62                0.92
# 2             39  3953052        102000       276.82                0.36
# 3             39  3953052        102000       484.44                0.21
# 4             39  3953052        102000       227.97                0.44
# 5             46  4663966        102000       285.78                0.35
# 6             46  4663966        102000       457.25                0.22
# 7             46  4663966        102000       228.63                0.43
# 8              7   630092        102000        88.25                1.00
# 9             14  1402031        106000       661.34                0.14
# 10            14  1402031        106000       110.22                0.86
# 11            20  2079105        106000       490.35                0.20
# 12            20  2079105        106000      1961.42                0.05
# 13            20  2079105        106000       130.76                0.75
# 14            11  1131832        106000        97.07                1.00
# 15             2   186733        106000        88.08                1.00
# 16            43  3128820         73000       389.64                0.26
# 17            43  3128820         73000       389.64                0.26
# 18            43  3128820         73000       204.10                0.49
# 19            45  3274991         73000       373.86                0.27
# 20            45  3274991         73000       407.84                0.24
# 21            45  3274991         73000       203.92                0.49
# 22            19  1384988         73000       948.62                0.11
# 23            19  1384988         73000       948.62                0.11
# 24            19  1384988         73000       126.48                0.79
# 25             5   292856         73000        80.23                1.00
# 26             1    23254        118000        19.71                1.00
# 27            10  1146520        118000        97.16                1.00
# 28             2   156518        118000        66.32                1.00
# 29             1     2414        118000         2.05                1.00
#
# Total Fleet Cost: $57,701,618.07
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2037.csv
#
# Processing topsis_results_2038.csv...
#
# Running optimization with dynamic maximum vehicles...
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($)         Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1     LNG  2160701.73          LNG              13
# 1   Size S1, Distance D2     BEV  1420274.70  Electricity              10
# 2   Size S1, Distance D2  Diesel  1679643.08          B20              11
# 3   Size S1, Distance D2     LNG  3167868.88          LNG              19
# 4   Size S1, Distance D3     BEV  1427975.92  Electricity              10
# 5   Size S1, Distance D3  Diesel  2492785.48          B20              17
# 6   Size S1, Distance D3     LNG  3501114.18          LNG              21
# 7   Size S1, Distance D4     LNG  1169159.07          LNG               7
# 8   Size S2, Distance D1  Diesel   700322.51          B20               1
# 9   Size S2, Distance D1     LNG  2871000.66          LNG              13
# 10  Size S2, Distance D2  Diesel  1164874.72          B20               6
# 11  Size S2, Distance D2     LNG  3315326.03          LNG              15
# 12  Size S2, Distance D3     LNG  2649985.21          LNG              12
# 13  Size S2, Distance D4     LNG   453057.44          LNG               2
# 14  Size S3, Distance D1     BEV  2316840.55  Electricity              10
# 15  Size S3, Distance D1  Diesel  2630385.86          B20              13
# 16  Size S3, Distance D1     LNG  5511979.78          LNG              22
# 17  Size S3, Distance D2     BEV  3224235.95  Electricity              14
# 18  Size S3, Distance D2  Diesel  1715969.87          B20               8
# 19  Size S3, Distance D2     LNG  6009827.05          LNG              24
# 20  Size S3, Distance D3     BEV   522285.93  Electricity               2
# 21  Size S3, Distance D3  Diesel   738485.52          B20               1
# 22  Size S3, Distance D3     LNG  4255232.63          LNG              17
# 23  Size S3, Distance D4     LNG  1256719.41          LNG               5
# 24  Size S4, Distance D1     LNG   322828.75          LNG               1
# 25  Size S4, Distance D2     LNG  3211204.26          LNG              10
# 26  Size S4, Distance D3     LNG   650491.53          LNG               2
# 27  Size S4, Distance D4     LNG   319828.33          LNG               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0             13  1254358        102000        94.60                1.00
# 1             40  3994169        102000       391.59                0.25
# 2             40  3994169        102000       355.99                0.28
# 3             40  3994169        102000       206.10                0.47
# 4             48  4847871        102000       475.28                0.21
# 5             48  4847871        102000       279.58                0.35
# 6             48  4847871        102000       226.32                0.44
# 7              7   642216        102000        89.95                1.00
# 8             14  1410693        106000      1330.84                0.07
# 9             14  1410693        106000       102.37                0.93
# 10            21  2151804        106000       338.33                0.29
# 11            21  2151804        106000       135.33                0.71
# 12            12  1187938        106000        93.39                1.00
# 13             2   190889        106000        90.04                1.00
# 14            45  3229278         73000       442.37                0.22
# 15            45  3229278         73000       340.28                0.29
# 16            45  3229278         73000       201.08                0.49
# 17            46  3297618         73000       322.66                0.30
# 18            46  3297618         73000       564.66                0.17
# 19            46  3297618         73000       188.22                0.52
# 20            20  1448550         73000       992.16                0.10
# 21            20  1448550         73000      1984.32                0.05
# 22            20  1448550         73000       116.72                0.85
# 23             5   306910         73000        84.08                1.00
# 24             1    23437        118000        19.86                1.00
# 25            10  1148555        118000        97.34                1.00
# 26             2   161386        118000        68.38                1.00
# 27             1     2446        118000         2.07                1.00
#
# Total Fleet Cost: $60,860,405.03
# Results saved to fleet_optimization_results\optimized_fleet_allocation_2038.csv
#
# Yearly total cost summary saved to fleet_optimization_results\yearly_total_cost_summary.csv

# %%
# without topsis


import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    # print("Columns after renaming:", df.columns)


    # Calculate Total Cost if missing
    # if 'Total_Cost' not in df.columns:
    #     df['Total_Cost'] = df['Insurance_Cost'] + df['Maintenance_Cost'] + df['Fuel_Costs']

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def calculate_utilization(self, demand: float, num_vehicles: int, yearly_range: float) -> float:
        """Calculate utilization metric for a vehicle type"""
        if num_vehicles == 0 or yearly_range == 0:
            return 0
        return (demand / num_vehicles) / yearly_range * 100

    def calculate_demand_fulfillment(self, num_vehicles: int, max_vehicles: int) -> float:
        """Calculate demand fulfillment by fuel type"""
        if max_vehicles == 0:
            return 0
        return num_vehicles / max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs_per_km']+
            vehicle['Cost ($)']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. Meeting demand requirements
        2. Total cost
        3. Penalty for exceeding maximum vehicles
        
        TOPSIS score is now removed from the calculation
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']

        
        # Penalize solutions that don't meet demand
        demand = vehicles[0]['demand']
        demand_penalty = max(0, demand - total_capacity) * 1000
        
        # Normalize costs (lower is better)
        cost_score = 1 / (total_cost + 1)
        
        # Return fitness score without TOPSIS component
        return cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    # Calculate evaluation metrics
                    utilization = self.calculate_utilization(
                        vehicle_data['demand'],
                        num_vehicles,
                        vehicle_data['yearly_range']
                    )
                    
                    demand_fulfillment = self.calculate_demand_fulfillment(
                        num_vehicles,
                        max_vehicles
                    )

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        "Utilization": round(utilization, 2),
                        "Demand_Fulfillment": round(demand_fulfillment, 2)
                    })

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    
    # Calculate and print the total cost across all allocations
    total_cost = optimized_results["Cost ($)"].sum()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    print(f"\nTotal Fleet Cost: ${total_cost:,.2f}")
    
    return optimized_results

if __name__ == "__main__":
    csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    # results_df.to_csv("optimized_fleet_allocation_2023.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
# Columns after renaming: Index(['Allocation', 'Operating Year', 'Size', 'Distance_demand', 'Demand',
#        'ID', 'Vehicle', 'Available Year', 'Cost', 'Yearly_Range',
#        'Distance_vehicle', 'Fuel', 'carbon_emissions_per_km', 'Insurance_Cost',
#        'Maintenance_Cost', 'Fuel_Costs', 'Total_Cost', 'Topsis_Score', 'Rank',
#        'Distance'],
#       dtype='object')
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($) Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1  Diesel   450501.36  B20               5
# 1   Size S1, Distance D2  Diesel   540601.63  B20               6
# 2   Size S1, Distance D2     LNG   742001.17  LNG               7
# 3   Size S1, Distance D3  Diesel  1081203.27  B20              12
# 4   Size S1, Distance D3     LNG   530000.84  LNG               5
# 5   Size S1, Distance D4  Diesel   270300.82  B20               3
# 6   Size S2, Distance D1  Diesel   551201.37  B20               5
# 7   Size S2, Distance D2  Diesel   771681.91  B20               7
# 8   Size S2, Distance D3  Diesel   440961.09  B20               4
# 9   Size S2, Distance D4  Diesel   110240.27  B20               1
# 10  Size S3, Distance D1  Diesel  1628537.74  B20              13
# 11  Size S3, Distance D1     LNG   320408.65  LNG               2
# 12  Size S3, Distance D2  Diesel  1503265.60  B20              12
# 13  Size S3, Distance D2     LNG   801021.63  LNG               5
# 14  Size S3, Distance D3  Diesel   876904.93  B20               7
# 15  Size S3, Distance D4  Diesel   250544.27  B20               2
# 16  Size S4, Distance D1  Diesel   160348.59  B20               1
# 17  Size S4, Distance D2  Diesel   641394.35  B20               4
# 18  Size S4, Distance D3  Diesel   160348.59  B20               1
# 19  Size S4, Distance D4  Diesel   160348.59  B20               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   869181        102000       170.43                0.56
# 1             26  2597094        102000       424.36                0.23
# 2             26  2597094        102000       363.74                0.27
# 3             33  3292011        102000       268.96                0.36
# 4             33  3292011        102000       645.49                0.15
# 5              5   414315        102000       135.40                0.60
# 6             10   995694        106000       187.87                0.50
# 7             14  1383196        106000       186.41                0.50
# 8              8   778008        106000       183.49                0.50
# 9              2   133677        106000       126.11                0.50
# 10            30  2183475         73000       230.08                0.43
# 11            30  2183475         73000      1495.53                0.07
# 12            34  2431901         73000       277.61                0.35
# 13            34  2431901         73000       666.27                0.15
# 14            14  1002466         73000       196.18                0.50
# 15             3   205426         73000       140.70                0.67
# 16             1    14576        118000        12.35                1.00
# 17             7   754717        118000       159.90                0.57
# 18             2   118899        118000       100.76                0.50
# 19             1     1809        118000         1.53                1.00
#
# Total Fleet Cost: $11,991,816.67

# %%
import pandas as pd
import random
from typing import List, Dict, Tuple
import numpy as np
import math

def load_and_preprocess_data(csv_path: str) -> pd.DataFrame:
    """Load and preprocess the fleet data from CSV file."""
    df = pd.read_csv(csv_path)
    
    # Rename columns properly
    column_mapping = {
        'Unnamed: 0': 'Index',
        'Distance_demand': 'Distance_demand',
        'Demand (km)': 'Demand',
        'Cost ($)': 'Cost',
        'Yearly range (km)': 'Yearly_Range',
        'insurance_cost': 'Insurance_Cost',
        'maintenance_cost': 'Maintenance_Cost',
        'fuel_costs_per_km': 'Fuel_Costs',
        'Fuel': 'Fuel',
        'Total_Cost': 'Total_Cost',
        'Topsis_Score': 'Topsis_Score',
    }
    
    df.rename(columns=column_mapping, inplace=True, errors='ignore')
    print("Columns after renaming:", df.columns)

    return df

class FleetOptimizer:
    def __init__(self, data: pd.DataFrame):
        self.data = data
        self.vehicles_by_size_distance = self._group_vehicles()
        self.max_vehicles_by_group = self._calculate_max_vehicles()
    
    def _group_vehicles(self) -> Dict:
        """Group vehicles by (Size, Distance_demand) combination"""
        groups = {}
        for _, row in self.data.iterrows():
            key = (row['Size'], row['Distance_demand'])
            if key not in groups:
                groups[key] = []
            groups[key].append({
                'vehicle_type': row['Vehicle'],
                'yearly_range': row['Yearly_Range'],
                'topsis_score': row['Topsis_Score'],
                'insurance_cost': row['Insurance_Cost'],
                'maintenance_cost': row['Maintenance_Cost'],
                'Cost ($)':row['Cost'],
                'fuel_costs_per_km': row['Fuel_Costs'],
                'fuel': row['Fuel'],
                'demand': row['Demand']
            })
        return groups
    
    def _calculate_max_vehicles(self) -> Dict:
        """Calculate maximum vehicles for each size-distance combination"""
        max_vehicles = {}
        for key, vehicles in self.vehicles_by_size_distance.items():
            # Get demand for this combination
            demand = vehicles[0]['demand']  # All vehicles in the same group have the same demand
            
            # Calculate max vehicles based on the vehicle with highest yearly range
            max_yearly_range = max(v['yearly_range'] for v in vehicles)
            
            # Calculate max vehicles needed and round up to ensure demand is met
            max_vehicles[key] = math.ceil(demand / max_yearly_range)
        
        return max_vehicles

    def calculate_utilization(self, demand: float, num_vehicles: int, yearly_range: float) -> float:
        """Calculate utilization metric for a vehicle type"""
        if num_vehicles == 0 or yearly_range == 0:
            return 0
        return (demand / num_vehicles) / yearly_range * 100

    def calculate_demand_fulfillment(self, num_vehicles: int, max_vehicles: int) -> float:
        """Calculate demand fulfillment by fuel type"""
        if max_vehicles == 0:
            return 0
        return num_vehicles / max_vehicles

    def is_valid_solution(self, solution: Dict, size_distance: Tuple) -> bool:
        """Check if the total number of vehicles in the solution is within the dynamic maximum limit"""
        return sum(solution.values()) <= self.max_vehicles_by_group[size_distance]

    def calculate_total_cost(self, num_vehicles: int, vehicle: Dict) -> float:
        """Calculate total cost including insurance, maintenance, and fuel costs"""
        return num_vehicles * (
            vehicle['insurance_cost'] + 
            vehicle['maintenance_cost'] + 
            vehicle['fuel_costs_per_km']+
            vehicle['Cost ($)']
        )

    def generate_initial_population(self, size_distance: Tuple, population_size: int = 50) -> List[Dict]:
        """Generate initial population of fleet combinations"""
        population = []
        vehicles = self.vehicles_by_size_distance[size_distance]
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while len(population) < population_size:
            # Generate a solution
            solution = {v['vehicle_type']: 0 for v in vehicles}
            remaining_vehicles = max_vehicles
            
            # Randomly distribute vehicles while respecting the total maximum
            vehicle_types = list(solution.keys())
            while remaining_vehicles > 0 and vehicle_types:
                vehicle_type = random.choice(vehicle_types)
                if random.random() < 0.5:  # 50% chance to add a vehicle
                    solution[vehicle_type] += 1
                    remaining_vehicles -= 1
                else:
                    vehicle_types.remove(vehicle_type)
            
            if self.is_valid_solution(solution, size_distance):
                population.append(solution)
        
        return population

    def crossover(self, parent1: Dict, parent2: Dict, size_distance: Tuple) -> Tuple[Dict, Dict]:
        """Perform crossover between two parent solutions while respecting dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        
        while attempts < max_attempts:
            crossover_point = random.randint(1, len(parent1) - 1)
            child1 = {}
            child2 = {}
            
            for i, vehicle_type in enumerate(parent1.keys()):
                if i < crossover_point:
                    child1[vehicle_type] = parent1[vehicle_type]
                    child2[vehicle_type] = parent2[vehicle_type]
                else:
                    child1[vehicle_type] = parent2[vehicle_type]
                    child2[vehicle_type] = parent1[vehicle_type]
            
            if (self.is_valid_solution(child1, size_distance) and 
                self.is_valid_solution(child2, size_distance)):
                return child1, child2
            
            attempts += 1
        
        # If we can't create valid children, return copies of parents
        return parent1.copy(), parent2.copy()

    def mutate(self, solution: Dict, size_distance: Tuple, mutation_rate: float = 0.1) -> Dict:
        """Mutate a solution while respecting the dynamic vehicle limit"""
        attempts = 0
        max_attempts = 10
        max_vehicles = self.max_vehicles_by_group[size_distance]
        
        while attempts < max_attempts:
            mutated_solution = solution.copy()
            total_vehicles = sum(mutated_solution.values())
            
            for vehicle_type in mutated_solution.keys():
                if random.random() < mutation_rate:
                    change = random.choice([-1, 1])
                    if (change == 1 and total_vehicles < max_vehicles) or \
                       (change == -1 and mutated_solution[vehicle_type] > 0):
                        mutated_solution[vehicle_type] += change
                        total_vehicles += change
            
            if self.is_valid_solution(mutated_solution, size_distance):
                return mutated_solution
            
            attempts += 1
        
        return solution  # Return original if no valid mutation found

    def fitness_function(self, solution: Dict, size_distance: Tuple) -> float:
        """
        Calculate fitness of a solution based on:
        1. Meeting demand requirements (significantly increased priority)
        2. Total cost
        3. Penalty for exceeding maximum vehicles
        """
        if not self.is_valid_solution(solution, size_distance):
            return float('-inf')
            
        vehicles = self.vehicles_by_size_distance[size_distance]
        total_cost = 0
        total_capacity = 0
        
        for vehicle in vehicles:
            num_vehicles = solution[vehicle['vehicle_type']]
            total_cost += self.calculate_total_cost(num_vehicles, vehicle)
            total_capacity += num_vehicles * vehicle['yearly_range']
        
        # Get demand for this combination
        demand = vehicles[0]['demand']
        
        # Calculate demand fulfillment ratio (1.0 = fully met, < 1.0 = not fully met)
        demand_fulfillment = min(1.0, total_capacity / demand) if demand > 0 else 1.0
        
        # Much stronger penalty for not meeting demand (increased by 10x)
        demand_penalty = max(0, demand - total_capacity) * 10000
        
        # Calculate demand bonus to favor solutions that meet demand
        demand_bonus = 5000 * demand_fulfillment
        
        # Normalize costs (lower is better)
        cost_score = 1000 / (total_cost + 1)
        
        # Return fitness with much higher weight on meeting demand
        return demand_bonus + cost_score - demand_penalty

    def optimize(self, size_distance: Tuple, generations: int = 100) -> Dict:
        """Run genetic algorithm to find optimal fleet combination"""
        population = self.generate_initial_population(size_distance)
        best_solution = None
        best_fitness = float('-inf')
        
        for _ in range(generations):
            # Calculate fitness for all solutions
            fitness_scores = [(solution, self.fitness_function(solution, size_distance))
                            for solution in population]
            
            # Sort by fitness (descending)
            fitness_scores.sort(key=lambda x: x[1], reverse=True)
            
            # Update best solution if needed
            if fitness_scores[0][1] > best_fitness:
                best_solution = fitness_scores[0][0]
                best_fitness = fitness_scores[0][1]
            
            # Select parents for next generation
            parents = [score[0] for score in fitness_scores[:len(population)//2]]
            
            # Create next generation
            next_generation = parents.copy()
            while len(next_generation) < len(population):
                parent1, parent2 = random.sample(parents, 2)
                child1, child2 = self.crossover(parent1, parent2, size_distance)
                child1 = self.mutate(child1, size_distance)
                child2 = self.mutate(child2, size_distance)
                next_generation.extend([child1, child2])
            
            population = next_generation[:len(population)]
        
        return best_solution

    def get_optimized_results(self) -> pd.DataFrame:
        """Run optimization and return results in the required format"""
        results = []
        
        for size_distance in self.vehicles_by_size_distance.keys():
            best_solution = self.optimize(size_distance)
            max_vehicles = self.max_vehicles_by_group[size_distance]
            
            # Calculate total capacity and demand for this group
            vehicles = self.vehicles_by_size_distance[size_distance]
            demand = vehicles[0]['demand']
            total_capacity = 0
            
            for vehicle_type, num_vehicles in best_solution.items():
                if num_vehicles > 0:
                    vehicle_data = next(v for v in self.vehicles_by_size_distance[size_distance] 
                                     if v['vehicle_type'] == vehicle_type)
                    total_capacity += num_vehicles * vehicle_data['yearly_range']
                    total_cost = self.calculate_total_cost(num_vehicles, vehicle_data)

                    # Calculate evaluation metrics
                    utilization = self.calculate_utilization(
                        vehicle_data['demand'],
                        num_vehicles,
                        vehicle_data['yearly_range']
                    )
                    
                    demand_fulfillment = self.calculate_demand_fulfillment(
                        num_vehicles,
                        max_vehicles
                    )

                    results.append({
                        "Allocation": f"Size {size_distance[0]}, Distance {size_distance[1]}",
                        "Vehicle": vehicle_type,
                        "Cost ($)": round(total_cost, 2),
                        "Fuel": vehicle_data['fuel'],
                        "no_of_vehicles": num_vehicles,
                        "Max Vehicles": max_vehicles,
                        "Demand": vehicle_data['demand'],
                        "Yearly Range": vehicle_data['yearly_range'],
                        "Utilization": round(utilization, 2),
                        "Demand_Fulfillment": round(demand_fulfillment, 2)
                    })
            
            # Print warning if demand is not met for this group
            demand_met_percentage = (total_capacity / demand) * 100 if demand > 0 else 100
            if demand_met_percentage < 100:
                print(f"WARNING: Demand not fully met for {size_distance}. Capacity: {total_capacity}, Demand: {demand} ({demand_met_percentage:.1f}%)")

        return pd.DataFrame(results)

def main(csv_path: str):
    """Main function to run the optimization"""
    print("\nRunning optimization with dynamic maximum vehicles...")
    data_df = load_and_preprocess_data(csv_path)
    optimizer = FleetOptimizer(data_df)
    optimized_results = optimizer.get_optimized_results()
    
    # Calculate and print the total cost across all allocations
    total_cost = optimized_results["Cost ($)"].sum()
    print("\nOptimized Fleet Allocation:")
    print(optimized_results)
    print(f"\nTotal Fleet Cost: ${total_cost:,.2f}")
    
    # Check if all demand is met
    allocations = optimized_results["Allocation"].unique()
    total_demand_met = True
    
    for allocation in allocations:
        allocation_rows = optimized_results[optimized_results["Allocation"] == allocation]
        demand = allocation_rows["Demand"].iloc[0]
        total_capacity = sum(allocation_rows["no_of_vehicles"] * allocation_rows["Yearly Range"])
        if total_capacity < demand:
            total_demand_met = False
            print(f"WARNING: {allocation} - Demand not fully met. Capacity: {total_capacity}, Demand: {demand}")
    
    if total_demand_met:
        print("\nAll demand requirements have been successfully met!")
    else:
        print("\nWARNING: Some demand requirements were not fully met. Consider adjusting parameters.")
    
    return optimized_results

if __name__ == "__main__":
    csv_path = "topsis_result/topsis_results_2023.csv"  # Replace with your CSV file path
    results_df = main(csv_path)
    # results_df.to_csv("optimized_fleet_allocation_2023.csv", index=False)
# Out:
# Running optimization with dynamic maximum vehicles...
# Columns after renaming: Index(['Allocation', 'Operating Year', 'Size', 'Distance_demand', 'Demand',
#        'ID', 'Vehicle', 'Available Year', 'Cost', 'Yearly_Range',
#        'Distance_vehicle', 'Fuel', 'carbon_emissions_per_km', 'Insurance_Cost',
#        'Maintenance_Cost', 'Fuel_Costs', 'Total_Cost', 'Topsis_Score', 'Rank',
#        'Distance'],
#       dtype='object')
# WARNING: Demand not fully met for ('S1', 'D1'). Capacity: 510000, Demand: 869181 (58.7%)
# WARNING: Demand not fully met for ('S1', 'D2'). Capacity: 1326000, Demand: 2597094 (51.1%)
# WARNING: Demand not fully met for ('S1', 'D3'). Capacity: 1734000, Demand: 3292011 (52.7%)
# WARNING: Demand not fully met for ('S1', 'D4'). Capacity: 306000, Demand: 414315 (73.9%)
# WARNING: Demand not fully met for ('S2', 'D1'). Capacity: 530000, Demand: 995694 (53.2%)
# WARNING: Demand not fully met for ('S2', 'D2'). Capacity: 742000, Demand: 1383196 (53.6%)
# WARNING: Demand not fully met for ('S2', 'D3'). Capacity: 424000, Demand: 778008 (54.5%)
# WARNING: Demand not fully met for ('S2', 'D4'). Capacity: 106000, Demand: 133677 (79.3%)
# WARNING: Demand not fully met for ('S3', 'D1'). Capacity: 1095000, Demand: 2183475 (50.1%)
# WARNING: Demand not fully met for ('S3', 'D2'). Capacity: 1241000, Demand: 2431901 (51.0%)
# WARNING: Demand not fully met for ('S3', 'D3'). Capacity: 511000, Demand: 1002466 (51.0%)
# WARNING: Demand not fully met for ('S3', 'D4'). Capacity: 146000, Demand: 205426 (71.1%)
# WARNING: Demand not fully met for ('S4', 'D2'). Capacity: 472000, Demand: 754717 (62.5%)
# WARNING: Demand not fully met for ('S4', 'D3'). Capacity: 118000, Demand: 118899 (99.2%)
#
# Optimized Fleet Allocation:
#               Allocation Vehicle    Cost ($) Fuel  no_of_vehicles  \
# 0   Size S1, Distance D1  Diesel   450501.36  B20               5
# 1   Size S1, Distance D2  Diesel   360401.09  B20               4
# 2   Size S1, Distance D2     LNG   954001.51  LNG               9
# 3   Size S1, Distance D3  Diesel   991102.99  B20              11
# 4   Size S1, Distance D3     LNG   636001.00  LNG               6
# 5   Size S1, Distance D4  Diesel   270300.82  B20               3
# 6   Size S2, Distance D1  Diesel   551201.37  B20               5
# 7   Size S2, Distance D2  Diesel   661441.64  B20               6
# 8   Size S2, Distance D2     LNG   140980.17  LNG               1
# 9   Size S2, Distance D3  Diesel   440961.09  B20               4
# 10  Size S2, Distance D4  Diesel   110240.27  B20               1
# 11  Size S3, Distance D1  Diesel   876904.93  B20               7
# 12  Size S3, Distance D1     LNG  1281634.61  LNG               8
# 13  Size S3, Distance D2  Diesel  1252721.34  B20              10
# 14  Size S3, Distance D2     LNG  1121430.29  LNG               7
# 15  Size S3, Distance D3  Diesel   876904.93  B20               7
# 16  Size S3, Distance D4  Diesel   250544.27  B20               2
# 17  Size S4, Distance D1  Diesel   160348.59  B20               1
# 18  Size S4, Distance D2  Diesel   641394.35  B20               4
# 19  Size S4, Distance D3  Diesel   160348.59  B20               1
# 20  Size S4, Distance D4  Diesel   160348.59  B20               1
#
#     Max Vehicles   Demand  Yearly Range  Utilization  Demand_Fulfillment
# 0              9   869181        102000       170.43                0.56
# 1             26  2597094        102000       636.54                0.15
# 2             26  2597094        102000       282.91                0.35
# 3             33  3292011        102000       293.41                0.33
# 4             33  3292011        102000       537.91                0.18
# 5              5   414315        102000       135.40                0.60
# 6             10   995694        106000       187.87                0.50
# 7             14  1383196        106000       217.48                0.43
# 8             14  1383196        106000      1304.90                0.07
# 9              8   778008        106000       183.49                0.50
# 10             2   133677        106000       126.11                0.50
# 11            30  2183475         73000       427.29                0.23
# 12            30  2183475         73000       373.88                0.27
# 13            34  2431901         73000       333.14                0.29
# 14            34  2431901         73000       475.91                0.21
# 15            14  1002466         73000       196.18                0.50
# 16             3   205426         73000       140.70                0.67
# 17             1    14576        118000        12.35                1.00
# 18             7   754717        118000       159.90                0.57
# 19             2   118899        118000       100.76                0.50
# 20             1     1809        118000         1.53                1.00
#
# Total Fleet Cost: $12,349,713.80
# WARNING: Size S1, Distance D1 - Demand not fully met. Capacity: 510000, Demand: 869181
# WARNING: Size S1, Distance D2 - Demand not fully met. Capacity: 1326000, Demand: 2597094
# WARNING: Size S1, Distance D3 - Demand not fully met. Capacity: 1734000, Demand: 3292011
# WARNING: Size S1, Distance D4 - Demand not fully met. Capacity: 306000, Demand: 414315
# WARNING: Size S2, Distance D1 - Demand not fully met. Capacity: 530000, Demand: 995694
# WARNING: Size S2, Distance D2 - Demand not fully met. Capacity: 742000, Demand: 1383196
# WARNING: Size S2, Distance D3 - Demand not fully met. Capacity: 424000, Demand: 778008
# WARNING: Size S2, Distance D4 - Demand not fully met. Capacity: 106000, Demand: 133677
# WARNING: Size S3, Distance D1 - Demand not fully met. Capacity: 1095000, Demand: 2183475
# WARNING: Size S3, Distance D2 - Demand not fully met. Capacity: 1241000, Demand: 2431901
# WARNING: Size S3, Distance D3 - Demand not fully met. Capacity: 511000, Demand: 1002466
# WARNING: Size S3, Distance D4 - Demand not fully met. Capacity: 146000, Demand: 205426
# WARNING: Size S4, Distance D2 - Demand not fully met. Capacity: 472000, Demand: 754717
# WARNING: Size S4, Distance D3 - Demand not fully met. Capacity: 118000, Demand: 118899
#
# WARNING: Some demand requirements were not fully met. Consider adjusting parameters.
