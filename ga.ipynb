# %%
import pandas as pd

# %%
df = pd.read_csv("data/something_new.csv")

# %%
df.drop(columns=['Allocation','Year','Distance_x','Demand (km)'], inplace=True)

# %%
# we have 204 items in the dataset
# a random example solution in chromosome representation: 0 1 0 1 0 0 1 1....... 0 1 1
# constraint --> total carbon emissions of the picked vehicles should be less than threshold giveb meet demand for each vehicle type
# objective --> minimize cost

# %%
df.rename(columns={'Distance_y':'Distance'}, inplace=True)

# %%
df
# Out:
#     Size              ID Vehicle  Cost ($)  Yearly range (km) Distance  \
# 0     S1     BEV_S1_2023     BEV    187000             102000       D1
# 1     S1     BEV_S1_2023     BEV    187000             102000       D1
# 2     S1     BEV_S1_2023     BEV    187000             102000       D1
# 3     S1  Diesel_S1_2023  Diesel     85000             102000       D4
# 4     S1  Diesel_S1_2023  Diesel     85000             102000       D4
# ..   ...             ...     ...       ...                ...      ...
# 199   S3     LNG_S3_2023     LNG    151136              73000       D4
# 200   S3     LNG_S3_2023     LNG    151136              73000       D4
# 201   S3     LNG_S3_2023     LNG    151136              73000       D4
# 202   S3     LNG_S3_2023     LNG    151136              73000       D4
# 203   S3     LNG_S3_2023     LNG    151136              73000       D4
#
#      Operating Year         Fuel  carbon_emissions  insurance_cost  \
# ...

# %%
df.to_csv('data/something_new_new.csv')

# %%
df
# Out:
#     Size              ID Vehicle  Cost ($)  Yearly range (km) Distance  \
# 0     S1     BEV_S1_2023     BEV    187000             102000       D1
# 1     S1     BEV_S1_2023     BEV    187000             102000       D1
# 2     S1     BEV_S1_2023     BEV    187000             102000       D1
# 3     S1  Diesel_S1_2023  Diesel     85000             102000       D4
# 4     S1  Diesel_S1_2023  Diesel     85000             102000       D4
# ..   ...             ...     ...       ...                ...      ...
# 199   S3     LNG_S3_2023     LNG    151136              73000       D4
# 200   S3     LNG_S3_2023     LNG    151136              73000       D4
# 201   S3     LNG_S3_2023     LNG    151136              73000       D4
# 202   S3     LNG_S3_2023     LNG    151136              73000       D4
# 203   S3     LNG_S3_2023     LNG    151136              73000       D4
#
#      Operating Year         Fuel  carbon_emissions  insurance_cost  \
# ...
