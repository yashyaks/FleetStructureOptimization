# %%
import pandas as pd
import numpy as np

# %%
topsis_results = pd.read_csv('data/topsis_results.csv')

# %%
topsis_results
# Out:
#          Allocation  Year Size Distance_x  Demand (km)              ID  \
# 0       BEV_S1_2023  2023   S1         D1       869181     BEV_S1_2023
# 1       BEV_S1_2023  2023   S1         D1       869181     BEV_S1_2023
# 2    Diesel_S1_2023  2023   S1         D1       869181  Diesel_S1_2023
# 3    Diesel_S1_2023  2023   S1         D1       869181  Diesel_S1_2023
# 4    Diesel_S1_2023  2023   S1         D1       869181  Diesel_S1_2023
# ..              ...   ...  ...        ...          ...             ...
# 131  Diesel_S4_2023  2023   S4         D4         1809  Diesel_S4_2023
# 132     LNG_S4_2023  2023   S4         D4         1809     LNG_S4_2023
# 133     LNG_S4_2023  2023   S4         D4         1809     LNG_S4_2023
# 134     LNG_S4_2023  2023   S4         D4         1809     LNG_S4_2023
# 135     LNG_S4_2023  2023   S4         D4         1809     LNG_S4_2023
#
#     Vehicle  Cost ($)  Yearly range (km) Distance_y  ...  insurance_cost  \
# ...

# %%
combinations = topsis_results.groupby(["Size", "Distance_x"])

# %%
for (size, distance_x), group in combinations:
